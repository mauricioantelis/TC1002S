# %% [markdown]
# # LEER DATOS CON PANDAS
#
# El objetivo de este notebook es leer el archivo de datos .csv con las informacion del dataset cartwheel

# %% [markdown]
# # Definiciones

# %%
# Aqui van las definciones

#rutadatos = TBD

# %% [markdown]
# # Import libraries

# %%
# Importar pakages
import pandas as pd

# %%
# Import the library to mount Google Drive
from google.colab import drive

# Mount the Google Drive at /content/drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls 'drive/MyDrive/TC1002S/NotebooksProfessor/cartwheel/'
# Out:
# cartwheel.csv  NB1_LeerDatosCartWheel.ipynb

# %% [markdown]
# # Leer datos
#
# Cargar el archivo de datos y ponerlo en un datframe de pandas

# %%
# Define the file path
file_path = '/content/drive/MyDrive/TC1002S/NotebooksProfessor/cartwheel/cartwheel.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# %%
df
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %%
# Get number of rows and columns
df.shape
# Out:
# (52, 12)

# %%
# Get number of rows
Nrows = df.shape[0]

# Print number of rows
print('The number of rows is ' + str(Nrows) )
# Out:
# The number of rows is 52

# %%
# Get number of cols
Ncols = df.shape[1]

# Print number of cols
print('The number of cols is ' + str(Ncols) )
# Out:
# The number of cols is 12

# %% [markdown]
# # Explorar dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             52 non-null     int64
#  1   Age            51 non-null     float64
#  2   Gender         52 non-null     object
#  3   GenderGroup    52 non-null     int64
#  4   Glasses        52 non-null     object
#  5   GlassesGroup   52 non-null     int64
#  6   Height         51 non-null     float64
#  7   Wingspan       51 non-null     float64
#  8   CWDistance     52 non-null     int64
#  9   Complete       52 non-null     object
#  10  CompleteGroup  51 non-null     float64
#  11  Score          52 non-null     int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 5.0+ KB

# %%
# Obtener los nombres de las columna
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
# Obtener los datos de una columna
#df.Age
#df["Age"]

# %%
# Obtener un nuevo dataframe con algunas columnas
df2 = df[ ["Age","Height","Wingspan","CWDistance"] ]

# %%
df2.head(3)
# Out:
#     Age  Height  Wingspan  CWDistance
# 0  56.0    62.0      61.0          79
# 1  26.0    62.0      60.0          70
# 2  33.0    66.0      64.0          85

# %%
df2.tail(3)
# Out:
#      Age  Height  Wingspan  CWDistance
# 49  30.0    74.6       NaN          71
# 50   NaN    71.0      70.0         101
# 51  27.0     NaN      71.5         103

# %%
# Identificar rows/cols with mission information
df.isnull()
# Out:
#        ID    Age  Gender  GenderGroup  Glasses  GlassesGroup  Height  \
# 0   False  False   False        False    False         False   False
# 1   False  False   False        False    False         False   False
# 2   False  False   False        False    False         False   False
# 3   False  False   False        False    False         False   False
# 4   False  False   False        False    False         False   False
# 5   False  False   False        False    False         False   False
# 6   False  False   False        False    False         False   False
# 7   False  False   False        False    False         False   False
# 8   False  False   False        False    False         False   False
# 9   False  False   False        False    False         False   False
# 10  False  False   False        False    False         False   False
# 11  False  False   False        False    False         False   False
# 12  False  False   False        False    False         False   False
# ...

# %% [markdown]
# # Estadistica de las variales
#
# Calcular e imprimir estadisticas descriptiva

# %%
# Imprimir estadistica descriptiva
