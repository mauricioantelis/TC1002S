# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing data

# %%
# Define where you are running the code: colab or local
RunInColab          = False     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

else:
    # Define path del proyecto
    Ruta = "C:/Users/jplop/OneDrive/Documentos/School/Semestre4/Herramientas Computacionales/TC1002S/NotebooksProfessor/"

# %%
# url string that hosts our .csv file
url = Ruta + "datasets/cartwheel/cartwheel.csv"

# Read the .csv file and store it as a pandas Data Frame
db = pd.read_csv(url)

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
db
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
columns = ['Age','Gender','GenderGroup','Glasses','GlassesGroup','Height','Wingspan','CWDistance','Complete','CompleteGroup','Score']
for col in columns:
    print(db[col].value_counts())
    print(' ')
# Out:
# Age
# 26.0    7
# 27.0    7
# 24.0    5
# 28.0    5
# 23.0    5
# 30.0    4
# 25.0    4
# 33.0    3
# 39.0    2
# 29.0    2
# 31.0    2
# 38.0    2
# 56.0    1
# 22.0    1
# 32.0    1
# Name: count, dtype: int64
#
# Gender
# F    26
# M    26
# Name: count, dtype: int64
#
# GenderGroup
# 1    26
# 2    26
# Name: count, dtype: int64
#
# Glasses
# Y    26
# N    26
# Name: count, dtype: int64
#
# GlassesGroup
# 1    26
# 0    26
# Name: count, dtype: int64
#
# Height
# 61.50    4
# 65.00    4
# 62.00    3
# 64.00    3
# 73.00    3
# 75.00    3
# 66.00    3
# 71.00    3
# 68.00    2
# 70.00    2
# 69.00    2
# 63.00    2
# 69.50    2
# 62.75    1
# 73.50    1
# 77.80    1
# 79.50    1
# 78.00    1
# 72.00    1
# 72.50    1
# 67.80    1
# 70.40    1
# 77.00    1
# 65.30    1
# 76.00    1
# 78.40    1
# 74.00    1
# 74.60    1
# Name: count, dtype: int64
#
# Wingspan
# 66.0    5
# 63.0    4
# 75.0    4
# 71.0    4
# 72.0    4
# 60.0    4
# 64.0    3
# 76.0    3
# 61.0    2
# 74.0    2
# ...

# %%
# Proportion of each distinct value of a variable occurs in a data set
columns = ['Age','Gender','GenderGroup','Glasses','GlassesGroup','Height','Wingspan','CWDistance','Complete','CompleteGroup','Score']
for col in columns:
    print(db[col].value_counts()/len(db))
    print(' ')
# Out:
# Age
# 26.0    0.134615
# 27.0    0.134615
# 24.0    0.096154
# 28.0    0.096154
# 23.0    0.096154
# 30.0    0.076923
# 25.0    0.076923
# 33.0    0.057692
# 39.0    0.038462
# 29.0    0.038462
# 31.0    0.038462
# 38.0    0.038462
# 56.0    0.019231
# 22.0    0.019231
# 32.0    0.019231
# Name: count, dtype: float64
#
# Gender
# F    0.5
# M    0.5
# Name: count, dtype: float64
#
# GenderGroup
# 1    0.5
# 2    0.5
# Name: count, dtype: float64
#
# Glasses
# Y    0.5
# N    0.5
# Name: count, dtype: float64
#
# GlassesGroup
# 1    0.5
# 0    0.5
# Name: count, dtype: float64
#
# Height
# 61.50    0.076923
# 65.00    0.076923
# 62.00    0.057692
# 64.00    0.057692
# 73.00    0.057692
# 75.00    0.057692
# 66.00    0.057692
# 71.00    0.057692
# 68.00    0.038462
# 70.00    0.038462
# 69.00    0.038462
# 63.00    0.038462
# 69.50    0.038462
# 62.75    0.019231
# 73.50    0.019231
# 77.80    0.019231
# 79.50    0.019231
# 78.00    0.019231
# 72.00    0.019231
# 72.50    0.019231
# ...

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
print('total observations:', len(db))

# Total number of null observations
X = db.dropna()
print('null observations:', len(db)-len(X))

# Total number of counts (excluding missing values)
print('total counts:', len(X))
# Out:
# total observations: 52
# null observations: 3
# total counts: 49

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of the total bill only
plt.hist(db['Glasses'])
plt.show()

# %%
# Plot distribution of the tips only
plt.hist(db['Gender'])
plt.show()

# %%
# Plot histogram of both the Age and the Wingspan

plt.hist(db['Age'],label='Age')
plt.hist(db['Wingspan'],label='Wingspan')
plt.legend()
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"
grouped = db.groupby('Gender')
for name,data in grouped:
    plt.hist(data['Wingspan'], alpha=0.5, label=name)
plt.legend()
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "total bill" amounts
plt.boxplot(db['Age'].dropna())
plt.show()

# %%
# Create the boxplot of the "tips" amounts
plt.boxplot(db['GlassesGroup'].dropna())
plt.show()

# %%
# Create the boxplots of the "Wingspan" and of the "Height" amounts
plt.boxplot([db['Wingspan'].dropna(),db['Height'].dropna()])
plt.show()

# %%
# Create the boxplots of the "Wingspan" and of the "tips" amounts
plt.boxplot([db['Wingspan'].dropna(),db['Age'].dropna()])
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "Height" grouped by "Gender"
data = db.dropna()
grouped = data.groupby('Gender')['Height']

plt.boxplot([grouped.get_group('M'),grouped.get_group('F')],labels=['M','F'])
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "tips" grouped by "Gender"
data = db.dropna()
grouped = data.groupby('Gender')['Age']

plt.boxplot([grouped.get_group('M'),grouped.get_group('F')],labels=['M','F'])
plt.show()
plt.hist([grouped.get_group('M'),grouped.get_group('F')])
plt.show()

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
plt.scatter(data['Age'],data['Height'])
plt.show()

# %%
# scatter plot between two variables (one categorical)
plt.scatter(data['Age'],data['Glasses'])
plt.show()

# %%
# scatter plot between two variables (one categorical)
plt.scatter(data['Age'],data['Gender'])
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable
grouped = data.groupby('Gender')
for name,group in grouped:
    plt.scatter(group['Age'],group['Height'],label = name)
plt.legend()
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers
grouped = data.groupby('Glasses')
for name,group in grouped:
    plt.scatter(group['Wingspan'],group['Height'],s=group['Height']/2,label = name)
plt.legend()
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries

# %%
# url string that hosts our .csv file
url = Ruta + "datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame
columns=['sepal length in cm','sepal width in cm','petal length in cm','petal width in cm','class']
db = pd.read_csv(url, header=None, names=columns)

# %% [markdown]
# 1. Plot the histograms for each of the four quantitative variables

# %%
for col in db.columns[:4]:
    plt.hist(db[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# 2. Plot the histograms for each of the quantitative variables

# %%
for col in db.columns[:4]:
    plt.hist(db[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# 3. Plot the boxplots for each of the quantitative variables

# %%
for col in db.columns[:4]:
    plt.boxplot(db[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# 4. Plot the boxplots of the petal width grouped by type of flower

# %%
# 'sepal length in cm','sepal width in cm','petal length in cm','petal width in cm'
grouped = db.groupby('class')['petal width in cm']
plt.boxplot([grouped.get_group('Iris-setosa'),grouped.get_group('Iris-versicolor'),grouped.get_group('Iris-virginica')],labels=['Iris-setosa','Iris-versicolor','Iris-virginica'])
plt.show()

# %% [markdown]
# 5. Plot the boxplots of the setal length grouped by type of flower

# %%
grouped = db.groupby('class')['sepal length in cm']
plt.boxplot([grouped.get_group('Iris-setosa'),grouped.get_group('Iris-versicolor'),grouped.get_group('Iris-virginica')],labels=['Iris-setosa','Iris-versicolor','Iris-virginica'])
plt.show()

# %% [markdown]
# 6. Provide a description (explaination from your observations) of each of the quantitative variables
#
# - sepal length in cm: the value of the length of the sepal of a flower in cm, the smallest value is for the Iris-setosa, and the biggest is for the Iris-virginica; all values range from 4.3 to 7.9 cm, the values show no correlation between sepal length and petal width.
# - sepal width in cm: the value of the width of the sepal of a flower in cm, the smallest value is for the Iris-versicolor, and the biggest is for the Iris-setosa; all values range from 2.0 to 4.4 cm, the values show no correlation between sepal length and sepal width.
# - petal length in cm: the value of the length of the petals of a flower in cm, the smallest value is for the Iris-setosa, and the biggest is for the Iris-virginica; all values range from 1.0 to 6.9 cm, the values show a correlation between petal length and petal width.
# - petal width in cm: the value of the width of the petals of a flower in cm, the smallest value is for the Iris-setosa, and the biggest is for the Iris-virginica; all values range from 0.1 to 2.5 cm, the values show a correlation between petal length and petal width.

# %%
# code cell to experiment with data
grouped = db.groupby('class')['petal length in cm']
plt.boxplot([grouped.get_group('Iris-setosa'),grouped.get_group('Iris-versicolor'),grouped.get_group('Iris-virginica')],labels=['Iris-setosa','Iris-versicolor','Iris-virginica'])
plt.show()
print(grouped.max())
print(grouped.min())
# Out:
# class
# Iris-setosa        1.9
# Iris-versicolor    5.1
# Iris-virginica     6.9
# Name: petal length in cm, dtype: float64
# class
# Iris-setosa        1.0
# Iris-versicolor    3.0
# Iris-virginica     4.5
# Name: petal length in cm, dtype: float64
