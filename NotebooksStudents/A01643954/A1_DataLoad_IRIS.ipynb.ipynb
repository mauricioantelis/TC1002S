# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/MyDrive/NOTEBOOK/TC1002S/NotebooksStudents/A01643954/"

else:
    # Define path del proyecto
    Ruta            = ""
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd

# Dataset url
url = Ruta + "datasets/iris/iris.csv"

# Load the dataset
dataset = pd.read_csv(url )
# Print the dataset
dataset
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# Total de observaciones (filas): Hay 150 observaciones.
#
# Total de variables (columnas): Hay 6 variables/columnas.
#
# Representación de variables:
# Columna 0: id de observacion
# Columna 1: Longitud del sépalo
# Columna 2: Ancho del sépalo
# Columna 3: Longitud del pétalo
# Columna 4: Ancho del pétalo
# Columna 5: Especies (Tipo de flor)
#
# Número de observaciones para cada tipo de flor:
# Iris-setosa: Hay 50 observaciones.
# Iris-virginica: Hay 50 observaciones.
# Iris versicolor: Hay 50 observaciones.
# Tipo de datos para cada variable:
#
# Columna 0: entero mostrando ID
# Columnas 1 a 4: datos numéricos continuos osea FLOAT.
# Columna 5: String.
#
# Unidades de cada variable:
# La longitud del sépalo, el ancho del sépalo, la longitud del pétalo y el ancho del pétalo generalmente se miden en centímetros (cm).
#
# La columna de especies contiene datos categóricos que indican el tipo de flor de iris. Es una variable string.
