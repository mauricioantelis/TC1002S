# %% [markdown]
# Ana Karen Zetter Márquez
# A01627124

# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

else:
    # Define path del proyecto
    Ruta            = ""
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# url string that hosts our .csv file
file_path = '/content/drive/MyDrive/Profesional/Semestre 5/Análisis de datos/cartwheel.csv'


# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(file_path)

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df.shape
# Out:
# (52, 12)

# %%
df.describe()
# Out:
#               ID        Age  GenderGroup  GlassesGroup     Height   Wingspan  \
# count  52.000000  51.000000    52.000000     52.000000  51.000000  51.000000
# mean   26.500000  28.411765     1.500000      0.500000  68.971569  67.313725
# std    15.154757   5.755611     0.504878      0.504878   5.303812   5.624021
# min     1.000000  22.000000     1.000000      0.000000  61.500000  57.500000
# 25%    13.750000  25.000000     1.000000      0.000000  64.500000  63.000000
# 50%    26.500000  27.000000     1.500000      0.500000  69.000000  66.000000
# 75%    39.250000  30.000000     2.000000      1.000000  73.000000  72.000000
# max    52.000000  56.000000     2.000000      1.000000  79.500000  76.000000
#
#        CWDistance  CompleteGroup      Score
# count   52.000000      51.000000  52.000000
# mean    85.576923       0.843137   7.173077
# std     14.353173       0.367290   2.211566
# min     63.000000       0.000000   2.000000
# 25%     72.000000       1.000000   6.000000
# ...

# %%
df.isnull().sum()
# Out:
# ID               0
# Age              1
# Gender           0
# GenderGroup      0
# Glasses          0
# GlassesGroup     0
# Height           1
# Wingspan         1
# CWDistance       0
# Complete         0
# CompleteGroup    1
# Score            0
# dtype: int64

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.value_counts()
# Out:
# ID  Age   Gender  GenderGroup  Glasses  GlassesGroup  Height  Wingspan  CWDistance  Complete  CompleteGroup  Score
# 1   56.0  F       1            Y        1             62.00   61.0      79          Y         1.0            7        1
# 26  28.0  M       2            N        0             75.00   76.0      111         Y         1.0            10       1
# 28  25.0  M       2            Y        1             76.00   73.0      107         Y         1.0            8        1
# 29  32.0  F       1            Y        1             63.00   60.0      75          Y         1.0            8        1
# 30  38.0  F       1            Y        1             61.50   61.0      78          Y         1.0            7        1
# 31  27.0  F       1            Y        1             62.00   60.0      72          Y         1.0            8        1
# 32  33.0  F       1            Y        1             65.30   64.0      91          Y         1.0            7        1
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 26.0    7
# 27.0    7
# 24.0    5
# 28.0    5
# 23.0    5
# 30.0    4
# 25.0    4
# 33.0    3
# 39.0    2
# 29.0    2
# 31.0    2
# 38.0    2
# 56.0    1
# 22.0    1
# 32.0    1
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    26
# M    26
# Name: count, dtype: int64

# %%
df['Glasses'].value_counts()
# Out:
# Glasses
# Y    26
# N    26
# Name: count, dtype: int64

# %%
df['Height'].value_counts()
# Out:
# Height
# 61.50    4
# 65.00    4
# 62.00    3
# 64.00    3
# 73.00    3
# 75.00    3
# 66.00    3
# 71.00    3
# 68.00    2
# 70.00    2
# 69.00    2
# 63.00    2
# 69.50    2
# 62.75    1
# 73.50    1
# 77.80    1
# 79.50    1
# 78.00    1
# 72.00    1
# 72.50    1
# 67.80    1
# 70.40    1
# 77.00    1
# 65.30    1
# 76.00    1
# 78.40    1
# 74.00    1
# 74.60    1
# Name: count, dtype: int64

# %%
df['Wingspan'].value_counts()
# Out:
# Wingspan
# 66.0    5
# 63.0    4
# 75.0    4
# 71.0    4
# 72.0    4
# 60.0    4
# 64.0    3
# 76.0    3
# 61.0    2
# 74.0    2
# 59.5    2
# 73.0    2
# 64.5    2
# 62.0    2
# 70.0    2
# 68.0    1
# 67.0    1
# 58.0    1
# 69.0    1
# 57.5    1
# 71.5    1
# Name: count, dtype: int64

# %%
df['CWDistance'].value_counts()
# Out:
# CWDistance
# 72     5
# 92     4
# 85     3
# 66     3
# 79     2
# 96     2
# 82     2
# 101    2
# 90     2
# 115    2
# 74     2
# 98     2
# 107    2
# 81     2
# 87     2
# 65     1
# 78     1
# 71     1
# 99     1
# 100    1
# 86     1
# 91     1
# 67     1
# 75     1
# 111    1
# 106    1
# 63     1
# 64     1
# 70     1
# 103    1
# Name: count, dtype: int64

# %%
df['Complete'].value_counts()
# Out:
# Complete
# Y    44
# N     8
# Name: count, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 8     11
# 10     9
# 7      7
# 9      7
# 6      6
# 4      4
# 5      4
# 3      3
# 2      1
# Name: count, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
df.value_counts(normalize=True)
# Out:
# ID  Age   Gender  GenderGroup  Glasses  GlassesGroup  Height  Wingspan  CWDistance  Complete  CompleteGroup  Score
# 1   56.0  F       1            Y        1             62.00   61.0      79          Y         1.0            7        0.020408
# 26  28.0  M       2            N        0             75.00   76.0      111         Y         1.0            10       0.020408
# 28  25.0  M       2            Y        1             76.00   73.0      107         Y         1.0            8        0.020408
# 29  32.0  F       1            Y        1             63.00   60.0      75          Y         1.0            8        0.020408
# 30  38.0  F       1            Y        1             61.50   61.0      78          Y         1.0            7        0.020408
# 31  27.0  F       1            Y        1             62.00   60.0      72          Y         1.0            8        0.020408
# ...

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 26.0    0.137255
# 27.0    0.137255
# 24.0    0.098039
# 28.0    0.098039
# 23.0    0.098039
# 30.0    0.078431
# 25.0    0.078431
# 33.0    0.058824
# 39.0    0.039216
# 29.0    0.039216
# 31.0    0.039216
# 38.0    0.039216
# 56.0    0.019608
# 22.0    0.019608
# 32.0    0.019608
# Name: proportion, dtype: float64

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# F    0.5
# M    0.5
# Name: proportion, dtype: float64

# %%
df['Glasses'].value_counts(normalize=True)
# Out:
# Glasses
# Y    0.5
# N    0.5
# Name: proportion, dtype: float64

# %%
df['Height'].value_counts(normalize=True)
# Out:
# Height
# 61.50    0.078431
# 65.00    0.078431
# 62.00    0.058824
# 64.00    0.058824
# 73.00    0.058824
# 75.00    0.058824
# 66.00    0.058824
# 71.00    0.058824
# 68.00    0.039216
# 70.00    0.039216
# 69.00    0.039216
# 63.00    0.039216
# 69.50    0.039216
# 62.75    0.019608
# 73.50    0.019608
# 77.80    0.019608
# 79.50    0.019608
# 78.00    0.019608
# 72.00    0.019608
# 72.50    0.019608
# 67.80    0.019608
# 70.40    0.019608
# 77.00    0.019608
# 65.30    0.019608
# 76.00    0.019608
# 78.40    0.019608
# 74.00    0.019608
# 74.60    0.019608
# Name: proportion, dtype: float64

# %%
df['Wingspan'].value_counts(normalize=True)
# Out:
# Wingspan
# 66.0    0.098039
# 63.0    0.078431
# 75.0    0.078431
# 71.0    0.078431
# 72.0    0.078431
# 60.0    0.078431
# 64.0    0.058824
# 76.0    0.058824
# 61.0    0.039216
# 74.0    0.039216
# 59.5    0.039216
# 73.0    0.039216
# 64.5    0.039216
# 62.0    0.039216
# 70.0    0.039216
# 68.0    0.019608
# 67.0    0.019608
# 58.0    0.019608
# 69.0    0.019608
# 57.5    0.019608
# 71.5    0.019608
# Name: proportion, dtype: float64

# %%
df['CWDistance'].value_counts(normalize=True)
# Out:
# CWDistance
# 72     0.096154
# 92     0.076923
# 85     0.057692
# 66     0.057692
# 79     0.038462
# 96     0.038462
# 82     0.038462
# 101    0.038462
# 90     0.038462
# 115    0.038462
# 74     0.038462
# 98     0.038462
# 107    0.038462
# 81     0.038462
# 87     0.038462
# 65     0.019231
# 78     0.019231
# 71     0.019231
# 99     0.019231
# 100    0.019231
# 86     0.019231
# 91     0.019231
# 67     0.019231
# 75     0.019231
# 111    0.019231
# 106    0.019231
# 63     0.019231
# 64     0.019231
# 70     0.019231
# 103    0.019231
# Name: proportion, dtype: float64

# %%
df['Complete'].value_counts(normalize=True)
# Out:
# Complete
# Y    0.846154
# N    0.153846
# Name: proportion, dtype: float64

# %%
df['Score'].value_counts(normalize=True)
# Out:
# Score
# 8     0.211538
# 10    0.173077
# 7     0.134615
# 9     0.134615
# 6     0.115385
# 4     0.076923
# 5     0.076923
# 3     0.057692
# 2     0.019231
# Name: proportion, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
observations = len(df)
print(observations)

# Total number of null observations in Age
null_observations = df.Age.isnull().sum()
print(null_observations)


# Total number of counts in Age (excluding missing values)
df.Age.value_counts().sum()
# Out:
# 52
# 1
# 51

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of Age
plt.title('Age')
plt.hist(df['Age'], alpha = 0.5, color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of CWDistance
plt.title('Histogram of CWDistance')
sns.kdeplot(data=df, x='CWDistance', fill=True)
plt.xlabel('CWDistance')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of CWDistance
plt.title('Histogram of CWDistance')
plt.hist(df['CWDistance'], alpha = 0.5, color='blue')
plt.xlabel('CWDistance')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram of both the Age and the Wingspan

# Plot histogram for Age
plt.hist(df['Age'], alpha=0.5, label='Age', color='blue')

# Plot histogram for Wingspan
plt.hist(df['Wingspan'], alpha=0.5, label='Wingspan', color='purple')

# Add titles and labels
plt.title('Histogram of Age and Wingspan')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"
sns.histplot(data=df, x='Wingspan', hue='Gender', multiple='stack', alpha=0.7) #multiple = 'stack' so that F and M do not overlap
plt.title('Histogram of Wingspan by Gender')
plt.xlabel('Wingspan')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "CWDistance"
df.boxplot(column = 'CWDistance')
plt.show()

# %%
# Create the boxplot of the "Height"
df.boxplot(column = 'Height')
plt.show()

# %%
# Create the boxplots of the "CWDistance", "Height" and "Wingspan"
df.boxplot(column = ['CWDistance', 'Height', 'Wingspan'])
plt.show()

# %%
# Create the boxplots of the "CWDistance" and of the "Wingspan"
df.boxplot(column = ['CWDistance', 'Wingspan'])
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "CWDistance" grouped by "Gender"
sns.boxplot(data=df, y='CWDistance', hue='Gender', gap=.4)
# Out:
# <Axes: ylabel='CWDistance'>

# %%
# Create side-by-side boxplots of the "Glasses" grouped by "Gender"
sns.boxplot(data=df, x="Glasses", y="Height", hue="Gender")
# Out:
# <Axes: xlabel='Glasses', ylabel='Height'>

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "tips" grouped by "Gender"
sns.boxplot(data=df, x="Score", hue="Gender")
# Out:
# <Axes: xlabel='Score'>

# %%
sns.histplot(data=df, x="Score", hue="Gender", multiple='stack')
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
# scatter plot between two variables
sns.scatterplot(data=df, x='Wingspan', y='CWDistance')
# Out:
# <Axes: xlabel='Wingspan', ylabel='CWDistance'>

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='Age', y='CWDistance')
# Out:
# <Axes: xlabel='Age', ylabel='CWDistance'>

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='Glasses', y='Score')
# Out:
# <Axes: xlabel='Glasses', ylabel='Score'>

# %%
# scatter plot between two variables grouped according to a categorical variable
sns.scatterplot(data=df, x='Wingspan', y='Height', hue = 'Gender')
# Out:
# <Axes: xlabel='Wingspan', ylabel='Height'>

# %%
sns.scatterplot(data=df, x='Wingspan', y='Height', hue = 'Age')
# Out:
# <Axes: xlabel='Wingspan', ylabel='Height'>

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers
sns.scatterplot(data=df, x='Wingspan', y='Height', hue = 'Gender', size = 'Age')
# Out:
# <Axes: xlabel='Wingspan', ylabel='Height'>

# %%
# Pairplot: Scatterplot of "Age","CWDistance","Height",'Wingspan'
sns.pairplot(df, vars=["Age", "CWDistance", "Height", "Wingspan"])
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %%
# Define the col names for the iris dataset
columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']

# Dataset url
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Load the dataset
df = pd.read_csv(url, header=None, names=columns)

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.isnull().sum()
# Out:
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.value_counts()
# Out:
# SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 4.9          3.1         1.5          0.1         Iris-setosa        3
# 5.8          2.7         5.1          1.9         Iris-virginica     2
#              4.0         1.2          0.2         Iris-setosa        1
# 5.9          3.0         4.2          1.5         Iris-versicolor    1
# 6.2          3.4         5.4          2.3         Iris-virginica     1
#                                                                     ..
# 5.5          2.3         4.0          1.3         Iris-versicolor    1
#              2.4         3.7          1.0         Iris-versicolor    1
#                          3.8          1.1         Iris-versicolor    1
#              2.5         4.0          1.3         Iris-versicolor    1
# 7.9          3.8         6.4          2.0         Iris-virginica     1
# Name: count, Length: 147, dtype: int64

# %%
df['SepalLength'].value_counts()
# Out:
# SepalLength
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
df['SepalWidth'].value_counts()
# Out:
# SepalWidth
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
df['PetalLength'].value_counts()
# Out:
# PetalLength
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: count, dtype: int64

# %%
df['PetalWidth'].value_counts()
# Out:
# PetalWidth
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
df.value_counts(normalize=True)
# Out:
# SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 4.9          3.1         1.5          0.1         Iris-setosa        0.020000
# 5.8          2.7         5.1          1.9         Iris-virginica     0.013333
#              4.0         1.2          0.2         Iris-setosa        0.006667
# 5.9          3.0         4.2          1.5         Iris-versicolor    0.006667
# 6.2          3.4         5.4          2.3         Iris-virginica     0.006667
#                                                                        ...
# 5.5          2.3         4.0          1.3         Iris-versicolor    0.006667
#              2.4         3.7          1.0         Iris-versicolor    0.006667
#                          3.8          1.1         Iris-versicolor    0.006667
#              2.5         4.0          1.3         Iris-versicolor    0.006667
# 7.9          3.8         6.4          2.0         Iris-virginica     0.006667
# Name: proportion, Length: 147, dtype: float64

# %%
df['SepalLength'].value_counts(normalize=True)
# Out:
# SepalLength
# 5.0    0.066667
# 5.1    0.060000
# 6.3    0.060000
# 5.7    0.053333
# 6.7    0.053333
# 5.8    0.046667
# 5.5    0.046667
# 6.4    0.046667
# 4.9    0.040000
# 5.4    0.040000
# 6.1    0.040000
# 6.0    0.040000
# 5.6    0.040000
# 4.8    0.033333
# 6.5    0.033333
# 6.2    0.026667
# 7.7    0.026667
# 6.9    0.026667
# 4.6    0.026667
# 5.2    0.026667
# 5.9    0.020000
# 4.4    0.020000
# 7.2    0.020000
# 6.8    0.020000
# 6.6    0.013333
# 4.7    0.013333
# 7.6    0.006667
# 7.4    0.006667
# 7.3    0.006667
# 7.0    0.006667
# 7.1    0.006667
# 5.3    0.006667
# 4.3    0.006667
# 4.5    0.006667
# 7.9    0.006667
# Name: proportion, dtype: float64

# %%
df['SepalWidth'].value_counts(normalize=True)
# Out:
# SepalWidth
# 3.0    0.173333
# 2.8    0.093333
# 3.2    0.086667
# 3.1    0.080000
# 3.4    0.080000
# 2.9    0.066667
# 2.7    0.060000
# 2.5    0.053333
# 3.5    0.040000
# 3.3    0.040000
# 3.8    0.040000
# 2.6    0.033333
# 2.3    0.026667
# 3.7    0.020000
# 2.4    0.020000
# 2.2    0.020000
# 3.6    0.020000
# 3.9    0.013333
# 4.4    0.006667
# 4.0    0.006667
# 4.1    0.006667
# 4.2    0.006667
# 2.0    0.006667
# Name: proportion, dtype: float64

# %%
df['PetalLength'].value_counts(normalize=True)
# Out:
# PetalLength
# 1.5    0.093333
# 1.4    0.080000
# 5.1    0.053333
# 4.5    0.053333
# 1.6    0.046667
# 1.3    0.046667
# 5.6    0.040000
# 4.7    0.033333
# 4.9    0.033333
# 4.0    0.033333
# 4.2    0.026667
# 5.0    0.026667
# 4.4    0.026667
# 4.8    0.026667
# 1.7    0.026667
# 3.9    0.020000
# 4.6    0.020000
# 5.7    0.020000
# 4.1    0.020000
# 5.5    0.020000
# 6.1    0.020000
# 5.8    0.020000
# 3.3    0.013333
# 5.4    0.013333
# 6.7    0.013333
# 5.3    0.013333
# 5.9    0.013333
# 6.0    0.013333
# 1.2    0.013333
# 4.3    0.013333
# 1.9    0.013333
# 3.5    0.013333
# 5.2    0.013333
# 3.0    0.006667
# 1.1    0.006667
# 3.7    0.006667
# 3.8    0.006667
# 6.6    0.006667
# 6.3    0.006667
# 1.0    0.006667
# 6.9    0.006667
# 3.6    0.006667
# 6.4    0.006667
# Name: proportion, dtype: float64

# %%
df['PetalLength'].value_counts(normalize=True)
# Out:
# PetalLength
# 1.5    0.093333
# 1.4    0.080000
# 5.1    0.053333
# 4.5    0.053333
# 1.6    0.046667
# 1.3    0.046667
# 5.6    0.040000
# 4.7    0.033333
# 4.9    0.033333
# 4.0    0.033333
# 4.2    0.026667
# 5.0    0.026667
# 4.4    0.026667
# 4.8    0.026667
# 1.7    0.026667
# 3.9    0.020000
# 4.6    0.020000
# 5.7    0.020000
# 4.1    0.020000
# 5.5    0.020000
# 6.1    0.020000
# 5.8    0.020000
# 3.3    0.013333
# 5.4    0.013333
# 6.7    0.013333
# 5.3    0.013333
# 5.9    0.013333
# 6.0    0.013333
# 1.2    0.013333
# 4.3    0.013333
# 1.9    0.013333
# 3.5    0.013333
# 5.2    0.013333
# 3.0    0.006667
# 1.1    0.006667
# 3.7    0.006667
# 3.8    0.006667
# 6.6    0.006667
# 6.3    0.006667
# 1.0    0.006667
# 6.9    0.006667
# 3.6    0.006667
# 6.4    0.006667
# Name: proportion, dtype: float64

# %%
df['Species'].value_counts(normalize=True)
# Out:
# Species
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# Name: proportion, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
observations = len(df)
print(observations)

# Total number of null observations
null_observations = df.isnull().sum()
print(null_observations)


# Total number of counts
df.value_counts().sum()
# Out:
# 150
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64
# 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram
plt.title('PetalWidth')
plt.hist(df['PetalWidth'], alpha = 0.5, color='blue')
plt.xlabel('PetalWidth')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution
plt.title('Distribution of PetalWidth')
sns.kdeplot(data=df, x='PetalWidth', fill=True)
plt.xlabel('PetalWidth')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram of both

# Plot histogram for PetalLength
plt.hist(df['PetalLength'], alpha=0.5, label='Age', color='blue')

# Plot histogram for PetalWidth
plt.hist(df['PetalWidth'], alpha=0.5, label='Wingspan', color='purple')

# Add titles and labels
plt.title('Histogram of PetalLength and PetalWidth')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"
sns.histplot(data=df, x='PetalLength', hue='Species', multiple='stack', alpha=0.7)
plt.title('Histogram')
plt.xlabel('PetalLength')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "PetalLength"
df.boxplot(column = 'PetalLength')
plt.show()

# %%
# Create the boxplot of the "PetalWidth"
df.boxplot(column = 'PetalWidth')
plt.show()

# %%
# Create the boxplots of the "CWDistance", "Height" and "Wingspan"
df.boxplot(column = ['PetalLength','PetalWidth'])
plt.show()

# %%
# Create the boxplots
df.boxplot(column = ['PetalLength', 'PetalWidth'])
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "PetalLength" grouped by "Species"
sns.boxplot(data=df, y='PetalLength', hue='Species', gap=.4)
# Out:
# <Axes: ylabel='PetalLength'>

# %%
# Create side-by-side boxplots of the "PetalWidth" grouped by "Species"
sns.boxplot(data=df, y="PetalWidth", hue="Species")
# Out:
# <Axes: ylabel='PetalWidth'>

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram
sns.boxplot(data=df, x="SepalLength", hue="Species")
# Out:
# <Axes: xlabel='SepalLength'>

# %%
sns.histplot(data=df, x="SepalWidth", hue="Species", multiple='stack')
# Out:
# <Axes: xlabel='SepalWidth', ylabel='Count'>

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species'], dtype='object')

# %%
# scatter plot between two variables
sns.scatterplot(data=df, x='SepalLength', y='SepalWidth')
# Out:
# <Axes: xlabel='SepalLength', ylabel='SepalWidth'>

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='SepalLength', y='Species')
# Out:
# <Axes: xlabel='SepalLength', ylabel='Species'>

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='SepalWidth', y='Species')
# Out:
# <Axes: xlabel='SepalWidth', ylabel='Species'>

# %%
# scatter plot between two variables grouped according to a categorical variable
sns.scatterplot(data=df, x='PetalLength', y='PetalWidth', hue = 'Species')
# Out:
# <Axes: xlabel='PetalLength', ylabel='PetalWidth'>

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers
sns.scatterplot(data=df, x='PetalLength', y='PetalWidth', size = 'Species')
# Out:
# <Axes: xlabel='PetalLength', ylabel='PetalWidth'>

# %%
# Pairplot: Scatterplot of all 4 variables
sns.pairplot(df, vars=["PetalLength", "PetalWidth", "SepalLength", "SepalWidth"])
plt.show()

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %% [markdown]
# ##Histograms

# %%
# Plot histogram
plt.title('PetalLength')
plt.hist(df['PetalLength'], alpha = 0.5, color='blue')
plt.xlabel('PetalLength')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram
plt.title('PetalWidth')
plt.hist(df['PetalWidth'], alpha = 0.5, color='blue')
plt.xlabel('PetalWidth')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram
plt.title('SepalLength')
plt.hist(df['SepalLength'], alpha = 0.5, color='blue')
plt.xlabel('SepalLength')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram
plt.title('SepalWidth')
plt.hist(df['SepalWidth'], alpha = 0.5, color='blue')
plt.xlabel('SepalWidth')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram
plt.title('Species')
plt.hist(df['Species'], alpha = 0.5, color='blue')
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##Boxplots

# %%
#Plot the boxplots for each of the quantitative variables
df.boxplot(column = ['PetalLength', 'PetalWidth', 'SepalLength', 'SepalWidth'])
plt.show()

# %%
#Plot the boxplots of the petal width grouped by type of flower

# %%
sns.boxplot(data = df, x = 'PetalWidth', hue="Species")
# Out:
# <Axes: xlabel='PetalWidth'>

# %%
#Plot the boxplots of the setal length grouped by type of flower
sns.boxplot(data = df, x = 'SepalLength', hue="Species")
# Out:
# <Axes: xlabel='SepalLength'>

# %% [markdown]
# ##Description
# 1. Histograms: Sepal Length is the longest part of the flower, PetalWidth is the shortest. The Sepal seems to have a normal distribution (more frequency for the middle numbers and it reduces for the smaller and bigger numbers), while the petal appears to have a logarithmic normal distribution (more frequency for the smallest numbers and it reduces for the biggest numbers).
#
# 2. BoxPlots: PetalWidth varies the most from the mean, PetalWidth and SepalWidth vary the least. Iris Setosa has the smallest measures overall, while Iris Virginica has the largest measures overall.
