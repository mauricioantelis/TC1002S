# %%
# Define where you are running the code: colab or local
RunInColab          = False     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/Colab Notebooks/"

else:
    # Define path del proyecto
    Ruta            = ""

# %%
# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd

# Dataset url
url = Ruta + "/content/drive/MyDrive/R16/iris.csv"

# Load the dataset
dataset = pd.read_csv(url )

# %%
# Print the dataset
dataset
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# Print the number of rows
Nrows = dataset.shape[0]
Nrows
# Out:
# 149

# %%
# Print the number of columns
Ncols = dataset.shape[1]
Ncols
# Out:
# 5

# %% [markdown]
# Activity: work with the iris dataset
# Load the iris.csv file in your computer and understand the dataset
#
# How many observations (rows) are in total?
# 149
# How many variables (columns) are in total? What do they represent?
# 5
# How many observations are for each type of flower?
# 50
# What is the type of data for each variable?
# integer
# What are the units of each variable?
# cm

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (149, 5)

# %%
dataset.head()
#dataset.head(10)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
dataset.tail()
#dataset.tail(3)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
dataset.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
dataset.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
# Summary statistics for the quantitative variables
dataset.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.054362    3.773826    1.206040
# std      0.828594    0.435810    1.760543    0.760354
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
dataset.mean()
# Out:
# <ipython-input-33-e55bc0ed4499>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.mean()
# 5.1    5.848322
# 3.5    3.054362
# 1.4    3.773826
# 0.2    1.206040
# dtype: float64

# %%
dataset.min()
# Out:
# 5.1                    4.3
# 3.5                    2.0
# 1.4                    1.0
# 0.2                    0.1
# Iris-setosa    Iris-setosa
# dtype: object

# %%
dataset.max()
# Out:
# 5.1                       7.9
# 3.5                       4.4
# 1.4                       6.9
# 0.2                       2.5
# Iris-setosa    Iris-virginica
# dtype: object

# %%
dataset.median()
# Out:
# <ipython-input-36-e22d0dc743ec>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.median()
# 5.1    5.8
# 3.5    3.0
# 1.4    4.4
# 0.2    1.3
# dtype: float64

# %%
dataset.std()
# Out:
# <ipython-input-40-d926424df4d9>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.std()
# 5.1    0.828594
# 3.5    0.435810
# 1.4    1.760543
# 0.2    0.760354
# dtype: float64

# %%
dataset = dataset.rename(columns={"5.1": "Sepal Length"})
dataset = dataset.rename(columns={"3.5": "Sepal Width"})
dataset = dataset.rename(columns={"1.4": "Petal Length"})
dataset = dataset.rename(columns={"0.2": "Petal Width"})
dataset = dataset.rename(columns={"Iris-setosa": "Type"})
dataset.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Type
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
keep = ['Sepal Length', 'Sepal Width', 'Type']
dataset_sepal = dataset[keep]
dataset_sepal
# Out:
#      Sepal Length  Sepal Width            Type
# 0             4.9          3.0     Iris-setosa
# 1             4.7          3.2     Iris-setosa
# 2             4.6          3.1     Iris-setosa
# 3             5.0          3.6     Iris-setosa
# 4             5.4          3.9     Iris-setosa
# ..            ...          ...             ...
# 144           6.7          3.0  Iris-virginica
# 145           6.3          2.5  Iris-virginica
# 146           6.5          3.0  Iris-virginica
# 147           6.2          3.4  Iris-virginica
# 148           5.9          3.0  Iris-virginica
#
# [149 rows x 3 columns]

# %%
keep2 = ['Petal Length', 'Petal Width', 'Type']
dataset_petal = dataset[keep2]
dataset_petal
# Out:
#      Petal Length  Petal Width            Type
# 0             1.4          0.2     Iris-setosa
# 1             1.3          0.2     Iris-setosa
# 2             1.5          0.2     Iris-setosa
# 3             1.4          0.2     Iris-setosa
# 4             1.7          0.4     Iris-setosa
# ..            ...          ...             ...
# 144           5.2          2.3  Iris-virginica
# 145           5.0          1.9  Iris-virginica
# 146           5.2          2.0  Iris-virginica
# 147           5.4          2.3  Iris-virginica
# 148           5.1          1.8  Iris-virginica
#
# [149 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.hist(dataset['Sepal Length'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(dataset['Sepal Width'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(dataset['Petal Length'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(dataset['Petal Width'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Petal Width')
plt.xlabel('Petal Width')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataset['Sepal Length'])
plt.title('Boxplot of Sepal Length')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataset['Sepal Width'])
plt.title('Boxplot of Sepal Width')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataset['Petal Length'])
plt.title('Boxplot of Petal Length')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(dataset['Petal Width'])
plt.title('Boxplot of Petal Width')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
dataset.boxplot(column='Petal Width', by='Type', figsize=(10,6))
plt.title('Boxplot of Petal Width Grouped by Type')
plt.xlabel('Type')
plt.ylabel('Petal Width')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
dataset.boxplot(column='Sepal Length', by='Type', figsize=(10,6))
plt.title('Boxplot of Sepal Length Grouped by Type')
plt.xlabel('Type')
plt.ylabel('Sepal Length')
plt.grid(True)
plt.show()
