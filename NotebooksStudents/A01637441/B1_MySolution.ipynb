# %% [markdown]
# # TC1002S Herramientas computacionales: el arte de la analítica
#
# This is a notebook with all your work for the final evidence of this course
#
#
# # Niveles de dominio a demostrar con la evidencia
#
# ### SING0202A
#
# Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.
#
#
# # Student information
#
# - Name: Jorge Antonio Arizpe Cantú
#
# - ID: A01637441
#
# - My carreer: ITC

# %% [markdown]
# # Importing libraries

# %%
import numpy as np                  # For array
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# %% [markdown]
# # PART 1
# # Use your assigned dataset

# %% [markdown]
# ## A1 Load data

# %%
Ruta = "C:/Users/jorge/OneDrive/Documentos/Code/Python/TC1002S/NotebooksStudents/A01637441/A01637441_X.csv"


df  = pd.read_csv(Ruta)

# %% [markdown]
# ## A2 Data managment

# %% [markdown]
# Print the first 7 rows

# %%
df.head(7)
# Out:
#    Unnamed: 0         x1         x2        x3        x4        x5
# 0           0  -4.249517  10.556716  1.233942  4.235284  3.920661
# 1           1   6.527533   2.665325 -0.035845 -4.979986  7.575991
# 2           2   3.324255   7.492974 -7.745258  3.670587 -1.849463
# 3           3  -4.419054   8.159885 -3.142665  3.198455  0.048746
# 4           4  -0.857230   3.293987  7.543362 -9.459483 -3.520438
# 5           5  -0.755361   3.235644  9.894223 -8.777790 -4.344313
# 6           6  10.024861   3.967104 -8.708711  2.731514 -1.136979

# %% [markdown]
# Print the last 4 rows

# %%
df.tail(4)
# Out:
#      Unnamed: 0        x1        x2        x3        x4        x5
# 482         482 -3.554555  0.822033  6.536458 -5.393728 -2.440384
# 483         483  7.716269  5.432637 -5.872395  5.041583  0.234049
# 484         484 -6.417762  6.864554 -2.183948  3.999650 -0.027477
# 485         485  2.354443  5.786951 -5.730743  1.468249  1.695637

# %% [markdown]
# How many rows and columns are in your data?
#
# Use the `shape` method

# %%
df.shape
# Out:
# (486, 6)

# %% [markdown]
# Print the name of all columns
#
# Use the `columns` method

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'x1', 'x2', 'x3', 'x4', 'x5'], dtype='object')

# %% [markdown]
# What is the data type in each column
#
# Use the `dtypes` method

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# x1            float64
# x2            float64
# x3            float64
# x4            float64
# x5            float64
# dtype: object

# %% [markdown]
# What is the meaning of rows and columns?

# %%
# Your responses here

# 1) The rows are the amount of observations or amount of times data was recollected

# 2) The first column is the index number for each obersvation

# 3) The other 5 columns are numeric variables relating to whatever information was being collected

# %% [markdown]
# Print a statistical summary of your columns

# %%
#Dropping the index column
df = df.drop(df.columns[0] ,axis=1)

#Statistics form the dataset
print("Promedio\n", df.select_dtypes(include='number').mean(), "\n")
print("Correlacion \n", df.select_dtypes(include='number').corr(), "\n")
print("Conteo\n", df.select_dtypes(include='number').count(), "\n")
print("Maximo\n", df.select_dtypes(include='number').max(), "\n")
print("Minimo\n", df.select_dtypes(include='number').min(), "\n")
print("Mediana\n", df.select_dtypes(include='number').median(), "\n")
print("Desviacion estandar\n", df.select_dtypes(include='number').std(), "\n")
# Out:
# Promedio
#  x1    1.802128
# x2    5.171028
# x3    0.040422
# x4   -2.218749
# x5    0.220475
# dtype: float64
#
# Correlacion
#            x1        x2        x3        x4        x5
# x1  1.000000 -0.527418 -0.362810 -0.103823  0.223774
# x2 -0.527418  1.000000 -0.222665  0.506742 -0.149163
# x3 -0.362810 -0.222665  1.000000 -0.758016 -0.381915
# x4 -0.103823  0.506742 -0.758016  1.000000  0.290252
# x5  0.223774 -0.149163 -0.381915  0.290252  1.000000
#
# Conteo
#  x1    486
# x2    486
# x3    486
# x4    486
# x5    486
# dtype: int64
#
# Maximo
#  x1    14.575433
# x2    13.516253
# x3    13.597165
# x4     9.112560
# x5    10.585314
# dtype: float64
#
# Minimo
#  x1   -10.583368
# x2    -4.372049
# x3   -12.617198
# x4   -14.706142
# x5   -11.699367
# dtype: float64
#
# Mediana
#  x1    2.614639
# x2    5.322166
# x3   -0.348288
# x4   -1.434583
# x5    0.543112
# dtype: float64
#
# Desviacion estandar
#  x1    5.945913
# x2    3.312361
# x3    6.306706
# x4    5.744527
# ...

# %%
# 1) What is the minumum and maximum values of each variable
# Maximo
# x1    14.575433
# x2    13.516253
# x3    13.597165
# x4     9.112560
# x5    10.585314
# dtype: float64 

# Minimo
# x1   -10.583368
# x2    -4.372049
# x3   -12.617198
# x4   -14.706142
# x5   -11.699367

# 2) What is the mean and standar deviation of each variable
# Desviacion estandar
# x1    5.945680
# x2    3.306713
# x3    6.312984
# x4    5.742955
# x5    4.205747

# 3) What the 25%, 50% and 75% represent?
#It represents the amount of data that lands in those percentajes of the total observations.

# %% [markdown]
# Rename the columns using the same name with capital letters

# %%
df = df.rename(columns={"x1": "X1", "x2": "X2", "x3": "X3", "x4": "X4", "x5": "X5"})
df.head()
# Out:
#          X1         X2        X3        X4        X5
# 0 -4.249517  10.556716  1.233942  4.235284  3.920661
# 1  6.527533   2.665325 -0.035845 -4.979986  7.575991
# 2  3.324255   7.492974 -7.745258  3.670587 -1.849463
# 3 -4.419054   8.159885 -3.142665  3.198455  0.048746
# 4 -0.857230   3.293987  7.543362 -9.459483 -3.520438

# %% [markdown]
# Rename the columns to their original names

# %%
df = df.rename(columns={"X1": "x1", "X2": "x2", "X3": "x3", "X4": "x4", "X5": "x5"})
df.head()
# Out:
#          x1         x2        x3        x4        x5
# 0 -4.249517  10.556716  1.233942  4.235284  3.920661
# 1  6.527533   2.665325 -0.035845 -4.979986  7.575991
# 2  3.324255   7.492974 -7.745258  3.670587 -1.849463
# 3 -4.419054   8.159885 -3.142665  3.198455  0.048746
# 4 -0.857230   3.293987  7.543362 -9.459483 -3.520438

# %% [markdown]
# Use two different alternatives to get one of the columns

# %%
alternative1 = df.iloc[:, 1]

print(alternative1)

alternative2= df.loc[:, "x1"]

print(alternative2)
# Out:
# 0      10.556716
# 1       2.665325
# 2       7.492974
# 3       8.159885
# 4       3.293987
#          ...
# 481    -4.372049
# 482     0.822033
# 483     5.432637
# 484     6.864554
# 485     5.786951
# Name: x2, Length: 486, dtype: float64
# 0     -4.249517
# 1      6.527533
# 2      3.324255
# 3     -4.419054
# 4     -0.857230
#          ...
# 481    6.110860
# 482   -3.554555
# 483    7.716269
# 484   -6.417762
# 485    2.354443
# Name: x1, Length: 486, dtype: float64

# %% [markdown]
# Get a slice of your data set: second and thrid columns and rows from 62 to 72

# %%
df.loc[62:72, ["x2", "x3"]]
# Out:
#            x2         x3
# 62   7.981665  -2.818451
# 63   7.008646  -7.135958
# 64   4.301434   9.033354
# 65   4.847295   9.141280
# 66   3.197340  11.053140
# 67   3.627388   7.548356
# 68   9.204508  -7.131323
# 69   8.897831   1.361631
# 70  10.170054  -9.863150
# 71   0.574268   9.176125
# 72   8.996587   0.861852

# %% [markdown]
# For the second and thrid columns, calculate the number of null and not null values and verify that their sum equals the total number of rows

# %%
#nulls
print("Nulls")
print(df["x2"].isnull().sum())
print(df["x3"].isnull().sum())

#not nulls
print("Not nulls")
print(df["x2"].notnull().sum())
print(df["x3"].notnull().sum())

#total
print("Total")
print(df["x2"].count())
print(df["x3"].count())
# Out:
# Nulls
# 0
# 0
# Not nulls
# 486
# 486
# Total
# 486
# 486

# %% [markdown]
# Discard the last column

# %%
df.drop("x5", axis=1, inplace=True)

df.head()
# Out:
#          x1         x2        x3        x4
# 0 -4.249517  10.556716  1.233942  4.235284
# 1  6.527533   2.665325 -0.035845 -4.979986
# 2  3.324255   7.492974 -7.745258  3.670587
# 3 -4.419054   8.159885 -3.142665  3.198455
# 4 -0.857230   3.293987  7.543362 -9.459483

# %% [markdown]
# ### Questions
#
# Based on the previos results, provide a description of yout dataset
#
# Your response: Its a dataset of 5 (now 4) numeric variables that has 486 instances stored in it and its values include both negative and positive numbers.

# %% [markdown]
# ## A3 Data visualization

# %% [markdown]
# Plot in the same figure the histogram of two variables

# %%
sns.histplot(df[["x1", "x2"]])

plt.show()

# %% [markdown]
# Based on these plots, provide a description of your data:
#
# Your response here: The data of the variables x1 and x2  is centered mostly between 1 and 10, x2 is more commonly seen at the positives x1 has is seen equally on both

# %% [markdown]
# Plot in the same figure the boxplot of two variables

# %%
sns.boxplot(df[["x1", "x2"]], orient="h")
plt.show()

# %% [markdown]
# Plot the scatter plot of two variables

# %%
sns.scatterplot(df[["x1", "x2"]])
plt.show()

# %%
# Pairplot: Scatterplot of all variables
g = sns.pairplot(df, corner =True, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")
plt.show()

# %% [markdown]
# ### Questions
#
# Based on the previos plots, provide a description of yout dataset
#
# Your response: The dataset could be grouped into 4 clusters

# %% [markdown]
# ## A4 Kmeans

# %% [markdown]
# Do Kmeans clustering assuming a number of clusters accorging to your scatter plot

# %%
# Import sklearn KMeans
from sklearn.cluster import KMeans

# Define number of clusters
K  = 4

# Create/Initialize the Kmeans box/object
km = KMeans(n_clusters=K, n_init="auto")

# Do K-means clustering (assing each point in the dataset to a cluster) 
yestimated = km.fit_predict(df)

# Print estimated cluster of each point in the dataset
yestimated
# Out:
# c:\Users\jorge\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\jorge\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# array([1, 0, 2, 1, 3, 3, 2, 2, 1, 2, 3, 1, 2, 0, 2, 3, 1, 2, 2, 0, 0, 2,
#        3, 2, 1, 1, 0, 1, 2, 0, 1, 3, 0, 0, 1, 0, 3, 0, 2, 0, 1, 1, 1, 0,
#        3, 0, 3, 1, 1, 2, 2, 1, 1, 1, 0, 3, 1, 0, 0, 0, 3, 1, 1, 2, 3, 3,
#        3, 3, 2, 1, 2, 3, 1, 0, 0, 1, 0, 1, 0, 1, 1, 2, 1, 1, 3, 1, 2, 3,
# ...

# %% [markdown]
# Add to your dataset a column with the estimated cluster to each data point

# %%
# Add a new column to the dataset with the cluster information
df['yestimated'] = yestimated

df
# Out:
#            x1         x2        x3        x4  yestimated
# 0   -4.249517  10.556716  1.233942  4.235284           1
# 1    6.527533   2.665325 -0.035845 -4.979986           0
# 2    3.324255   7.492974 -7.745258  3.670587           2
# 3   -4.419054   8.159885 -3.142665  3.198455           1
# 4   -0.857230   3.293987  7.543362 -9.459483           3
# ..        ...        ...       ...       ...         ...
# 481  6.110860  -4.372049 -0.870319 -2.788369           0
# 482 -3.554555   0.822033  6.536458 -5.393728           3
# 483  7.716269   5.432637 -5.872395  5.041583           2
# 484 -6.417762   6.864554 -2.183948  3.999650           1
# 485  2.354443   5.786951 -5.730743  1.468249           2
#
# [486 rows x 5 columns]

# %% [markdown]
# Print the number associated to each cluster

# %%
# Print the Labels/Names of the existing clusters
df.yestimated.unique()
# Out:
# array([1, 0, 2, 3])

# %% [markdown]
# Print the centroids

# %%
# Cluster centroides
km.cluster_centers_
# Out:
# array([[ 8.37768634,  1.26547838, -0.33391803, -5.29385219],
#        [-5.9773461 ,  8.26827735, -0.3010827 ,  2.21301907],
#        [ 5.68250183,  6.63155345, -8.01276913,  3.53040289],
#        [-0.84210426,  4.48113579,  8.87883628, -9.40870731]])

# %% [markdown]
# Print the intertia metric

# %%
# Sum of squared error (sse) of the final model
print(km.inertia_)

# The number of iterations required to converge
km.n_iter_
# Out:
# 7907.7450090758275
# 3

# %%
#Number of points per cluster
# Get a dataframe with the data of each clsuter
df0 = df[df.yestimated==0]
df1 = df[df.yestimated==1]
df2 = df[df.yestimated==2]
df3 = df[df.yestimated==3]

# Number of points in cluster 0
NpointsCluster0 = df0.shape[0]
NpointsCluster1 = df1.shape[0]
NpointsCluster2 = df2.shape[0]
NpointsCluster3 = df3.shape[0]

# Print
print("Number of points in clusters 0: " + str(NpointsCluster0) )
print("Number of points in clusters 1: " + str(NpointsCluster1) )
print("Number of points in clusters 02: " + str(NpointsCluster2) )
print("Number of points in clusters 03: " + str(NpointsCluster3) )


# Print total number of points
print("Total Number of points in the clusters: " + str(NpointsCluster0+NpointsCluster1+NpointsCluster2) )
# Out:
# Number of points in clusters 0: 121
# Number of points in clusters 1: 122
# Number of points in clusters 02: 122
# Number of points in clusters 03: 121
# Total Number of points in the clusters: 365

# %% [markdown]
# Plot a scatter plot of your data using different color for each cluster. Also plot the centroids

# %%
# Scatter plot of each cluster
plt.scatter(df0.x1, df0.x2, label='Cluster 0', c='r', marker='o', s=32, alpha=0.3)
plt.scatter(df1.x1, df1.x2, label='Cluster 1', c='g', marker='o', s=32, alpha=0.3)
plt.scatter(df2.x1, df2.x2, label='Cluster 2', c='b', marker='o', s=32, alpha=0.3)
plt.scatter(df3.x1, df3.x2, label='Cluster 3', c='y', marker='o', s=32, alpha=0.3)


# Plot centrodides
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color='black', marker='*', label='Centroides', s=256)

plt.title('Scatter plot (for each cluster)')
plt.xlabel('x1')
plt.ylabel('x3')
plt.show()

# %% [markdown]
# ### Questions
#
# Provides a detailed description of your results
#
# Your response: We can clearly see the points clustering around the 4 centroids that were defined.

# %% [markdown]
# ## A5 Elbow plot
#
# Compute the Elbow plot

# %%
# Intialize a list to hold sum of squared error (sse)
sse = []

# Define values of k
k_rng = range(1,10)

# For each k
for k in k_rng:
    # Create model
    km = KMeans(n_clusters=k, n_init="auto")
    # Do K-means clustering
    km.fit_predict(df[['x1','x2']])
    # Save sse for each k
    sse.append(km.inertia_)

# %%
# Plot sse versus k
plt.plot(k_rng,sse, 'o-', markersize=8)

plt.title('Elbow plot')
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.show()

# %% [markdown]
# ### Questions
#
# What is the best number of clusters K? (argue your response)
#
# Your response: 4 is the best any more doesnt see a susbtancial increase thats worth the extra iterations
#
#
# Does this number of clusters agree with your inital guess? (argue your response, no problem at all if they do not agree)
#
# Your response: Yes the numbers match because the initial number was chosen based off of the scatter plots.

# %% [markdown]
# # PART 2
# # Descipcion de tu percepcion del nivel de desarrollo de la subcompetencia
#
# ### SING0202A Interpretación de variables

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Interpreta interacciones**. Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo.

# %% [markdown]
# Tu respuesta: Gracias a este curso he sido capaz de desarrollar mis habilidades de pensamiento critico y analisis de datos lo que me ha permitido poder ver las relaciones entre las variables y construir modelos en base a estos para la visulizacion de los datos que permita una facil interpretacion.

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Construcción de modelos**. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.

# %% [markdown]
# Tu respuesta: Soy capaz de crear modelos y clusterizar datos que me permite la clasificacion y analisis de un dado fenomeno para explicar el comportamiento de este cosa que facilta su reproduccion o entendimiento.
