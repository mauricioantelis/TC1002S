# %%
# Define where you are running the code: colab or local
RunInColab = True  # (False: no  | True: yes)
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

    # Define path to the folder containing the dataset
    Ruta = "/content/drive/My Drive/TC1002S/NotebooksProfessor/datasets/cartwheel/"
else:
    # Define path del proyecto
    Ruta = ""

# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd

# Dataset file name
file_name = "cartwheel.csv"

# Complete file path
file_path = Ruta + file_name

# Load the dataset
try:
    dataset = pd.read_csv(file_path)
    print(dataset)

    # Print the number of rows
    Nrows = dataset.shape[0]
    print("Number of rows:", Nrows)

    # Print the number of columns
    Ncols = dataset.shape[1]
    print("Number of columns:", Ncols)

except FileNotFoundError:
    print("File not found. Please check the file path.")
# Out:
# Mounted at /content/drive
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# ...

# %% [markdown]
# # **Activity: work with the iris dataset**
#
# Load the iris.csv file in your computer and understand the dataset
#
# How many observations (rows) are in total?
#
# How many variables (columns) are in total? What do they represent?
#
# How many observations are for each type of flower?
#
# What is the type of data for each variable?
#
# What are the units of each variable?

# %% [markdown]
# 1.

# %%
# Define where you are running the code: colab or local
RunInColab = True  # (False: no  | True: yes)
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

    # Define path to the folder containing the dataset
    Ruta = "/content/drive/My Drive/TC1002S/NotebooksProfessor/datasets/iris/"
else:
    # Define path del proyecto
    Ruta = ""

# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd

# Dataset file name
file_name = "iris.csv"

# Complete file path
url = Ruta + file_name
df = pd.read_csv(url)

# Load the dataset
df
# Out:
# Mounted at /content/drive
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width     Flower_Name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.

# %%
# Print the number of rows
Nrows = dataset.shape[0]
print("Number of rows:", Nrows)
# Out:
# Number of rows: 52

# %% [markdown]
# 3.

# %%
 # Print the number of columns
Ncols = dataset.shape[1]
print("Number of columns:", Ncols)
# Out:
# Number of columns: 12

# %% [markdown]
# 4.
#
# There are 4 observations for the flowers, the sepal length, sepal width, petal length and petal width, the flower name can also be considered one of the flower observations.

# %%
df.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Flower_Name'],
#       dtype='object')

# %% [markdown]
# 5.

# %%
df.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Flower_Name      object
# dtype: object

# %% [markdown]
# 6.
#
# For all variables, the sepal length, sepal width, petal length, petal width will be different but for the flower names it will either be one of three types.
#
# Iris-setosa
#
# Iris-versicolor
#
# Iris-virginica
