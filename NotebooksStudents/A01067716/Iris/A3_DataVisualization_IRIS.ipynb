# %% [markdown]
# #**A3 IRIS**
#
#
#   **Nombre:** Ana Karen Valencia Villaseñor
#
#   **Matrícula:** A01067716
#
#
#   **Fecha:** 10 de septiembre de 2024
#
#
#
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/MyDrive/TC1002S"

else:
    # Define path del proyecto
    Ruta            = ""
# Out:
# Mounted at /content/drive

# %%
# url string that hosts our .csv file
url= "/datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame

df = pd.read_csv(Ruta + url)

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  sepal.length  sepal.width  petal.length  \
# 0             0           0           5.1          3.5           1.4
# 1             1           1           4.9          3.0           1.4
# 2             2           2           4.7          3.2           1.3
# 3             3           3           4.6          3.1           1.5
# 4             4           4           5.0          3.6           1.4
#
#    petal.width variety
# 0          0.2  Setosa
# 1          0.2  Setosa
# 2          0.2  Setosa
# 3          0.2  Setosa
# 4          0.2  Setosa

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df=df.rename(columns={"petal.width":"petal_width"})
df=df.rename(columns={"petal.length":"petal_length"})
df=df.rename(columns={"sepal.width":"sepal_width"})
df=df.rename(columns={"sepal.length":"sepal_length"})
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'sepal_length', 'sepal_width',
#        'petal_length', 'petal_width', 'variety'],
#       dtype='object')

# %%
df.sepal_length.value_counts()
# Out:
# sepal_length
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x= df.sepal_length.value_counts()
x=100*x/x.sum()

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations

print("Total de numero de observaciones  "+ str(df.shape[0]))

# Total number of null observations
print("Total numeber of null observations in type:" + str(df.variety.isnull().sum()))

# Total number of counts (excluding missing values)

print("Total number exluding missing values: " + str(df.variety.notnull().sum()))
# Out:
# Total de numero de observaciones  150
# Total numeber of null observations in type:0
# Total number exluding missing values: 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of
sns.distplot(df.petal_width)
plt.show()
# Out:
# <ipython-input-15-15a1cdac7b96>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.petal_width)

# %%
#Plot histogram of "petal_width"
var2plot= df['petal_width']
sns.histplot(data=var2plot,kde=True)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma variable petal_width')
plt.show()

# %%
# Plot distribution  petal_length
var2plot= df['petal_length']
sns.histplot(data=var2plot,kde=True)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma variable petal_length')
plt.show()

# %%
# Plot distribution  sepal_length
var2plot= df['sepal_length']
sns.histplot(data=var2plot,kde=True)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma variable sepal_length')
plt.show()

# %%
# Plot distribution  sepal_width
var2plot= df['sepal_width']
sns.histplot(data=var2plot,kde=True)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma variable sepal_width')
plt.show()

# %%
# Plot histogram of both petal and sepal width
var1= df['petal_width']
var2= df['sepal_width']

sns.histplot(data=df, x=var1, y=var2)
plt.xlabel('Var 1')
plt.ylabel('Var 2')
plt.title('Histograma dos valores ')
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "variety"

sns.histplot(data=df, x='petal_width', hue='variety')
plt.xlabel('petal_width')
plt.ylabel('Frecuencia')
plt.title('Histograma agrupado por variety')
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "petal width"

sns.boxplot(data=df,y='petal_width')
plt.ylabel('FreC')
plt.title('Boxplot petal width')
plt.show()

# %%
# Create the boxplot of the "petal length"

sns.boxplot(data=df,y='petal_length')
plt.ylabel('FreC')
plt.title('Boxplot petal length')
plt.show()

# %%
# Create the boxplot of the "sepal width"

sns.boxplot(data=df,y='sepal_width')
plt.ylabel('FreC')
plt.title('Boxplot sepal width')
plt.show()

# %%
# Create the boxplot of the "sepal length"

sns.boxplot(data=df,y='sepal_length')
plt.ylabel('FreC')
plt.title('Boxplot sepal_length')
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.
#
# Plot the boxplots of the petal width grouped by type of flower
#
#
# Plot the boxplots of the setal length grouped by type of flower

# %%
#


sns.boxplot(data=df,x= 'petal_width', hue='variety', orient='v')
plt.xlabel('petal_width')
plt.ylabel('Frecuencia')
plt.title('Agrupado por variety')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.boxplot(data=df,x= 'sepal_length', hue='variety', orient='v')
plt.xlabel('sepal_length')
plt.ylabel('Frecuencia')
plt.title('Agrupado por variety')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "CWDistance" grouped by "Gender"

plt.figure(figsize=(10, 6))  # Ajustar el tamaño de la figura
sns.boxplot(x="Gender", y="CWDistance", data=df)
plt.title('Boxplot of CWDistance by Gender')
plt.show()

# Crear histogramas de "CWDistance" para cada "Gender"
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="CWDistance", hue="Gender", multiple="stack", bins=15)
plt.title('Histogram of CWDistance by Gender')
plt.show()

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
sns.scatterplot(data=df,x='petal_length',y='petal_width', s=80, alpha=0.75)
plt.show()

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df,x='variety',y='petal_width', s=80, alpha=0.75)
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables
