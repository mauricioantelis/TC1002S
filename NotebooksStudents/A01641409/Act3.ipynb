# %%
# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Dataset url
url = "/Users/estebanm/Documents/SemanaTec/TC1002S/NotebooksProfessor/datasets/iris/iris.csv"

# Ingresar nombre a columnas
names = ['SEPAL_LENGTH', 'SEPAL_WIDTH', 'PETAL_LENGTH', 'PETAL_WIDTH', 'CLASS']

# Load the dataset
dataset = pd.read_csv(url, names=names)
dataset
# Out:
#      SEPAL_LENGTH  SEPAL_WIDTH  PETAL_LENGTH  PETAL_WIDTH           CLASS
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# General feel of data

dataset.describe
# Out:
# <bound method NDFrame.describe of      SEPAL_LENGTH  SEPAL_WIDTH  PETAL_LENGTH  PETAL_WIDTH           CLASS
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
# Number of times that each distinct value of a variable occurs in a data set

dataset.SEPAL_LENGTH.value_counts()
#dataset.SEPAL_WIDTH.value_counts()
#dataset.PETAL_LENGTH.value_counts()
#dataset.PETAL_WIDTH.value_counts()
# Out:
# SEPAL_LENGTH
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set

print('NUMERO DE OBSERVACIONES', dataset.shape[0])
# Out:
# NUMERO DE OBSERVACIONES 150

# %%
# Total number of observations
print('Numero de observaciones: ', dataset.shape[0])

# Total number of null observations
print('Numero de observaciones Nulas: ', dataset.isnull().sum())

# Total number of counts (excluding missing values)
print('Numero de observaciones Nulas: ', dataset.notnull().sum())
# Out:
# Numero de observaciones:  150
# Numero de observaciones Nulas:  SEPAL_LENGTH    0
# SEPAL_WIDTH     0
# PETAL_LENGTH    0
# PETAL_WIDTH     0
# CLASS           0
# dtype: int64
# Numero de observaciones Nulas:  SEPAL_LENGTH    150
# SEPAL_WIDTH     150
# PETAL_LENGTH    150
# PETAL_WIDTH     150
# CLASS           150
# dtype: int64

# %%
# Plot the histograms for each of the four quantitative variables

# Histogram SEPAL_LENGTH
sns.histplot(data=dataset, x='SEPAL_LENGTH', color='blue', kde=True)
plt.title('Histograma de SEPAL_LENGTH')
plt.xlabel('SEPAL_LENGTH')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Histogram SEPAL_WIDTH
sns.histplot(data=dataset, x='SEPAL_WIDTH', color='green', kde=True)
plt.title('Histograma de SEPAL_WIDTH')
plt.xlabel('SEPAL_WIDTH')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Histogram PETAL_LENGTH
sns.histplot(data=dataset, x='PETAL_LENGTH', color='red', kde=True)
plt.title('Histograma de PETAL_LENGTH')
plt.xlabel('PETAL_LENGTH')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Histogram PETAL_WIDTH
sns.histplot(data=dataset, x='PETAL_WIDTH', color='orange', kde=True)
plt.title('Histograma de PETAL_WIDTH')
plt.xlabel('PETAL_WIDTH')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot the boxplots for each of the quantitative variables
# Boxplot SEPAL_LENGTH
sns.boxplot(data=dataset['SEPAL_LENGTH'], color='blue')
plt.title('Boxplot de SEPAL_LENGTH')
plt.xlabel('SEPAL_LENGTH')
plt.show()

# %%
# Boxplot SEPAL_WIDTH

sns.boxplot(data=dataset['SEPAL_WIDTH'], color='green')
plt.title('Boxplot de SEPAL_WIDTH')
plt.xlabel('SEPAL_WIDTH')
plt.show()

# %%
# Boxplot PETAL_LENGTH

sns.boxplot(data=dataset['PETAL_LENGTH'], color='red')
plt.title('Boxplot de PETAL_LENGTH')
plt.xlabel('PETAL_LENGTH')
plt.show()

# %%
# Boxplot PETAL_WIDTH

sns.boxplot(data=dataset['PETAL_WIDTH'], color='orange')
plt.title('Boxplot de PETAL_WIDTH')
plt.xlabel('PETAL_WIDTH')
plt.show()

# %%
# Boxplots of the petal width grouped by type of flower

sns.boxplot(data=dataset, x='CLASS', y='PETAL_WIDTH', palette='Set2')
plt.title('Boxplots del Ancho del Pétalo por Tipo de Flor')
plt.xlabel('Tipo de Flor')
plt.ylabel('Ancho del Pétalo')
plt.show()

# %%
# Boxplots of the setal length grouped by type of flower
sns.boxplot(data=dataset, x='CLASS', y='SEPAL_LENGTH', palette='Set2')
plt.title('Boxplots del Largo del Sépalo por Tipo de Flor')
plt.xlabel('Tipo de Flor')
plt.ylabel('Largo del Sépalo')
plt.show()
