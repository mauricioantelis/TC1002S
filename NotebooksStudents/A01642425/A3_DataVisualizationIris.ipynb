# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load the dataset
df = sns.load_dataset('iris')

# %% [markdown]
# # Importing data

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set

df.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 5.8           2.7          5.1           1.9          virginica     2
# 6.2           2.2          4.5           1.5          versicolor    1
#               2.9          4.3           1.3          versicolor    1
#               3.4          5.4           2.3          virginica     1
# 6.3           2.3          4.4           1.3          versicolor    1
#                                                                    ..
# 5.4           3.9          1.3           0.4          setosa        1
#                            1.7           0.4          setosa        1
# 5.5           2.3          4.0           1.3          versicolor    1
#               2.4          3.7           1.0          versicolor    1
# 7.9           3.8          6.4           2.0          virginica     1
# Name: count, Length: 149, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
df.value_counts(normalize=True)
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 5.8           2.7          5.1           1.9          virginica     0.013333
# 6.2           2.2          4.5           1.5          versicolor    0.006667
#               2.9          4.3           1.3          versicolor    0.006667
#               3.4          5.4           2.3          virginica     0.006667
# 6.3           2.3          4.4           1.3          versicolor    0.006667
#                                                                       ...
# 5.4           3.9          1.3           0.4          setosa        0.006667
#                            1.7           0.4          setosa        0.006667
# 5.5           2.3          4.0           1.3          versicolor    0.006667
#               2.4          3.7           1.0          versicolor    0.006667
# 7.9           3.8          6.4           2.0          virginica     0.006667
# Name: proportion, Length: 149, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
print(df.shape[0])


# Total number of null observations
print(df.isnull().sum().sum())


# Total number of counts (excluding missing values)
print(df.count().sum())
# Out:
# 150
# 0
# 750

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of both the Sepal length and the Sepal width
plt.hist(df['sepal_length'].dropna(), bins=30, edgecolor='black')
plt.title('Histogram of Sepal')
plt.xlabel('sepal')
plt.ylabel('lenght')
plt.grid(True)
plt.show()

# Plot histogram of both the Sepal length and the Sepal width
plt.hist(df['sepal_width'].dropna(), bins=30, edgecolor='black')
plt.title('Histogram of Sepal')
plt.xlabel('sepal')
plt.ylabel('width')
plt.grid(True)
plt.show()

# Plot histogram of both the Age and the Wingspan
sns.histplot(data=df, x="sepal_length", y="sepal_width", cmap="Blues", binwidth=(1, 1))
plt.title('2D Histogram of length and width')
plt.xlabel('length')
plt.ylabel('wisth')
plt.grid(True)
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the petal "length" grouped by "width"

sns.histplot(data=df, x="petal_length", hue = "petal_width" )
plt.title('Histogram of length Grouped by width')
plt.xlabel('length')
plt.ylabel('width')
plt.legend(title='width')
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplots of the "Wingspan" and of the "Height" amounts
sns.boxplot(y=df['sepal_length'])
plt.title('Boxplot of petal length (cm)')
plt.xlabel('petal length (cm)')
plt.tight_layout()
plt.show()
# Create the boxplots of the "Wingspan" and of the "Height" amounts
sns.boxplot(y=df['sepal_length'])
plt.title('Boxplot of sepal length (cm)')
plt.xlabel('sepal length (cm)')
plt.tight_layout()
plt.show()

# Create the boxplots of the "Wingspan" and of the "Height" amounts
sns.boxplot(data=df[['sepal_length', "petal_length"]])
plt.title('Boxplot of 2')
plt.ylabel('Valor')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "Height" grouped by "Gender"

sns.boxplot(data=df, x='sepal_width', y='species', palette="Set1")

plt.title('Boxplot of sepal width Grouped by species')
plt.xlabel('petal')
plt.ylabel('species')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-7f99a20d539d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='sepal_width', y='species', palette="Set1")

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "Wingspan" grouped by "Gender"
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='species', y='sepal_length', palette="Set1")
plt.title('Boxplot of sepal length Grouped by species')
plt.xlabel('species')
plt.ylabel('length')
plt.subplot(1, 2, 2)
sns.histplot(data=df, x='sepal_length', hue='species', multiple='stack', palette="Set1", bins=30)
plt.title('Histogram of sepal length Grouped by species')
plt.xlabel('sepal length')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-2e60d9823b1c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y='sepal_length', palette="Set1")

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
sns.scatterplot(data=df, x='petal_length', y='petal_width', palette='Set1')

plt.title('Scatter Plot between petals')
plt.xlabel('length')
plt.ylabel('width')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-33-4dd4e3524361>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='petal_length', y='petal_width', palette='Set1')

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='petal_length', y='species', palette='Set1')

plt.title('Scatter Plot of Age vs. Wingspan by Gender')
plt.xlabel('length')
plt.ylabel('species')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-34-4a3435dfccab>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='petal_length', y='species', palette='Set1')

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x='sepal_length', y='species', palette='Set1')

plt.title('Scatter Plot of pedal')
plt.xlabel('species')
plt.ylabel('lenght')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-35-a84c0dc1d1bd>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='sepal_length', y='species', palette='Set1')

# %%
# scatter plot between two variables grouped according to a categorical variable

sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species', palette='Set1')

plt.title('Scatter Plot of pedal')
plt.xlabel('length')
plt.ylabel('width')
plt.legend(title='Species')
plt.grid(True)
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers

sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species', size='sepal_width', sizes=(20, 200))

plt.title('Scatter Plot of pedal')
plt.xlabel('Age')
plt.ylabel('length')
plt.legend(title='width')
plt.grid(True)
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %%
#1 hecho
#2 hecho tambien
#3
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.iloc[:, :-1])  # Exclude the species column (non-numeric)
plt.title('Boxplots for Quantitative Variables in the Iris Dataset')
plt.xlabel('Quantitative Variables')
plt.ylabel('Values')
plt.tight_layout()
plt.show()

#4
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='petal_width', data=df)
plt.title('Boxplot of Petal Width Grouped by Type of Flower')
plt.xlabel('Type of Flower')
plt.ylabel('Petal Width')
plt.tight_layout()
plt.show()

#5
plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Boxplot of Sepal Length Grouped by Type of Flower')
plt.xlabel('Type of Flower')
plt.ylabel('Sepal Length')
plt.tight_layout()
plt.show()

#6
#La setosa es la mas chica, la versicolor es mediana y despues la la virginica que es la mas grande
