# %% [markdown]
# # TC1002S Herramientas computacionales: el arte de la analítica
#
# This is a notebook with all your work for the final evidence of this course
#
#
# # Niveles de dominio a demostrar con la evidencia
#
# ### SING0202A
#
# Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.
#
#
# # Student information
#
# - Name: José Benjamín Ortiz Badillo
#
# - ID: A01277673
#
# - My carreer: ITC (Ingeniería en Tecnologías Computacionales)

# %% [markdown]
# # Importing libraries

# %%
#Import
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# # PART 1
# # Use your assigned dataset

# %% [markdown]
# ## A1 Load data

# %%
#Loading data
df = pd.read_csv("./A01277673_X.csv")
df.drop("Unnamed: 0", axis = 1, inplace = True)

# %% [markdown]
# ## A2 Data managment

# %% [markdown]
# Print the first 7 rows

# %%
print(df.head(7))
# Out:
#          x1         x2        x3         x4        x5        x6        x7  \
# 0 -6.776811  -7.663741 -1.937139   5.619535  1.957212  4.065625 -0.505045
# 1 -0.591086   8.237555  3.693422 -10.431475 -0.396667  9.181452  9.057534
# 2  1.231533 -11.428369  4.311638  -5.496241  2.297575  8.175036  4.045665
# 3 -3.450509  -3.693726 -2.790534   0.053492 -1.698626  7.694596 -3.803988
# 4  3.368960  -8.293089  4.816668  -4.750761 -3.995433  8.282782  6.214604
# 5 -0.818073  -8.606082  1.622451  -7.284514  4.228764  7.842585  7.642872
# 6 -6.392977  -4.594642 -4.318249   5.295772 -2.646878  4.206607 -1.436790
#
#          x8         x9       x10       x11       x12       x13       x14  \
# 0  6.784833 -10.514162 -3.780633  7.805881 -1.560728 -3.963353 -6.656145
# 1  3.090578   0.300064 -8.716877  0.056892 -0.532461 -4.362457  9.142519
# 2 -9.307296  -0.483197 -3.311644 -8.442872 -8.590588  3.147026 -2.639428
# 3  9.843115  -3.609249 -8.282603  5.401969  0.244423  2.821752 -5.644745
# ...

# %% [markdown]
# Print the last 4 rows

# %%
print(df.tail(4))
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 764 -0.756570 -7.356031  5.465383 -8.700241  4.968072  8.430109  7.668838
# 765 -6.064186 -5.102107 -6.418646  2.982486 -3.281475  6.433182  2.536931
# 766  0.444943 -7.948488  4.910132 -4.967525  0.452647  5.470175  6.302910
# 767 -6.303726 -5.846985 -3.209190  3.093402  0.113342  5.773011 -3.445035
#
#            x8         x9       x10        x11       x12       x13       x14  \
# 764 -4.188009  -1.200924 -7.556168  -9.832685 -4.227110 -1.871427 -3.200114
# 765  8.468002 -11.754423 -5.616742   7.082580 -0.790479 -0.135347 -6.111794
# 766 -4.122467  -3.744146 -7.275751 -12.364598 -9.691291 -1.554594 -2.261653
# 767  5.155029  -9.818993 -5.953177   6.929385 -0.871282 -2.573017 -3.759188
#
#           x15
# 764  3.764081
# 765  0.507334
# 766  3.508055
# 767 -5.726389

# %% [markdown]
# How many rows and columns are in your data?
#
# Use the `shape` method

# %%
print("The number of rows is: ", df.shape[0])
print("The number of columns is: ", df.shape[1])
# Out:
# The number of rows is:  768
# The number of columns is:  15

# %% [markdown]
# Print the name of all columns
#
# Use the `columns` method

# %%
print(df.columns)
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11',
#        'x12', 'x13', 'x14', 'x15'],
#       dtype='object')

# %% [markdown]
# What is the data type in each column
#
# Use the `dtypes` method

# %%
print(df.dtypes)
# Out:
# x1     float64
# x2     float64
# x3     float64
# x4     float64
# x5     float64
# x6     float64
# x7     float64
# x8     float64
# x9     float64
# x10    float64
# x11    float64
# x12    float64
# x13    float64
# x14    float64
# x15    float64
# dtype: object

# %% [markdown]
# What is the meaning of rows and columns?

# %%
# Your responses here

# 1) The rows are the number of entries available in the dataset, each one contains a value for each of the columns.

# 2) The columns represent the values for each entry. There are 15 values for each of the 700+ entries.

# %% [markdown]
# Print a statistical summary of your columns

# %%
print(df.describe())
# Out:
#                x1          x2          x3          x4          x5          x6  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean    -2.132003   -1.613523    1.369154   -4.159767    0.392219    6.842217
# std      3.598241    7.201286    4.386789    6.013919    2.412882    2.279089
# min    -11.704958  -12.833417  -10.188844  -16.024173   -7.256697    0.380758
# 25%     -4.939928   -7.114019   -2.621688   -8.826639   -1.278914    5.275247
# 50%     -1.713110   -5.134686    2.718960   -6.002293    0.359121    6.904773
# 75%      0.529352    6.800059    4.631055    2.040105    2.070506    8.401969
# max      7.225738   13.998421   11.264586   11.227618    8.098515   13.093835
#
#                x7          x8          x9         x10         x11         x12  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.512441    2.885956   -2.718962   -6.869457    0.130437   -3.165186
# ...

# %%
# 1) What is the minumum and maximum values of each variable
min_values = df.min()
max_values = df.max()

print("Minimum values for each column:")
print(min_values)

print("\nMaximum values for each column:")
print(max_values)

# 2) What is the mean and standard deviation of each variable
mean_values = df.mean()
std_values = df.std()
print("Mean values for each column:")
print(mean_values)
print("Standard deviation for each column:")
print(std_values)

# 3) What the 25%, 50% and 75% represent?
    # They represent the Quartiles, they represent a value which N% of the data falls under. For example:
    # the value of 25% at x1 is equal to -4.93, meaning 25% of the data falls under this number.
    # The 50% represents the median, it is the middle value of the data, meaning 50% of the data falls below this value.
    # This is the value below which 75% of the data falls. It represents the upper quartile.
# Out:
# Minimum values for each column:
# x1    -11.704958
# x2    -12.833417
# x3    -10.188844
# x4    -16.024173
# x5     -7.256697
# x6      0.380758
# x7     -6.926737
# x8    -10.275614
# x9    -13.965875
# x10   -13.323359
# x11   -14.797663
# x12   -12.883867
# x13   -11.999520
# x14   -11.323385
# x15    -6.592810
# dtype: float64
#
# Maximum values for each column:
# x1      7.225738
# x2     13.998421
# x3     11.264586
# x4     11.227618
# x5      8.098515
# x6     13.093835
# x7     14.480834
# x8     15.447707
# x9      6.899261
# x10    -0.044638
# x11    13.152284
# x12     4.346056
# x13     5.615190
# x14    13.975849
# x15     9.896681
# dtype: float64
# Mean values for each column:
# x1    -2.132003
# x2    -1.613523
# x3     1.369154
# x4    -4.159767
# x5     0.392219
# x6     6.842217
# x7     3.512441
# x8     2.885956
# x9    -2.718962
# x10   -6.869457
# x11    0.130437
# x12   -3.165186
# x13   -2.241163
# x14   -0.214097
# x15    0.718774
# dtype: float64
# ...

# %% [markdown]
# Rename the columns using the same name with capital letters

# %%
df.columns = df.columns.str.replace('x', 'X')
print(df.head(5))
# Out:
#          X1         X2        X3         X4        X5        X6        X7  \
# 0 -6.776811  -7.663741 -1.937139   5.619535  1.957212  4.065625 -0.505045
# 1 -0.591086   8.237555  3.693422 -10.431475 -0.396667  9.181452  9.057534
# 2  1.231533 -11.428369  4.311638  -5.496241  2.297575  8.175036  4.045665
# 3 -3.450509  -3.693726 -2.790534   0.053492 -1.698626  7.694596 -3.803988
# 4  3.368960  -8.293089  4.816668  -4.750761 -3.995433  8.282782  6.214604
#
#          X8         X9       X10       X11       X12       X13       X14  \
# 0  6.784833 -10.514162 -3.780633  7.805881 -1.560728 -3.963353 -6.656145
# 1  3.090578   0.300064 -8.716877  0.056892 -0.532461 -4.362457  9.142519
# 2 -9.307296  -0.483197 -3.311644 -8.442872 -8.590588  3.147026 -2.639428
# 3  9.843115  -3.609249 -8.282603  5.401969  0.244423  2.821752 -5.644745
# 4 -3.075604   1.194046 -9.231290 -7.806242 -7.038902  2.527122 -2.204882
#
#         X15
# 0 -2.873712
# 1 -1.979015
# 2  2.264783
# 3 -3.193528
# 4 -0.177768

# %% [markdown]
# Rename the columns to their original names

# %%
df.columns = df.columns.str.replace('X', 'x')
print(df.head(5))
# Out:
#          x1         x2        x3         x4        x5        x6        x7  \
# 0 -6.776811  -7.663741 -1.937139   5.619535  1.957212  4.065625 -0.505045
# 1 -0.591086   8.237555  3.693422 -10.431475 -0.396667  9.181452  9.057534
# 2  1.231533 -11.428369  4.311638  -5.496241  2.297575  8.175036  4.045665
# 3 -3.450509  -3.693726 -2.790534   0.053492 -1.698626  7.694596 -3.803988
# 4  3.368960  -8.293089  4.816668  -4.750761 -3.995433  8.282782  6.214604
#
#          x8         x9       x10       x11       x12       x13       x14  \
# 0  6.784833 -10.514162 -3.780633  7.805881 -1.560728 -3.963353 -6.656145
# 1  3.090578   0.300064 -8.716877  0.056892 -0.532461 -4.362457  9.142519
# 2 -9.307296  -0.483197 -3.311644 -8.442872 -8.590588  3.147026 -2.639428
# 3  9.843115  -3.609249 -8.282603  5.401969  0.244423  2.821752 -5.644745
# 4 -3.075604   1.194046 -9.231290 -7.806242 -7.038902  2.527122 -2.204882
#
#         x15
# 0 -2.873712
# 1 -1.979015
# 2  2.264783
# 3 -3.193528
# 4 -0.177768

# %% [markdown]
# Use two different alternatives to get one of the columns

# %%
# First method
print(df.iloc[:, 5].head(6))

print("------------")

#Second method
print(df['x1'].head(6))
# Out:
# 0    4.065625
# 1    9.181452
# 2    8.175036
# 3    7.694596
# 4    8.282782
# 5    7.842585
# Name: x6, dtype: float64
# ------------
# 0   -6.776811
# 1   -0.591086
# 2    1.231533
# 3   -3.450509
# 4    3.368960
# 5   -0.818073
# Name: x1, dtype: float64

# %% [markdown]
# Get a slice of your data set: second and thrid columns and rows from 62 to 72

# %%
print(df.iloc[62:73, [2,3]])
# Out:
#           x3         x4
# 62  3.760375  -9.772241
# 63  5.537267 -10.800048
# 64 -3.743871   3.285142
# 65 -4.358615   2.297181
# 66  2.357983  -4.245790
# 67  0.603503  -6.306857
# 68  4.308994  -6.191737
# 69  3.836327  -3.689766
# 70 -2.807376   1.893894
# 71  4.992125 -11.176185
# 72 -6.274480   3.257300

# %% [markdown]
# For the second and thrid columns, calculate the number of null and not null values and verify that their sum equals the total number of rows

# %%
numberOfNull = df.iloc[:, [2,3]].isnull().sum().sum()
# We divide the number of not null rows over 2 because we are analyzing 2 columns.
numberOfNotNull = df.iloc[:, [2,3]].notnull().sum().sum()//2

numberOfDataAvailable = numberOfNull + numberOfNotNull
print("The number of rows in the dataset is: ", df.shape[0])
print("The number of available rows is: ",numberOfDataAvailable)
# Out:
# The number of rows in the dataset is:  768
# The number of available rows is:  768

# %% [markdown]
# Discard the last column

# %%
df = df.drop(df.columns[-1], axis=1)
df.head(5)
# Out:
#          x1         x2        x3         x4        x5        x6        x7  \
# 0 -6.776811  -7.663741 -1.937139   5.619535  1.957212  4.065625 -0.505045
# 1 -0.591086   8.237555  3.693422 -10.431475 -0.396667  9.181452  9.057534
# 2  1.231533 -11.428369  4.311638  -5.496241  2.297575  8.175036  4.045665
# 3 -3.450509  -3.693726 -2.790534   0.053492 -1.698626  7.694596 -3.803988
# 4  3.368960  -8.293089  4.816668  -4.750761 -3.995433  8.282782  6.214604
#
#          x8         x9       x10       x11       x12       x13       x14
# 0  6.784833 -10.514162 -3.780633  7.805881 -1.560728 -3.963353 -6.656145
# 1  3.090578   0.300064 -8.716877  0.056892 -0.532461 -4.362457  9.142519
# 2 -9.307296  -0.483197 -3.311644 -8.442872 -8.590588  3.147026 -2.639428
# 3  9.843115  -3.609249 -8.282603  5.401969  0.244423  2.821752 -5.644745
# 4 -3.075604   1.194046 -9.231290 -7.806242 -7.038902  2.527122 -2.204882

# %% [markdown]
# ### Questions
#
# Based on the previos results, provide a description of your dataset
#
# Your response:
#
# I have an idea about the structure of the data, there's 15 columns representing some float values, and around 750+ entries.
# Now, by looking at the summary statistics of this data, I can conclude some things:
#     1. The std is high, which means the data varies a lot from entry to entry.
#     2. Looking at the min and max of the columns, it shows a wide range, meaning that in addition to the data being variable, it does it in a wide range of values.
#     3. Outliers, as a consequence of the variability of the data, there can be a lot of outliers in the dataset.

# %% [markdown]
# ## A3 Data visualization

# %% [markdown]
# Plot in the same figure the histogram of two variables

# %%
# Histogram of x1 and x2
variable1 = df['x1']
variable2 = df['x2']


plt.figure(figsize=(10, 6))
plt.hist(variable1, bins=50, alpha=0.5, label='x1')
plt.hist(variable2, bins=50, alpha=0.5, label='x2')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of x1 and x2')
plt.legend(loc='upper right')
plt.show()

# %%
# Histogram of x4 and x13
variable1 = df['x4']
variable2 = df['x13']


plt.figure(figsize=(10, 6))
plt.hist(variable1, bins=50, alpha=0.5, label='x4')
plt.hist(variable2, bins=50, alpha=0.5, label='13')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of x1 and x2')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Based on these plots, provide a description of your data:
#
# Your response here:
#
# I've plotted the variables x1 and x2 combined, followed by the x4 and x13 plot. After looking at them, I've seen that there's som variables that it's values have a more spread distribution, for example, both, x4 and x2 have an inverted bell curve distribution, meaning there's more data on the edges of the values, rather than in the middle.
#
# This however, is not the case for all the other variables, both x1 and x13 have more of a normal distribution look to them, despite this, there is still a bit of leaning to one side of the data, for x1 it leans to the lower value range of data, and for x13 it leans to the upper value side.

# %% [markdown]
# Plot in the same figure the boxplot of two variables

# %%
# Boxplot of x1 and x13
variable1 = df['x1']
variable13 = df['x13']

newDf = pd.DataFrame({'x1': variable1, 'x13': variable13})

plt.figure(figsize=(10, 6))
newDf.boxplot(column=['x1', 'x13'])
plt.xlabel('Variable')
plt.ylabel('Value')
plt.title('Boxplot of x1 and x13')
plt.show()

# %%
# Boxplot of x2 and x4
variable2 = df['x2']
variable4 = df['x4']

newDf = pd.DataFrame({'x2': variable2, 'x4': variable4})

plt.figure(figsize=(10, 6))
newDf.boxplot(column=['x2', 'x4'])
plt.xlabel('Variable')
plt.ylabel('Value')
plt.title('Boxplot of x2 and x4')
plt.show()

# %% [markdown]
# Plot the scatter plot of two variables

# %%
# Scatter plot of x1 and x13
variable1 = df['x1']
variable13 = df['x13']

plt.figure(figsize=(10, 6))
plt.scatter(variable1, variable13, alpha=0.5)
plt.xlabel('x1')
plt.ylabel('x13')
plt.title('Scatter Plot of x1 and x13')
plt.show()

# %%
# Scatter plot of x2 and x4
variable2 = df['x2']
variable4 = df['x4']

plt.figure(figsize=(10, 6))
plt.scatter(variable2, variable4, alpha=0.5)
plt.xlabel('x2')
plt.ylabel('x4')
plt.title('Scatter Plot of x2 and x4')
plt.show()

# %% [markdown]
# ### Questions
#
# Based on the previos plots, provide a description of yout dataset
#
# Your response:
#
# The analysis stays much or less the same, the data is very disperse, and it has a wide range of variation, despite the fact there is a lot of variables that follow this pattern, there are some of them like x1 and x13, whose data range is shorter than other columns like x2 and x4, where its data varies in a wider range.
#
# We can verify this statement by looking at the x1 and x13 scatterplot compared to the x2 and x4 one. The first one has a much more centralized silhouette were its data appears to be more alike. Then we have the x2 and x4 one, which data has a more "out of bounds" silhouette.

# %% [markdown]
# ## A4 Kmeans

# %% [markdown]
# Do Kmeans clustering assuming a number of clusters accorging to your scatter plot

# %%
#Number of initial clusters: 7
kmeans = KMeans(n_clusters=7, random_state=42)
df['Cluster'] = kmeans.fit_predict(df)

# Get the centroids
centroids = kmeans.cluster_centers_

# Plotting the clusters for the first two features (x1 and x2)
plt.figure(figsize=(8, 6))
plt.scatter(df['x1'], df['x2'], c=df['Cluster'], cmap='viridis', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='x', label='Centroids')
plt.title('KMeans Clustering (7 clusters) based on all features')
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(label='Cluster')
plt.legend()
plt.show()

# %% [markdown]
# Add to your dataset a column with the estimated cluster to each data point
# Print the number associated to each cluster

# %%
#Clusters
print(df.iloc[:, 14])
# Out:
# 0      6
# 1      2
# 2      0
# 3      6
# 4      0
#       ..
# 763    4
# 764    5
# 765    1
# 766    3
# 767    6
# Name: Cluster, Length: 768, dtype: int32

# %% [markdown]
# Print the centroids

# %%
#Centroids of K-Means with 7 clusters
print(centroids)
# Out:
# [[  1.1435477   -7.91397955   4.81091638  -6.43374756   2.23057141
#     8.32766639   5.83751585  -5.10527539  -1.44875855  -7.76073353
#    -8.9288663   -7.74418233   2.62944232  -2.8259811    3.86075949]
#  [ -6.77906798  -5.84925543  -4.6097032    4.01699044   0.26050004
#     6.69118192  -0.41450931   9.45514983  -8.24557703  -5.37046489
#     7.56737829  -0.52363682  -0.28378889  -5.52426687   1.        ]
#  [ -0.92101454   7.57039923   4.83987415 -10.52768559  -1.2839037
#     5.06770463   6.44877362   2.97990297   0.3552407   -7.88196738
#     0.83701371  -0.97468456  -6.29868291   8.20128855   2.        ]
#  [  0.79241106  -5.45722899   3.27492947  -5.97116201   1.77952226
#     8.58502607   6.90390082  -5.4462861   -1.36361393  -7.21018137
#   -10.09015765  -7.50219317  -0.27928047  -3.73273887   6.        ]
#  [ -1.60998962   8.36819436   3.7637245   -9.640365    -1.2044727
#     6.45247432   4.60175699   4.42440001   0.68377827  -8.12907534
# ...

# %% [markdown]
# Print the intertia metric

# %%
#Inertia of K-Means
inertia = kmeans.inertia_
print("The inertia of K-Means is: ", inertia)
# Out:
# The inertia of K-Means is:  39103.25161962987

# %% [markdown]
# Plot a scatter plot of your data using different color for each cluster. Also plot the centroids

# %%
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray']
cluster_colors = [colors[label] for label in df['Cluster']]

plt.figure(figsize=(8, 6))
plt.scatter(df['x1'], df['x2'], c=cluster_colors,s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', s=200, marker='x', label='Centroids')
plt.title('KMeans Clustering (7 clusters) based on all features')
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(label='Cluster')
plt.legend()
plt.show()

# %% [markdown]
# ### Questions
#
# Provides a detailed description of your results
#
# Your response:
#
# While analyzing this K Means prediction, I noticed there's a lot of dispersion over all data, but when we categorize and assign groups, the data can become more organized. I feel 7 is a great number of clusters for assigning groups, there can certainly be more, but 7 is a great number to start with.

# %%
#K-Means with 3
newDf = df.drop(['Cluster'], axis=1)
means = KMeans(n_clusters=3, random_state=42)
newDf['Cluster'] = means.fit_predict(newDf)

# Get the centroids
centroids = means.cluster_centers_

# Plotting the clusters for the first two features (x1 and x2)
plt.figure(figsize=(8, 6))
plt.scatter(df['x1'], df['x2'], c=newDf['Cluster'], cmap='viridis', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='x', label='Centroids')
plt.title('KMeans Clustering (3 clusters) based on all features')
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(label='Cluster')
plt.legend()
plt.show()

# %% [markdown]
# ## A5 Elbow plot
#
# Compute the Elbow plot

# %%
cluster_range = range(1, 11)
inertia = []  

# Compute KMeans for each number of clusters and store the inertia
for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)  
    inertia.append(kmeans.inertia_)  

# Plot the elbow plot
plt.figure(figsize=(8, 6))
plt.plot(cluster_range, inertia, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Questions
#
# What is the best number of clusters K? (argue your response)
#
# Your response: For this specific case, before the elbow method i thought 7 could be great for classifying the values, after watching the graph made, I can argue the best number of clusters is probably 3 or 4, this because the inertia drops too much when passing from 2 clusters to 3.
#
#
# Does this number of clusters agree with your initial guess? (argue your response, no problem at all if they do not agree)
#
# Your response: No, it does not, I thought 7 was better for classifying this data, now looking at it more carefully I can agree that is between 3 and 4 clusters where we can find the best use for K-Means, this is because we are minimizing the number of iterations needed to complete the algorithm and to give us a decent classification.

# %% [markdown]
# # PART 2
# # Descipcion de tu percepcion del nivel de desarrollo de la subcompetencia
#
# ### SING0202A Interpretación de variables

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Interpreta interacciones**. Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo.

# %% [markdown]
# Tu respuesta: Soy capaz de identificar cómo las variables influyen en un problema mediante el análisis de datos. Esto me permite interpretar las interacciones entre las variables y construir modelos precisos. Estos modelos ayudan a predecir comportamientos futuros y a tomar decisiones informadas basadas en datos.

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Construcción de modelos**. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.

# %% [markdown]
# Tu respuesta: Me considero apto para construir un modelo que explique el comportamiento de un fenómeno. Esto significa que puedo identificar las variables que influyen en el problema y analizar cómo interactúan entre sí. Utilizo datos relevantes para crear un modelo que capture estas interacciones.
