# %% [markdown]
# # Nombre: León Emiliano García Pérez
# # Matrícula: A00573074

# %% [markdown]
# ## Repeating the Tutorial with de Iris Dataset

# %%
# Define where you are running the code: colab or local
RunInColab          = False     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = ""

else:
    # Define path del proyecto
    Ruta            = 'datasets'

# %%
# Import the packages that we will be using

import pandas as pd

# Dataset url

url = '/iris/iris.csv'

# Load the dataset

df = pd.read_csv(Ruta+url)
df.columns = ["PetalWidth", "PetalLength", "SepalWidth", "SepalLength", "Type"]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (149, 5)

# %%
df.shape[0]
# Out:
# 149

# %%
df.shape[1]
# Out:
# 5

# %%
df
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 0           4.9          3.0         1.4          0.2     Iris-setosa
# 1           4.7          3.2         1.3          0.2     Iris-setosa
# 2           4.6          3.1         1.5          0.2     Iris-setosa
# 3           5.0          3.6         1.4          0.2     Iris-setosa
# 4           5.4          3.9         1.7          0.4     Iris-setosa
# ..          ...          ...         ...          ...             ...
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
df.tail()
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica

# %%
df.columns
# Out:
# Index(['PetalWidth', 'PetalLength', 'SepalWidth', 'SepalLength', 'Type'], dtype='object')

# %%
df.dtypes
# Out:
# PetalWidth     float64
# PetalLength    float64
# SepalWidth     float64
# SepalLength    float64
# Type            object
# dtype: object

# %%
# Summary statistics for the quantitative variables

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PetalWidth   149 non-null    float64
#  1   PetalLength  149 non-null    float64
#  2   SepalWidth   149 non-null    float64
#  3   SepalLength  149 non-null    float64
#  4   Type         149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
#        PetalWidth  PetalLength  SepalWidth  SepalLength
# count  149.000000   149.000000  149.000000   149.000000
# mean     5.848322     3.054362    3.773826     1.206040
# std      0.828594     0.435810    1.760543     0.760354
# min      4.300000     2.000000    1.000000     0.100000
# 25%      5.100000     2.800000    1.600000     0.300000
# 50%      5.800000     3.000000    4.400000     1.300000
# 75%      6.400000     3.300000    5.100000     1.800000
# max      7.900000     4.400000    6.900000     2.500000

# %%
# Drop observations with NaN values

df.PetalWidth.dropna().describe()
df.PetalLength.dropna().describe()
df.SepalWidth.dropna().describe()
df.SepalLength.dropna().describe()
# Out:
# count    149.000000
# mean       1.206040
# std        0.760354
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: SepalLength, dtype: float64

# %%
#print("mean")
#df.mean()
#print("corr")
#df.corr()
#print("count")
#df.count()
#print("max")
#df.max()
#print("min")
#df.min()
#print("median")
#df.median()
#print("std")
df.std() ################## El único que, al menos en este tutorial, imprimió datos. CON WARNING.
# Out:
# C:\Users\LeonE\AppData\Local\Temp\ipykernel_7384\2295696299.py:14: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std() ################## El único que, al menos en este tutorial, imprimió datos. CON WARNING.
# PetalWidth     0.828594
# PetalLength    0.435810
# SepalWidth     1.760543
# SepalLength    0.760354
# dtype: float64

# %%
df.to_csv('myNewDataFrame.csv')
df.to_csv('myNewDataFrame.csv', sep='\t')

# %%
df = df.rename(columns={"PetalWidth": "AnchoPetal"})
df.head()
# Out:
#    AnchoPetal  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
# Back to the original name

df = df.rename(columns={"AnchoPetal": "PetalWidth"})

df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
a = df.PetalWidth
b = df["PetalLength"]
c = df.loc[:, "PetalLength"]
d = df.iloc[:, 1]

print(d)

e = df[["SepalWidth", "SepalWidth"]]

print(e)
# Out:
# 0      3.0
# 1      3.2
# 2      3.1
# 3      3.6
# 4      3.9
#       ...
# 144    3.0
# 145    2.5
# 146    3.0
# 147    3.4
# 148    3.0
# Name: PetalLength, Length: 149, dtype: float64
#      SepalWidth  SepalWidth
# 0           1.4         1.4
# 1           1.3         1.3
# 2           1.5         1.5
# 3           1.4         1.4
# 4           1.7         1.7
# ..          ...         ...
# 144         5.2         5.2
# 145         5.0         5.0
# 146         5.2         5.2
# 147         5.4         5.4
# 148         5.1         5.1
#
# [149 rows x 2 columns]

# %%
df.loc[:,"PetalLength"]


df.loc[:9, "PetalLength"]


df.loc[:,["SepalWidth", "SepalLength"]]


keep = ['PetalWidth', 'PetalLength']
df_gender = df[keep]


df.loc[4:9, ["SepalWidth", "PetalWidth", "Type"]]


df.loc[10:15,:]
# Out:
#     PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 10         4.8          3.4         1.6          0.2  Iris-setosa
# 11         4.8          3.0         1.4          0.1  Iris-setosa
# 12         4.3          3.0         1.1          0.1  Iris-setosa
# 13         5.8          4.0         1.2          0.2  Iris-setosa
# 14         5.7          4.4         1.5          0.4  Iris-setosa
# 15         5.4          3.9         1.3          0.4  Iris-setosa

# %%
df.iloc[:, :4]


df.iloc[:4, :]


df.iloc[:, 3:7]


df.iloc[4:8, 2:4]
# Out:
#    SepalWidth  SepalLength
# 4         1.7          0.4
# 5         1.4          0.3
# 6         1.5          0.2
# 7         1.4          0.2

# %%
df.Type.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df[df["SepalLength"] >= 1.0]
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength             Type
# 49          7.0          3.2         4.7          1.4  Iris-versicolor
# 50          6.4          3.2         4.5          1.5  Iris-versicolor
# 51          6.9          3.1         4.9          1.5  Iris-versicolor
# 52          5.5          2.3         4.0          1.3  Iris-versicolor
# 53          6.5          2.8         4.6          1.5  Iris-versicolor
# ..          ...          ...         ...          ...              ...
# 144         6.7          3.0         5.2          2.3   Iris-virginica
# 145         6.3          2.5         5.0          1.9   Iris-virginica
# 146         6.5          3.0         5.2          2.0   Iris-virginica
# 147         6.2          3.4         5.4          2.3   Iris-virginica
# 148         5.9          3.0         5.1          1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %%
df.sort_values("PetalWidth")
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 12          4.3          3.0         1.1          0.1     Iris-setosa
# 41          4.4          3.2         1.3          0.2     Iris-setosa
# 37          4.4          3.0         1.3          0.2     Iris-setosa
# 7           4.4          2.9         1.4          0.2     Iris-setosa
# 40          4.5          2.3         1.3          0.3     Iris-setosa
# ..          ...          ...         ...          ...             ...
# 117         7.7          2.6         6.9          2.3  Iris-virginica
# 116         7.7          3.8         6.7          2.2  Iris-virginica
# 121         7.7          2.8         6.7          2.0  Iris-virginica
# 134         7.7          3.0         6.1          2.3  Iris-virginica
# 130         7.9          3.8         6.4          2.0  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.groupby(['Type'])

# %%
df.isnull()
df.notnull()
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength  Type
# 0          True         True        True         True  True
# 1          True         True        True         True  True
# 2          True         True        True         True  True
# 3          True         True        True         True  True
# 4          True         True        True         True  True
# ..          ...          ...         ...          ...   ...
# 144        True         True        True         True  True
# 145        True         True        True         True  True
# 146        True         True        True         True  True
# 147        True         True        True         True  True
# 148        True         True        True         True  True
#
# [149 rows x 5 columns]

# %%
df.groupby(['Type']).size()
# Out:
# Type
# Iris-setosa        49
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PetalWidth     0
# PetalLength    0
# SepalWidth     0
# SepalLength    0
# Type           0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# PetalWidth     149
# PetalLength    149
# SepalWidth     149
# SepalLength    149
# Type           149
# dtype: int64

# %%
print( df.PetalWidth.notnull().sum() )
print( pd.isnull(df.PetalWidth).sum() )
# Out:
# 149
# 0

# %%
x = df.Type.dropna()
x.describe()
# Out:
# count                 149
# unique                  3
# top       Iris-versicolor
# freq                   50
# Name: Type, dtype: object

# %%
df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
# Add a new column with new data

# Create a column data
NewColumnData = df.PetalWidth/df.PetalLength

# Insert that column in the data frame
df.insert(5, "PetalWidth/PetalLength", NewColumnData, True)

df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type  \
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa
#
#    PetalWidth/PetalLength
# 0                1.633333
# 1                1.468750
# 2                1.483871
# 3                1.388889
# 4                1.384615

# %%
# # Eliminate inserted column
#df.drop("PetalWidth/PetalLength", axis=1, inplace = True) #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO
#df.drop(columns=['PetalWidth/PetalLength'], inplace = True) #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO

# # Remove three columns as index base
df.drop(df.columns[[5]], axis = 1, inplace = True) #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO

df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
# # Add new column derived from existing columns
#
# # The new column is a function of another column
df["SepalWidth/SepalLength"] = df["SepalWidth"] / df["SepalLength"] 
# 
df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type  \
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa
#
#    SepalWidth/SepalLength
# 0                    7.00
# 1                    6.50
# 2                    7.50
# 3                    7.00
# 4                    4.25

# %%
# # Eliminate inserted column
df.drop("SepalWidth/SepalLength", axis=1, inplace = True)
#
df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
df["NumType"] = df.Type.replace({"Iris-setosa":1 , "Iris-virginica": 2, "Iris-virginica":3})

# Show the first 5 rows of the created data frame

df.head(5)
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type NumType
# 0         4.9          3.0         1.4          0.2  Iris-setosa       1
# 1         4.7          3.2         1.3          0.2  Iris-setosa       1
# 2         4.6          3.1         1.5          0.2  Iris-setosa       1
# 3         5.0          3.6         1.4          0.2  Iris-setosa       1
# 4         5.4          3.9         1.7          0.4  Iris-setosa       1

# %%
## Eliminate inserted column
df.drop("NumType", axis=1, inplace = True) #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO
#df.drop(['NumType'],vaxis='columns',vinplace=True) #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO

# %%
## Add a new column with strata based on these cut points
#
## Create a column data
NewColumnData = df.PetalWidth/df.PetalWidth
#
## Insert that column in the data frame
df.insert(1, "ColumnStrata", NewColumnData, True)
#
df["ColumnStrata"] = pd.cut(df.PetalWidth, [0., 1., 2., 3., 4., 5., 6.])
#
## Show the first 5 rows of the created data frame
df.head()
# Out:
#    PetalWidth ColumnStrata  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9   (4.0, 5.0]          3.0         1.4          0.2  Iris-setosa
# 1         4.7   (4.0, 5.0]          3.2         1.3          0.2  Iris-setosa
# 2         4.6   (4.0, 5.0]          3.1         1.5          0.2  Iris-setosa
# 3         5.0   (4.0, 5.0]          3.6         1.4          0.2  Iris-setosa
# 4         5.4   (5.0, 6.0]          3.9         1.7          0.4  Iris-setosa

# %%
## Eliminate inserted column
df.drop("ColumnStrata", axis=1, inplace = True)
#
df.head()
# Out:
#    PetalWidth  PetalLength  SepalWidth  SepalLength         Type
# 0         4.9          3.0         1.4          0.2  Iris-setosa
# 1         4.7          3.2         1.3          0.2  Iris-setosa
# 2         4.6          3.1         1.5          0.2  Iris-setosa
# 3         5.0          3.6         1.4          0.2  Iris-setosa
# 4         5.4          3.9         1.7          0.4  Iris-setosa

# %%
# Print tail

df.tail()
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica

# %%
df.loc[len(df.index)] = [ 5.9, 3.0, 5.1, 1.8, 'Iris-virginica'] 

df.tail()
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica
# 149         5.9          3.0         5.1          1.8  Iris-virginica

# %%
## Eliminate inserted row
df.drop([149], inplace = True )
#
df.tail()
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica

# %%
vars = ["PetalWidth", "PetalLength", "SepalWidth", "Type"]
df = df[vars].dropna() #SOLO PUEDE SER USADO UNA A LA VEZ, NO SE PUEDE DROPEAR ALGO YA DROPEADO

df
# Out:
#      PetalWidth  PetalLength  SepalWidth            Type
# 0           4.9          3.0         1.4     Iris-setosa
# 1           4.7          3.2         1.3     Iris-setosa
# 2           4.6          3.1         1.5     Iris-setosa
# 3           5.0          3.6         1.4     Iris-setosa
# 4           5.4          3.9         1.7     Iris-setosa
# ..          ...          ...         ...             ...
# 144         6.7          3.0         5.2  Iris-virginica
# 145         6.3          2.5         5.0  Iris-virginica
# 146         6.5          3.0         5.2  Iris-virginica
# 147         6.2          3.4         5.4  Iris-virginica
# 148         5.9          3.0         5.1  Iris-virginica
#
# [149 rows x 4 columns]

# %% [markdown]
# ## Activity: work with the iris dataset
# 1. Calculate the statistical summary for each quantitative variables. Explain the results
#     - Identify the name of each column
#     - Identify the type of each column
#     - Minimum, maximum, mean, average, median, standar deviation
# 2. Are there missing data? If so, create a new dataset containing only the rows with the non-missing data
# 3. Create a new dataset containing only the petal width and length and the type of Flower
# 4. Create a new dataset containing only the setal width and length and the type of Flower
# 5. Create a new dataset containing the setal width and length and the type of Flower encoded as a categorical numerical column

# %%
import pandas as pd

Ruta            = 'datasets'

newUrl = '/iris/iris.csv'

newDatos = pd.read_csv(Ruta+newUrl)

# %%
newDatos.columns = ["PetalWidth", "PetalLength", "SepalWidth", "SepalLength", "Type"]

#Name and type of each column
### newDatos.info()
print(newDatos.columns)
print(newDatos.dtypes)

#Statistical Summary: - Minimun, Maximum, Mean - Average, Standar Deviation.
print(newDatos.describe())
# Out:
# Index(['PetalWidth', 'PetalLength', 'SepalWidth', 'SepalLength', 'Type'], dtype='object')
# PetalWidth     float64
# PetalLength    float64
# SepalWidth     float64
# SepalLength    float64
# Type            object
# dtype: object
#        PetalWidth  PetalLength  SepalWidth  SepalLength
# count  149.000000   149.000000  149.000000   149.000000
# mean     5.848322     3.054362    3.773826     1.206040
# std      0.828594     0.435810    1.760543     0.760354
# min      4.300000     2.000000    1.000000     0.100000
# 25%      5.100000     2.800000    1.600000     0.300000
# 50%      5.800000     3.000000    4.400000     1.300000
# 75%      6.400000     3.300000    5.100000     1.800000
# max      7.900000     4.400000    6.900000     2.500000

# %%
#Median
print("PetalWidth Median: ", newDatos['PetalWidth'].median())
print("PetalLength Median: ", newDatos['PetalLength'].median())
print("SepalWidth Median: ", newDatos['SepalWidth'].median())
print("SepalLength Median: ", newDatos['SepalLength'].median())
# Out:
# PetalWidth Median:  5.8
# PetalLength Median:  3.0
# SepalWidth Median:  4.4
# SepalLength Median:  1.3

# %%
newDatos
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 0           4.9          3.0         1.4          0.2     Iris-setosa
# 1           4.7          3.2         1.3          0.2     Iris-setosa
# 2           4.6          3.1         1.5          0.2     Iris-setosa
# 3           5.0          3.6         1.4          0.2     Iris-setosa
# 4           5.4          3.9         1.7          0.4     Iris-setosa
# ..          ...          ...         ...          ...             ...
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
newDF0 = newDatos.dropna() #Dropping missing data

# %%
newDF0
# Out:
#      PetalWidth  PetalLength  SepalWidth  SepalLength            Type
# 0           4.9          3.0         1.4          0.2     Iris-setosa
# 1           4.7          3.2         1.3          0.2     Iris-setosa
# 2           4.6          3.1         1.5          0.2     Iris-setosa
# 3           5.0          3.6         1.4          0.2     Iris-setosa
# 4           5.4          3.9         1.7          0.4     Iris-setosa
# ..          ...          ...         ...          ...             ...
# 144         6.7          3.0         5.2          2.3  Iris-virginica
# 145         6.3          2.5         5.0          1.9  Iris-virginica
# 146         6.5          3.0         5.2          2.0  Iris-virginica
# 147         6.2          3.4         5.4          2.3  Iris-virginica
# 148         5.9          3.0         5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
#Create a new dataset containing only the petal width and length and the type of Flower
#Create a new dataset containing only the sepal width and length and the type of Flower

newDF1 = newDF0[["PetalWidth","PetalLength","Type"]]
newDF2 = newDF0[["SepalWidth","SepalLength","Type"]]

# %%
newDF1
# Out:
#      PetalWidth  PetalLength            Type
# 0           4.9          3.0     Iris-setosa
# 1           4.7          3.2     Iris-setosa
# 2           4.6          3.1     Iris-setosa
# 3           5.0          3.6     Iris-setosa
# 4           5.4          3.9     Iris-setosa
# ..          ...          ...             ...
# 144         6.7          3.0  Iris-virginica
# 145         6.3          2.5  Iris-virginica
# 146         6.5          3.0  Iris-virginica
# 147         6.2          3.4  Iris-virginica
# 148         5.9          3.0  Iris-virginica
#
# [149 rows x 3 columns]

# %%
newDF2
# Out:
#      SepalWidth  SepalLength            Type
# 0           1.4          0.2     Iris-setosa
# 1           1.3          0.2     Iris-setosa
# 2           1.5          0.2     Iris-setosa
# 3           1.4          0.2     Iris-setosa
# 4           1.7          0.4     Iris-setosa
# ..          ...          ...             ...
# 144         5.2          2.3  Iris-virginica
# 145         5.0          1.9  Iris-virginica
# 146         5.2          2.0  Iris-virginica
# 147         5.4          2.3  Iris-virginica
# 148         5.1          1.8  Iris-virginica
#
# [149 rows x 3 columns]

# %%
#Create a new dataset containing the sepal width and length and the type of Flower encoded as a categorical numerical column

newDF0["NewType"] = newDF0.Type.replace({"Iris-setosa":1 , "Iris-virginica": 2, "Iris-virginica":3})

newDF3 = newDF0[["SepalWidth","SepalLength","NewType"]]

# %%
newDF3
# Out:
#      SepalWidth  SepalLength NewType
# 0           1.4          0.2       1
# 1           1.3          0.2       1
# 2           1.5          0.2       1
# 3           1.4          0.2       1
# 4           1.7          0.4       1
# ..          ...          ...     ...
# 144         5.2          2.3       3
# 145         5.0          1.9       3
# 146         5.2          2.0       3
# 147         5.4          2.3       3
# 148         5.1          1.8       3
#
# [149 rows x 3 columns]
