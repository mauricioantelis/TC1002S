# %%
# Import the packages that we will be using
import pandas as pd
import matplot as mlp

# Define where you are running the code: colab or local
RunInColab          = False     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

else:
    # Define path del proyecto
    Ruta            = "C:/Users/GeekD/OneDrive/Documents/GitHub/TC1002S/NotebooksProfessor"
    
    URL = Ruta + "/datasets/iris/iris.csv"

# %%
#Read the .csv
df = pd.read_csv(URL, header = None)

# %%
#Output object
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Use the shape method to determine the numbers of rows and columns in a data frame. This can be used to confirm that we have actually obtained the data the we are expecting.
#
# Based on what we see below, the data set being read here has  𝑁𝑟
#   rows, corresponding to  𝑁𝑟
#   observations, and  𝑁𝑐
#   columns, corresponding to  𝑁𝑐
#   variables in this particular data file.

# %%
df.shape
# Out:
# (150, 5)

# %%
f = df.shape[0]
c = df.shape[1]

print("Registros: "+str(f))
print ("Variables: "+str(c))
# Out:
# Registros: 150
# Variables: 5

# %%
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
top = df.head()
top
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
bot = df.tail()
bot
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4     object
# dtype: object

# %%
df.describe()
# Out:
#        Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo
# count    150.000000    150.000000    150.000000    150.000000
# mean       5.843333      3.057333      3.758000      1.199333
# std        0.828066      0.435866      1.765298      0.762238
# min        4.300000      2.000000      1.000000      0.100000
# 25%        5.100000      2.800000      1.600000      0.300000
# 50%        5.800000      3.000000      4.350000      1.300000
# 75%        6.400000      3.300000      5.100000      1.800000
# max        7.900000      4.400000      6.900000      2.500000

# %%
print("Media:\n"+ str(df.mean()))
print("Correlacion:\n"+ str(df.corr()))
print("No null:\n"+ str(df.count()))
print("Maximo:\n"+ str(df.max()))
print("Minimo:\n"+ str(df.min()))
print("Mediana:\n"+ str(df.median()))
print("Desviacion estandar:\n"+ str(df.std()))
# Out:
# Media:
# 0    5.843333
# 1    3.057333
# 2    3.758000
# 3    1.199333
# dtype: float64
# Correlacion:
#           0         1         2         3
# 0  1.000000 -0.117570  0.871754  0.817941
# 1 -0.117570  1.000000 -0.428440 -0.366126
# 2  0.871754 -0.428440  1.000000  0.962865
# 3  0.817941 -0.366126  0.962865  1.000000
# No null:
# 0    150
# 1    150
# 2    150
# 3    150
# 4    150
# dtype: int64
# Maximo:
# 0               7.9
# 1               4.4
# 2               6.9
# 3               2.5
# 4    Iris-virginica
# dtype: object
# Minimo:
# 0            4.3
# 1            2.0
# 2            1.0
# 3            0.1
# 4    Iris-setosa
# dtype: object
# Mediana:
# 0    5.80
# 1    3.00
# 2    4.35
# 3    1.30
# dtype: float64
# Desviacion estandar:
# 0    0.828066
# 1    0.435866
# 2    1.765298
# 3    0.762238
# dtype: float64
# C:\Users\GeekD\AppData\Local\Temp\ipykernel_9456\2693019815.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Media:\n"+ str(df.mean()))
# C:\Users\GeekD\AppData\Local\Temp\ipykernel_9456\2693019815.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Correlacion:\n"+ str(df.corr()))
# C:\Users\GeekD\AppData\Local\Temp\ipykernel_9456\2693019815.py:6: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Mediana:\n"+ str(df.median()))
# C:\Users\GeekD\AppData\Local\Temp\ipykernel_9456\2693019815.py:7: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Desviacion estandar:\n"+ str(df.std()))

# %% [markdown]
# ## How to write a data frame to a File

# %%
df.to_csv('myDataFrame.csv')

# %% [markdown]
# ## Rename Columns

# %%
df = df.rename(columns={4: "Especie"})

df.head()
# Out:
#      0    1    2    3      Especie
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ## Selection of columns

# %%
a = df.Especie
b = df["Especie"]
c = df.loc[:, "Especie"]
d = df.iloc[:, 4]

print(d)

x = df[["Ancho_Sepalo", "Largo_Sepalo"]]
x
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Especie, Length: 150, dtype: object
#      Ancho_Sepalo  Largo_Sepalo
# 0             3.5           5.1
# 1             3.0           4.9
# 2             3.2           4.7
# 3             3.1           4.6
# 4             3.6           5.0
# ..            ...           ...
# 145           3.0           6.7
# 146           2.5           6.3
# 147           3.0           6.5
# 148           3.4           6.2
# 149           3.0           5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# # Slicing a data set
#
# loc()

# %%
# Return all observations of CWDistance
#df.loc[0:4,"Especie"]

# Return a subset of observations of CWDistance
#df.loc[3:9, "Especie"]
# Select all rows for multiple columns, ["Gender", "GenderGroup"]
#df.loc[2:16,[3, "Especie"]]

# Select multiple columns, ["Gender", "GenderGroup"]me 
#keep = [3, 'Especie']
#df_gender = df[keep]

# Select few rows for multiple columns, ["CWDistance", "Height", "Wingspan"]
#df.loc[4:9, [2, 3, "Especie"]]

# Select range of rows for all columns
#df.loc[10:15,1:3]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Especie, dtype: object

# %% [markdown]
# The attribute **iloc()** is an integer based slicing.

# %%
# .
df.iloc[0:1, 2:4]

# .
#df.iloc[:4, :]

# .
#df.iloc[:, 3:7]

# .
df.iloc[4:8, 2:4]

# This is incorrect:
#df.iloc[1:5, ["Gender", "GenderGroup"]]
# Out:
#    Largo_Petalo  Ancho_Petalo
# 4           1.4           0.2
# 5           1.7           0.4
# 6           1.4           0.3
# 7           1.5           0.2

# %% [markdown]
# # Get unique existing values

# %%
df.Especie.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Filter, Sort and Groupby

# %%
df[df["Ancho_Sepalo"] >= 3.1]
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo         Especie
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# 5             5.4           3.9           1.7           0.4     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 140           6.7           3.1           5.6           2.4  Iris-virginica
# 141           6.9           3.1           5.1           2.3  Iris-virginica
# 143           6.8           3.2           5.9           2.3  Iris-virginica
# 144           6.7           3.3           5.7           2.5  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
#
# [67 rows x 5 columns]

# %%
df.sort_values("Largo_Sepalo")
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo         Especie  \
# 13            4.3           3.0           1.1           0.1     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# 131           7.9           3.8           6.4           2.0  Iris-virginica
#
#             test123
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 118  Iris-virginica
# 117  Iris-virginica
# 135  Iris-virginica
# 131  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.sort_values("Largo_Sepalo",ascending=False)
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo         Especie  \
# 131           7.9           3.8           6.4           2.0  Iris-virginica
# 135           7.7           3.0           6.1           2.3  Iris-virginica
# 122           7.7           2.8           6.7           2.0  Iris-virginica
# 117           7.7           3.8           6.7           2.2  Iris-virginica
# 118           7.7           2.6           6.9           2.3  Iris-virginica
# ..            ...           ...           ...           ...             ...
# 41            4.5           2.3           1.3           0.3     Iris-setosa
# 42            4.4           3.2           1.3           0.2     Iris-setosa
# 38            4.4           3.0           1.3           0.2     Iris-setosa
# 8             4.4           2.9           1.4           0.2     Iris-setosa
# 13            4.3           3.0           1.1           0.1     Iris-setosa
#
#             test123
# 131  Iris-virginica
# 135  Iris-virginica
# 122  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# ..              ...
# 41      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 13      Iris-setosa
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Groupby

# %%
gk = df.groupby(["Especie"])
gk.first()
# Out:
#                  Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo  \
# Especie
# Iris-setosa               5.1           3.5           1.4           0.2
# Iris-versicolor           7.0           3.2           4.7           1.4
# Iris-virginica            6.3           3.3           6.0           2.5
#
#                          test123
# Especie
# Iris-setosa          Iris-setosa
# Iris-versicolor  Iris-versicolor
# Iris-virginica    Iris-virginica

# %%
df.groupby(["Especie"]).size()
# Out:
# Especie
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Data Cleaning: handle with missing data

# %%
#General
df.isnull().sum()
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# Especie    0
# dtype: int64

# %%
#Columna (No vacío)
print( df.Especie.notnull().sum() )
# Out:
# 150

# %%
#Columna (Vacío)
print( pd.isnull(df.Especie).sum() )
# Out:
# 0

# %%
#Extraer null
x = df.Especie.dropna()
x.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Especie, dtype: object

# %% [markdown]
# # Add and eliminate columns

# %%
df.head()
# Out:
#    Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo      Especie
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
#Insertar
NewColumnData = df.Especie

# Insert that column in the data frame
df.insert(5, "test123", NewColumnData, True)
df.head()
# Out:
#    Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo      Especie  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#        test123
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
#Eliminar
df.drop("test123", axis=1, inplace = True)
#df.drop(columns=['test123'], inplace = True)
#df.drop(df.columns[[5]], axis = 1, inplace = True)
#
df.head()
# Out:
#    Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo      Especie
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %%
df["Ancho_Petalo*10"] = df["Ancho_Petalo"] * 10

df.head()
# Out:
#    Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo      Especie  \
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa
#
#    Ancho_Petalo*10
# 0              2.0
# 1              2.0
# 2              2.0
# 3              2.0
# 4              2.0

# %%
df.drop("Ancho_Petalo*10", axis=1, inplace = True)

df.head()
# Out:
#    Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo      Especie
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           3.0           1.4           0.2  Iris-setosa
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3           4.6           3.1           1.5           0.2  Iris-setosa
# 4           5.0           3.6           1.4           0.2  Iris-setosa

# %% [markdown]
# # Add and eliminate rows

# %% [markdown]
# # Cleaning your data: drop out unused columns and/or drop out rows with any missing values

# %%
# Drop unused columns and drop rows with any missing values
vars = ["Largo_Sepalo","Ancho_Sepalo","Largo_Petalo","Ancho_Petalo","Especie"]
df = df[vars].dropna()

df = df.rename(columns={0: "Largo_Sepalo"})
df = df.rename(columns={1: "Ancho_Sepalo"})
df = df.rename(columns={2: "Largo_Petalo"})
df = df.rename(columns={3: "Ancho_Petalo"})
df = df.rename(columns={4: "Especie"})

df
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo         Especie
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Final remarks
#
#
# - The understanding of your dataset is essential
#     - Number of observations
#     - Variables
#     - Data types: numerical or categorial
#     - What are my variables of interest
#
# - There are several ways to do the same thing
#
# - Cleaning your dataset (dropping out rows with any missing values) is a good practice
#
# - The **Pandas** library provides fancy, high-performance, easy-to-use data structures and data analysis tools

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Calculate the statistical summary for each quantitative variables. Explain the results
#     - Identify the name of each column
#     - Identify the type of each column
#     - Minimum, maximum, mean, average, median, standar deviation
#
#
#
# 2. Are there missing data? If so, create a new dataset containing only the rows with the non-missing data
# En este caso no falta ningún dato.
#
# 3. Create a new dataset containing only the petal width and length and the type of Flower
#
#
# 4. Create a new dataset containing only the setal width and length and the type of Flower
#
#
# 5. Create a new dataset containing the setal width and length and the type of Flower encoded as a categorical numerical column

# %%
# 1.-
dfSum = df.iloc[:, 0:4].copy()
dfSum.describe()

# %%
# 2.-
#No falta ningún dato pero la función en sí sería:
df2 = df.dropna()
df2
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo         Especie
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 3.-
df3 = df[["Especie", "Ancho_Petalo", "Largo_Petalo"]].copy()
df3
# Out:
#             Especie  Ancho_Petalo  Largo_Petalo
# 0       Iris-setosa           0.2           1.4
# 1       Iris-setosa           0.2           1.4
# 2       Iris-setosa           0.2           1.3
# 3       Iris-setosa           0.2           1.5
# 4       Iris-setosa           0.2           1.4
# ..              ...           ...           ...
# 145  Iris-virginica           2.3           5.2
# 146  Iris-virginica           1.9           5.0
# 147  Iris-virginica           2.0           5.2
# 148  Iris-virginica           2.3           5.4
# 149  Iris-virginica           1.8           5.1
#
# [150 rows x 3 columns]

# %%
# 4.-
df4 = df[["Especie", "Ancho_Sepalo", "Largo_Sepalo"]].copy()
df4
# Out:
#             Especie  Ancho_Sepalo  Largo_Sepalo
# 0       Iris-setosa           3.5           5.1
# 1       Iris-setosa           3.0           4.9
# 2       Iris-setosa           3.2           4.7
# 3       Iris-setosa           3.1           4.6
# 4       Iris-setosa           3.6           5.0
# ..              ...           ...           ...
# 145  Iris-virginica           3.0           6.7
# 146  Iris-virginica           2.5           6.3
# 147  Iris-virginica           3.0           6.5
# 148  Iris-virginica           3.4           6.2
# 149  Iris-virginica           3.0           5.9
#
# [150 rows x 3 columns]

# %%
#5. Create a new dataset containing the setal width and length and the type of Flower encoded as a categorical numerical column 
df5 = df.copy()
df5["Especie"] = df5["Especie"].replace({"Iris-setosa":0,"Iris-virginica":1,"Iris-versicolor":2})
df5
# Out:
#      Largo_Sepalo  Ancho_Sepalo  Largo_Petalo  Ancho_Petalo  Especie
# 0             5.1           3.5           1.4           0.2        0
# 1             4.9           3.0           1.4           0.2        0
# 2             4.7           3.2           1.3           0.2        0
# 3             4.6           3.1           1.5           0.2        0
# 4             5.0           3.6           1.4           0.2        0
# ..            ...           ...           ...           ...      ...
# 145           6.7           3.0           5.2           2.3        1
# 146           6.3           2.5           5.0           1.9        1
# 147           6.5           3.0           5.2           2.0        1
# 148           6.2           3.4           5.4           2.3        1
# 149           5.9           3.0           5.1           1.8        1
#
# [150 rows x 5 columns]
