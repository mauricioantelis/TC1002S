# %% [markdown]
# # Activity 1: work with the iris dataset
#
#
# > Alumno: Gabriel Alvarez Arzate Matricula: *A01642991*

# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Define path del proyecto
    Ruta            = "/content/drive/MyDrive/SemanaTecHerramientasComputacionales/NotebooksProfessor/"

else:
    # Define path del proyecto
    Ruta            = ""
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##1. Load the iris.csv file in your computer and understand the dataset

# %%
# Import the packages that we will be using
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns #libreria para visualizacion
import matplotlib.pyplot as plt

#Añadimosel nombre de cada uno de los renglones que tendra
colnames=["Sepal_Length","Sepal_Width","Petal_Length","Petal_Width","Flower_Name"]

# Dataset url
url = Ruta + "datasets/iris/iris.csv"

# Load the dataset
dataset = pd.read_csv(url,header=None, names=colnames)

dataset
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width     Flower_Name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##2. How many observations (rows) are in total?
# 150

# %%
# Print the number of rows
Nrows = dataset.shape[0]
Nrows
# Out:
# 150

# %% [markdown]
# ##3. How many variables (columns) are in total? What do they represent?
# 5

# %%
# Print the number of columns
Ncols = dataset.shape[1]
Ncols
# Out:
# 5

# %% [markdown]
# ##4. How many observations are for each type of flower?
# 50 por cada flor

# %%
dataset.groupby(['Flower_Name']).size()
# Out:
# Flower_Name
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ##5. What is the type of data for each variable?
# Sepal_Length    float64
#
# Sepal_Width     float64
#
# Petal_Length    float64
#
# Petal_Width     float64
#
# Flower_Name      object maybe string

# %%
dataset.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Flower_Name      object
# dtype: object

# %% [markdown]
# ##6. What are the units of each variable?
#
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm

# %% [markdown]
# # Activity 2: work with the iris dataset

# %% [markdown]
# ##1. Calculate the statistical summary for each quantitative variables. Explain the results
#   - Identify the name of each column
#   - Identify the type of each column
#   - Minimum, maximum, mean, median, standar deviation
#
#
#   - **Name: Sepal_Length**
#
#   1Data Type: float64
#
#   count    150.000000
#
#   mean       5.843333
#
#   std        0.828066
#
#   min        4.300000
#
#   25%        5.100000
#
#   50%        5.800000
#
#   75%        6.400000
#
#   max        7.900000
#
#   -**Name: Sepal_Width**
#
#   Data Type: float64
#
#   count    150.000000
#
#   mean       3.057333
#
#   std        0.435866
#
#   min        2.000000
#
#   25%        2.800000
#
#   50%        3.000000
#
#   75%        3.300000
#
#   max        4.400000
#
#   -**Name: Petal_Length**
#
#   Data type: float64
#
#   count    150.000000
#
#   mean       3.758000
#
#   std        1.765298
#
#   min        1.000000
#
#   25%        1.600000
#
#   50%        4.350000
#
#   75%        5.100000
#
#   max        6.900000
#
#   -**Name: Petal_Width**
#
#   Data type: float64
#
#   count    150.000000
#
#   mean       1.199333
#
#   std        0.762238
#
#   min        0.100000
#
#   25%        0.300000
#
#   50%        1.300000
#
#   75%        1.800000
#
#   max        2.500000

# %%
#Obtenemos el stadistical summary para el Sepal_Length
dataset.Sepal_Length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: Sepal_Length, dtype: float64

# %%
#Obtenemos el stadistical summary para el Sepal_Width
dataset.Sepal_Width.describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: Sepal_Width, dtype: float64

# %%
#Obtenemos el stadistical summary para el Petal_Length
dataset.Petal_Length.describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: Petal_Length, dtype: float64

# %%
#Obtenemos el stadistical summary para el Pepal_Width
dataset.Petal_Width.describe()
# Out:
# count    150.000000
# mean       1.199333
# std        0.762238
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: Petal_Width, dtype: float64

# %% [markdown]
# ##2. Are there missing data? If so, create a new dataset containing only the rows with the non-missing data
#
# No hay ningun valor que falte, ya que al correr el notnull vemos que nos regresa la misma cantidad de columnas y renglones que normalmente hay.

# %%
dataset.notnull()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Flower_Name
# 0            True         True          True         True         True
# 1            True         True          True         True         True
# 2            True         True          True         True         True
# 3            True         True          True         True         True
# 4            True         True          True         True         True
# ..            ...          ...           ...          ...          ...
# 145          True         True          True         True         True
# 146          True         True          True         True         True
# 147          True         True          True         True         True
# 148          True         True          True         True         True
# 149          True         True          True         True         True
#
# [150 rows x 5 columns]

# %% [markdown]
# ##3. Create a new dataset containing only the petal width and length and the type of Flower

# %%
vars1 = ["Sepal_Length","Sepal_Width"]
newds1=dataset.drop(vars1, axis=1, inplace = False)
newds1
# Out:
#      Petal_Length  Petal_Width     Flower_Name
# 0             1.4          0.2     Iris-setosa
# 1             1.4          0.2     Iris-setosa
# 2             1.3          0.2     Iris-setosa
# 3             1.5          0.2     Iris-setosa
# 4             1.4          0.2     Iris-setosa
# ..            ...          ...             ...
# 145           5.2          2.3  Iris-virginica
# 146           5.0          1.9  Iris-virginica
# 147           5.2          2.0  Iris-virginica
# 148           5.4          2.3  Iris-virginica
# 149           5.1          1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ##4. Create a new dataset containing only the setal width and length and the type of Flower

# %%
vars2 = ["Petal_Length","Petal_Width"]
newds2=dataset.drop(vars2, axis=1, inplace = False)
newds2
# Out:
#      Sepal_Length  Sepal_Width     Flower_Name
# 0             5.1          3.5     Iris-setosa
# 1             4.9          3.0     Iris-setosa
# 2             4.7          3.2     Iris-setosa
# 3             4.6          3.1     Iris-setosa
# 4             5.0          3.6     Iris-setosa
# ..            ...          ...             ...
# 145           6.7          3.0  Iris-virginica
# 146           6.3          2.5  Iris-virginica
# 147           6.5          3.0  Iris-virginica
# 148           6.2          3.4  Iris-virginica
# 149           5.9          3.0  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ##5. Create a new dataset containing the setal width and length and the type of Flower encoded as a categorical numerical column

# %%
flower_mapping = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
newds3=dataset
newds3['Encoded_Flower'] = newds3['Flower_Name'].map(flower_mapping)
newds3 = newds3[['Sepal_Length', 'Sepal_Width', 'Encoded_Flower']]
newds3
# Out:
#      Sepal_Length  Sepal_Width  Encoded_Flower
# 0             5.1          3.5               0
# 1             4.9          3.0               0
# 2             4.7          3.2               0
# 3             4.6          3.1               0
# 4             5.0          3.6               0
# ..            ...          ...             ...
# 145           6.7          3.0               2
# 146           6.3          2.5               2
# 147           6.5          3.0               2
# 148           6.2          3.4               2
# 149           5.9          3.0               2
#
# [150 rows x 3 columns]

# %% [markdown]
# #Activity 3: work with the iris dataset

# %% [markdown]
# ##1. Plot the histograms for each of the four quantitative variables

# %%
#Histograma del Sepal_Length
sns.histplot(dataset.Sepal_Length,kde=True)
plt.title("Histograma del Sepal_Length")
plt.show()
#Histograma del Sepal_Width
sns.histplot(dataset.Sepal_Width	,kde=True)
plt.title("Histograma del Sepal_Width")
plt.show()
#Histograma del Petal_Length
sns.histplot(dataset.Petal_Length,kde=True)
plt.title("Histograma del Petal_Length")
plt.show()
#Histograma del Petal_Width
sns.histplot(dataset.Petal_Width,kde=True)
plt.title("Histograma del Petal_Width")
plt.show()

# %% [markdown]
# ##2. Plot the histograms for each of the quantitative variables

# %%
#Histograma del Sepal_Length
sns.histplot(dataset.Sepal_Length,kde=True)
plt.title("Histograma del Sepal_Length")
plt.show()
#Histograma del Sepal_Width
sns.histplot(dataset.Sepal_Width	,kde=True)
plt.title("Histograma del Sepal_Width")
plt.show()
#Histograma del Petal_Length
sns.histplot(dataset.Petal_Length,kde=True)
plt.title("Histograma del Petal_Length")
plt.show()
#Histograma del Petal_Width
sns.histplot(dataset.Petal_Width,kde=True)
plt.title("Histograma del Petal_Width")
plt.show()
#Histograma del Flower_Name
sns.histplot(dataset.Flower_Name,kde=True)
plt.title("Histograma del Flower_Name")
plt.show()

# %% [markdown]
# ##3. Plot the boxplots for each of the quantitative variables

# %%
sns.boxplot(dataset["Sepal_Length"])
plt.title("Bloxplot del Sepal_Length")
plt.show()

sns.boxplot(dataset["Sepal_Width"])
plt.title("Bloxplot del Sepal_Width")
plt.show()

sns.boxplot(dataset["Petal_Length"])
plt.title("Bloxplot del Petal_Length")
plt.show()

sns.boxplot(dataset["Petal_Width"])
plt.title("Bloxplot del Petal_Width")
plt.show()

# %% [markdown]
# ##4. Plot the boxplots of the petal width grouped by type of flower

# %%
sns.boxplot(data=dataset,x="Petal_Width", y="Flower_Name")
plt.title("Boxplots de Petal_Width con Flower_Name")
plt.show()

# %% [markdown]
# ##5. Plot the boxplots of the setal length grouped by type of flower

# %%
sns.boxplot(data=dataset,x="Petal_Length", y="Flower_Name")
plt.title("Boxplots de Petal_Length con Flower_Name")
plt.show()

# %% [markdown]
# ##6. Provide a description (explaination from your observations) of each of the quantitative variables
#
#
# Para cada caso de las distintas variables, empecemos primero para lo que son el tipo de flor que son o el nombre de la flor, la cantidad de apariciones para cada tipo de flor es el mismo, esto quiere decir que cada tipo de flor son 50 diferentes.
#
# Ahora para lo que son es el longitud de los petalos, podemos ver que en las plantas que son de tipo iris-virginica son las mas propensas a tener una mayor longitud en el petalo, luego seguiria lo que es la iris-versicolory por ultimo la iris-setosa siendo a la de menor longitud.
#
# Ahora para el ancho de los petalos podemos ver que en las plantas que son de tipo iris-virginica son las mas propensas a tener una mayor anchura en el petalo, luego seguiria lo que es la iris-versicolory por ultimo la iris-setosa siendo a la de menor anchura en su petalo.
#
# Para lo que es el ancho del sepalo podemos ver que en las plantas que son de tipo iris-virginica son las mas propensas a tener una mayor anchura en el sépalo de la planta, luego seguiria lo que es la iris-versicolory por ultimo la iris-setosa siendo a la de menor anchura en su sépalo.
#
# Ya en la longitud del sépalo es donde si varia ya que las planta de tipo iris-setosa son las mas propensas a tener una mayor anchura en su sépalo, siguiendoles lo que son las plantas iris-virginica y por ultimo las que son de tipo iris-versicolor, esto quiere decir que estas ultimas son las mas propensas a tener una longitud de sépalo mas chico.
