# %% [markdown]
# # TC1002S Herramientas computacionales: el arte de la analítica
#
# This is a notebook with all your work for the final evidence of this course
#
#
# # Niveles de dominio a demostrar con la evidencia
#
# ### SING0202A
#
# Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.
#
#
# # Student information
#
# - Name: Diego Iván Rodríguez Núñez
#
# - ID: A01644772
#
# - My carreer: ITC

# %% [markdown]
# # Importing libraries

# %%
  # Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/Colab Notebooks/A01644772/TC1002S/NotebooksStudents/A01644772/Archivos/"

else:
    # Define path del proyecto
    Ruta            = ""

# Import the packages that we will be using
import numpy as np                  # For array
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# Note: specific functions of the "sklearn" package will be imported when needed to show concepts easily
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # PART 1
# # Use your assigned dataset

# %% [markdown]
# ## A1 Load data

# %%
# Dataset url
url = Ruta + "A01644772_X.csv"

# Load the dataset
df  = pd.read_csv(url)

df.drop(df.columns[[0]], axis = 1, inplace = True)

# %% [markdown]
# ## A2 Data managment

# %% [markdown]
# Print the first 7 rows

# %%
df.head(7)
# Out:
#          x1        x2        x3        x4        x5
# 0  7.957073  6.270602  6.020038 -3.486643 -6.572833
# 1  4.766637 -8.303079  0.886504  7.738335 -5.174543
# 2  8.379121  8.632838  0.709945 -4.460688 -3.229403
# 3  8.658963  6.715656  3.481143 -4.777430 -0.087965
# 4  5.049063  8.388561  0.238660 -3.502040 -4.104443
# 5 -7.702025  4.695843 -6.482582  6.853105  3.824850
# 6 -3.243659  6.075955 -7.484215  8.316509 -4.390800

# %% [markdown]
# Print the last 4 rows

# %%
df.tail(4)
# Out:
#             x1        x2        x3        x4        x5
# 395   9.091605  3.700511  4.911215 -2.544106  8.946703
# 396  -6.524189  4.875798 -3.932027  5.059456  5.437071
# 397  11.631565  4.841962  6.026820 -6.639001 -4.924242
# 398   7.115573  6.236620  1.553476 -1.575917 -4.016561

# %% [markdown]
# How many rows and columns are in your data?
#
# Use the `shape` method

# %%
df.shape
# Out:
# (399, 5)

# %% [markdown]
# Print the name of all columns
#
# Use the `columns` method

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5'], dtype='object')

# %% [markdown]
# What is the data type in each column
#
# Use the `dtypes` method

# %%
df.dtypes
# Out:
# x1    float64
# x2    float64
# x3    float64
# x4    float64
# x5    float64
# dtype: object

# %% [markdown]
# What is the meaning of rows and columns?

# %%
# Your responses here

# 1) The first row, which was eliminated previosly represents the index of the observations.

# 2) The rest of the data presented in the csv, are numerical non categorical values that can take negative forms and decimals

# %% [markdown]
# Print a statistical summary of your columns

# %%
df.describe()
# Out:
# 0
# 0
# 0
# 0

# %%
# 1) What is the minumum and maximum values of each variable
# x1: min: -10.761983, max: 13.339491
# x2: min: -14.117554, max: 11.779215
# x3: min: -9.702135, max: 8.114570
# x4: min: -10.611310, max: 15.896119
# x5: min: -10.667600, max: 13.665101

# 2) What is the mean and standar deviation of each variable
# x1: mean: 3.022721, std: 5.799338
# x2: mean: 1.420228, std: 6.229709
# x3: mean: 1.084628, std: 4.292788
# x4: mean: 1.404669, std: 6.673092
# x5: mean: -0.091243, std: 6.106694


# 3) What the 25%, 50% and 75% represent?
# x1: 25: -1.173726, 50: 5.095178, 75: 7.080821
# x2: 25: -3.308827, 50: 3.369962, 75: 6.075646
# x3: 25: -1.568154, 50: 2.286084, 75: 4.313635
# x4: 25: -5.084976, 50: 5.084976, 75: 7.621153
# x5: 25: -4.907232, 50: -1.372906, 75: 4.324706

# They represent the distribution of data, meaning the value below which n% of the data falls. The 50 percentile is also the median.

# %% [markdown]
# Rename the columns using the same name with capital letters

# %%
df = df.rename(columns={"x1": "X1", "x2": "X2", "x3": "X3", "x4": "X4", "x5": "X5"})
df
# Out:
#             X1        X2        X3        X4        X5
# 0     7.957073  6.270602  6.020038 -3.486643 -6.572833
# 1     4.766637 -8.303079  0.886504  7.738335 -5.174543
# 2     8.379121  8.632838  0.709945 -4.460688 -3.229403
# 3     8.658963  6.715656  3.481143 -4.777430 -0.087965
# 4     5.049063  8.388561  0.238660 -3.502040 -4.104443
# ..         ...       ...       ...       ...       ...
# 394   6.606360  1.848792  1.506727 -7.042476  7.874441
# 395   9.091605  3.700511  4.911215 -2.544106  8.946703
# 396  -6.524189  4.875798 -3.932027  5.059456  5.437071
# 397  11.631565  4.841962  6.026820 -6.639001 -4.924242
# 398   7.115573  6.236620  1.553476 -1.575917 -4.016561
#
# [399 rows x 5 columns]

# %% [markdown]
# Rename the columns to their original names

# %%
df = df.rename(columns={"X1": "x1", "X2": "x2", "X3": "x3", "X4": "x4", "X5": "x5"})
df
# Out:
#             x1        x2        x3        x4        x5
# 0     7.957073  6.270602  6.020038 -3.486643 -6.572833
# 1     4.766637 -8.303079  0.886504  7.738335 -5.174543
# 2     8.379121  8.632838  0.709945 -4.460688 -3.229403
# 3     8.658963  6.715656  3.481143 -4.777430 -0.087965
# 4     5.049063  8.388561  0.238660 -3.502040 -4.104443
# ..         ...       ...       ...       ...       ...
# 394   6.606360  1.848792  1.506727 -7.042476  7.874441
# 395   9.091605  3.700511  4.911215 -2.544106  8.946703
# 396  -6.524189  4.875798 -3.932027  5.059456  5.437071
# 397  11.631565  4.841962  6.026820 -6.639001 -4.924242
# 398   7.115573  6.236620  1.553476 -1.575917 -4.016561
#
# [399 rows x 5 columns]

# %% [markdown]
# Use two different alternatives to get one of the columns

# %%
print(df.x1)
print(df["x1"])
# Out:
# 0       7.957073
# 1       4.766637
# 2       8.379121
# 3       8.658963
# 4       5.049063
#          ...
# 394     6.606360
# 395     9.091605
# 396    -6.524189
# 397    11.631565
# 398     7.115573
# Name: x1, Length: 399, dtype: float64
# 0       7.957073
# 1       4.766637
# 2       8.379121
# 3       8.658963
# 4       5.049063
#          ...
# 394     6.606360
# 395     9.091605
# 396    -6.524189
# 397    11.631565
# 398     7.115573
# Name: x1, Length: 399, dtype: float64

# %% [markdown]
# Get a slice of your data set: second and thrid columns and rows from 62 to 72

# %%
df.loc[62:72, ["x2", "x3"]]
# Out:
#           x2        x3
# 62 -2.089024  0.667432
# 63  4.480679 -5.410395
# 64  8.734759  6.580646
# 65  4.368254  5.325360
# 66  7.595832  2.872699
# 67  7.576053 -8.345638
# 68  9.520749  3.570326
# 69  6.222036  3.149658
# 70  4.036437 -0.640266
# 71 -1.058879 -1.203109
# 72 -6.449265  2.156229

# %% [markdown]
# For the second and thrid columns, calculate the number of null and not null values and verify that their sum equals the total number of rows

# %%
print(df.x2.isnull().sum() + df.x3.notnull().sum())
print(df.x3.isnull().sum() + df.x3.notnull().sum())
df.shape[0]
# Out:
# 399
# 399
# 399

# %% [markdown]
# Discard the last column

# %%
df.drop("x5", axis = 1, inplace = True)
df.head(3)
# Out:
#          x1        x2        x3        x4
# 0  7.957073  6.270602  6.020038 -3.486643
# 1  4.766637 -8.303079  0.886504  7.738335
# 2  8.379121  8.632838  0.709945 -4.460688

# %% [markdown]
# ### Questions
#
# Based on the previos results, provide a description of yout dataset
#
# Your response:
#
# Based on the analysis provided by .describe() we can now see the range of values that the data can have, which is around -11 and 16 for most of the values. This could describe a lot of phenomenons, like the change in temperatura in a place. Also we can now observe how the data is distributed with the percentiles.

# %% [markdown]
# ## A3 Data visualization

# %% [markdown]
# Plot in the same figure the histogram of two variables

# %%
df_2plot = df[["x1", "x2"]]

sns.histplot(df_2plot, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Based on these plots, provide a description of your data:
#
# Your response here:
# There seems to be a correlation between the variables x1 and x2, because the histograms of both are fairly similar.

# %% [markdown]
# Plot in the same figure the boxplot of two variables

# %%
df_2plot = df[["x1", "x2", "x3", "x4"]]

sns.boxplot(df_2plot)
# Out:
# <Axes: >

# %% [markdown]
# Plot the scatter plot of two variables

# %%
g = sns.pairplot(df, corner =True, diag_kind="kde")
plt.show()

# %% [markdown]
# ### Questions
#
# Based on the previos plots, provide a description of yout dataset
#
# Your response:
#
# In almost all the scatterplots there can be seen an agrupation of data in 3 seperate groups, meaning that this variables could represent the characteristics of 3 diferent objects.

# %% [markdown]
# ## A4 Kmeans

# %% [markdown]
# Do Kmeans clustering assuming a number of clusters accorging to your scatter plot

# %%
# Import sklearn KMeans
from sklearn.cluster import KMeans

# Define number of clusters
K  = 3

# Create/Initialize the Kmeans box/object
km = KMeans(n_clusters=K, n_init="auto")

# Do K-means clustering (assing each point in the dataset to a cluster)
#yestimated = km.fit_predict(df)
yestimated = km.fit_predict(df)
#yestimated = km.fit_predict(df[['x1','x3']] )

# Print estimated cluster of each point in the dataset
yestimated

# Add a new column to the dataset with the cluster information
df['yestimated'] = yestimated

df

# Print the Labels/Names of the existing clusters
df.yestimated.unique()

# Cluster centroides
km.cluster_centers_

# Sum of squared error (sse) of the final model
km.inertia_

# The number of iterations required to converge
km.n_iter_

# Get a dataframe with the data of each clsuter
df0 = df[df.yestimated==0]
df1 = df[df.yestimated==1]
df2 = df[df.yestimated==2]

# Number of points in cluster 0
NpointsCluster0 = df0.shape[0]
NpointsCluster1 = df1.shape[0]
NpointsCluster2 = df2.shape[0]

# Print
print("Number of points in clusters 0: " + str(NpointsCluster0) )
print("Number of points in clusters 1: " + str(NpointsCluster1) )
print("Number of points in clusters 02: " + str(NpointsCluster2) )

# Print total number of points
print("Total Number of points in the clusters: " + str(NpointsCluster0+NpointsCluster1+NpointsCluster2) )

# Get a dataframe with the data of each clsuter
df1 = df[df.yestimated==0]
df2 = df[df.yestimated==1]
df3 = df[df.yestimated==2]

# Scatter plot of each cluster
plt.scatter(df1.x1, df1.x2, label='Cluster 0', c='r', marker='o', s=32, alpha=0.3)
plt.scatter(df2.x1, df2.x2, label='Cluster 1', c='g', marker='o', s=32, alpha=0.3)
plt.scatter(df3.x1, df3.x2, label='Cluster 2', c='b', marker='o', s=32, alpha=0.3)

# Plot centrodides
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color='black', marker='*', label='Centroides', s=256)

plt.title('Scatter plot (for each cluster)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()
# Out:
# Number of points in clusters 0: 100
# Number of points in clusters 1: 199
# Number of points in clusters 02: 100
# Total Number of points in the clusters: 399

# %% [markdown]
# Add to your dataset a column with the estimated cluster to each data point

# %%
df["Cluster"] = yestimated
df
# Out:
#             x1        x2        x3        x4  Cluster
# 0     7.957073  6.270602  6.020038 -3.486643        1
# 1     4.766637 -8.303079  0.886504  7.738335        2
# 2     8.379121  8.632838  0.709945 -4.460688        1
# 3     8.658963  6.715656  3.481143 -4.777430        1
# 4     5.049063  8.388561  0.238660 -3.502040        1
# ..         ...       ...       ...       ...      ...
# 394   6.606360  1.848792  1.506727 -7.042476        1
# 395   9.091605  3.700511  4.911215 -2.544106        1
# 396  -6.524189  4.875798 -3.932027  5.059456        0
# 397  11.631565  4.841962  6.026820 -6.639001        1
# 398   7.115573  6.236620  1.553476 -1.575917        1
#
# [399 rows x 5 columns]

# %% [markdown]
# Print the number associated to each cluster

# %%
df.Cluster
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    0
# 397    1
# 398    1
# Name: Cluster, Length: 399, dtype: int32

# %% [markdown]
# Print the centroids

# %%
print(km.cluster_centers_)
# Out:
# [[-6.07272729  5.48130634 -5.29802178  8.81472209]
#  [ 7.18429362  4.26871712  3.01168836 -4.92664204]
#  [ 3.83663829 -8.30934458  3.63242766  6.59392632]]

# %% [markdown]
# Print the intertia metric

# %%
print(km.inertia_)
# Out:
# 7750.6837290709755

# %% [markdown]
# Plot a scatter plot of your data using different color for each cluster. Also plot the centroids

# %%
# Scatter plot of each cluster
plt.scatter(df1.x1, df1.x2, label='Cluster 0', c='r', marker='o', s=32, alpha=0.3)
plt.scatter(df2.x1, df2.x2, label='Cluster 1', c='g', marker='o', s=32, alpha=0.3)
plt.scatter(df3.x1, df3.x2, label='Cluster 2', c='b', marker='o', s=32, alpha=0.3)

# Plot centrodides
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color='black', marker='*', label='Centroides', s=256)

plt.title('Scatter plot (for each cluster)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %% [markdown]
# ### Questions
#
# Provides a detailed description of your results
#
# Your response: The hypotesis seems to be correct, since the 3 groups previously mencioned are represented in the scatterplot and they are clearly separated.

# %% [markdown]
# ## A5 Elbow plot
#
# Compute the Elbow plot

# %%
# Intialize a list to hold sum of squared error (sse)
sse = []

# Define values of k
k_rng = range(1,10)

# For each k
for k in k_rng:
    # Create model
    km = KMeans(n_clusters=k, n_init="auto")
    # Do K-means clustering
    km.fit_predict(df)
    # Save sse for each k
    sse.append(km.inertia_)

# Plot sse versus k
plt.plot(k_rng,sse, 'o-', markersize=8)

plt.title('Elbow plot')
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.show()

# %% [markdown]
# ### Questions
#
# What is the best number of clusters K? (argue your response)
#
# Your response: 3, because is the inflection point where the sum of squared error starts having little to rest of numbers of clusters. Also, using less clusters results in a higher error, using more clusters results in longer computing time for almost the same result as 3.
#
#
# Does this number of clusters agree with your inital guess? (argue your response, no problem at all if they do not agree)
#
# Your response: Yes, because I was able to infer correctly from the scatterplots what the best number of clusters could be.

# %% [markdown]
# # PART 2
# # Descipcion de tu percepcion del nivel de desarrollo de la subcompetencia
#
# ### SING0202A Interpretación de variables

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Interpreta interacciones**. Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo.

# %% [markdown]
# Durante esta semana aprendí a realizar mejores análisis de relaciones entre variables de datos, esto gracias al uso de scatterplots y las herramientas que pandas seaborn y python proporcionan. Por esto, concluyo que tuve un nivel de logro alto en el desarrollo de esta subcompetencia

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Construcción de modelos**. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.

# %% [markdown]
# Tu respuesta:
#
# A mi parecer tuve un desarrollo significativo en esta competencia, pues antes de realizar esta semanaTec había realizado solo un modelo matemático de regresión lineal, nunca algo de mayor complejidad. Ahora soy capaz de usar el método de kmeans para explicar relaciones entre variables y predecir comportamientos en base a estos.
