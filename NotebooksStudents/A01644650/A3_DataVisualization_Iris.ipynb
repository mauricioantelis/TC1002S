# %% [markdown]
# # Classification (supervised learning)
#
# The notebook aims to study and implement classification (supervised learning) using "sklearn". The iris dataset will be used to classify.
#
#
# ## Acknowledgments
#
# - Used dataset: https://archive.ics.uci.edu/ml/datasets/iris
#
# - Inquiries: mauricio.antelis@tec.mx

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import numpy as np                  # For array
import pandas as pd                 # For data handling
import seaborn as sns               # For advanced plotting
import matplotlib.pyplot as plt     # For showing plots

# Note: specific functions of the "sklearn" package will be imported when needed to show concepts easily

# %% [markdown]
# # Importing data

# %%
# Define the col names for the iris dataset
colnames = ["Sepal_Length", "Sepal_Width","Petal_Length","Petal_Width", "Flower"]

# Dataset url
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Load the dataset from HHDD
dataset  = pd.read_csv(url, header = None, names = colnames )

dataset
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width          Flower
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Undertanding and preprocessing the data
#
# 1. Get a general 'feel' of the data

# %%
# Print dataset
dataset.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width       Flower
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Print dataset shape
print(dataset.shape)
# Out:
# (150, 5)

# %%
# Print column names
dataset.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Flower'], dtype='object')

# %%
#Data types
dataset.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Flower           object
# dtype: object

# %% [markdown]
# 2. Drop rows with any missing values

# %%
# Drop na
dataset = dataset .dropna()

print(dataset.shape)
# Out:
# (150, 5)

# %% [markdown]
# 3. Encoding the class label categorical column: from string to num

# %%
# Encoding the categorical column: {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2}
dataset = dataset.replace({"Flower":  {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2} })

#Visualize the dataset
dataset
# Out:
# <ipython-input-8-6cf562935661>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace({"Flower":  {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2} })
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Flower
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %% [markdown]
# Now the label/category is numeric

# %% [markdown]
# 4. Discard columns that won't be used

# %%
# # Drop out non necesary columns
dataset.drop(['Sepal_Length', 'Sepal_Width'],axis='columns',inplace=True)
#
# #Visualize the dataset
dataset
# Out:
#      Petal_Length  Petal_Width  Flower
# 0             1.4          0.2       0
# 1             1.4          0.2       0
# 2             1.3          0.2       0
# 3             1.5          0.2       0
# 4             1.4          0.2       0
# ..            ...          ...     ...
# 145           5.2          2.3       2
# 146           5.0          1.9       2
# 147           5.2          2.0       2
# 148           5.4          2.3       2
# 149           5.1          1.8       2
#
# [150 rows x 3 columns]

# %% [markdown]
# 5. Scatter plot of the data

# %%
# Scatter plot of Petal_Length vs Petal_Width
plt.scatter(dataset.Petal_Length,dataset.Petal_Width)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
dataset  = pd.read_csv(url, header = None, names = colnames )
# Encoding the categorical column: {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2}
dataset = dataset.replace({"Flower":  {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2} })
# Scatter plot of Petal_Length vs Sepal_Length
plt.scatter(dataset.Petal_Length,dataset.Sepal_Length)
plt.xlabel('Petal Length')
plt.ylabel('Sepal Length')
plt.show()
# Out:
# <ipython-input-11-21a294bf9579>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace({"Flower":  {"Iris-setosa":0, "Iris-versicolor":1, "Iris-virginica":2} })

# %%
# Scatter plot of Petal_Length vs Sepal_Width
plt.scatter(dataset.Petal_Length,dataset.Sepal_Width)
plt.xlabel('Petal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# Scatter plot of Petal_Width vs Sepal_Length
plt.scatter(dataset.Petal_Width,dataset.Sepal_Length)
plt.xlabel('Petal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
# Scatter plot of Petal_Width vs Sepal_Width
plt.scatter(dataset.Petal_Width,dataset.Sepal_Width)
plt.xlabel('Petal Width')
plt.ylabel('Sepal Width')
plt.show()

# %%
# Scatter plot of Sepal_Length vs Sepal_Width
plt.scatter(dataset.Sepal_Length,dataset.Sepal_Width)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
# Pairplot: Scatterplot of all variables (not the flower type)
g = sns.pairplot(dataset[['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width']], corner=True, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")
plt.show()

# %%
# Pairplot: Scatterplot of all variables (not the flower type)
g = sns.pairplot(dataset, corner=True, diag_kind="kde", hue='Flower')
g.map_lower(sns.kdeplot, levels=4, color=".2")
plt.show()

# %% [markdown]
# 6. Scatter plot of the data asigning each point to the cluster it belongs to ¡¡

# %%
# Get dataframes for each real cluster
df1 = dataset[dataset.Flower==0]
df2 = dataset[dataset.Flower==1]
df3 = dataset[dataset.Flower==2]

# %%
# Scatter plot of each real cluster for Petal
plt.scatter(df1.Petal_Length, df1.Petal_Width, label='Flower type 0', c='r', marker='o', s=64, alpha=0.3)
plt.scatter(df2.Petal_Length, df2.Petal_Width, label='Flower type 1', c='g', marker='o', s=64, alpha=0.3)
plt.scatter(df3.Petal_Length, df3.Petal_Width, label='Flower type 2', c='b', marker='o', s=64, alpha=0.3)

plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend()
plt.show()

# %%
# Scatter plot of each real cluster for Sepal
plt.scatter(df1.Sepal_Length, df1.Sepal_Width, label='Flower type 0', c='r', marker='o', s=64, alpha=0.3)
plt.scatter(df2.Sepal_Length, df2.Sepal_Width, label='Flower type 1', c='g', marker='o', s=64, alpha=0.3)
plt.scatter(df3.Sepal_Length, df3.Sepal_Width, label='Flower type 2', c='b', marker='o', s=64, alpha=0.3)

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()

# %%
#Min,Max,Mean,Median,Stardard Deviation
print(dataset.min())
print(dataset.max())
print(dataset.mean(numeric_only=True))
print(dataset.median(numeric_only=True))
print(dataset.std(numeric_only=True))
# Out:
# Sepal_Length    4.3
# Sepal_Width     2.0
# Petal_Length    1.0
# Petal_Width     0.1
# Flower          0.0
# dtype: float64
# Sepal_Length    7.9
# Sepal_Width     4.4
# Petal_Length    6.9
# Petal_Width     2.5
# Flower          2.0
# dtype: float64
# Sepal_Length    5.843333
# Sepal_Width     3.054000
# Petal_Length    3.758667
# Petal_Width     1.198667
# Flower          1.000000
# dtype: float64
# Sepal_Length    5.80
# Sepal_Width     3.00
# Petal_Length    4.35
# Petal_Width     1.30
# Flower          1.00
# dtype: float64
# Sepal_Length    0.828066
# Sepal_Width     0.433594
# Petal_Length    1.764420
# Petal_Width     0.763161
# Flower          0.819232
# dtype: float64

# %%
#Check for missiong data
pd.isnull(dataset).sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Flower          0
# dtype: int64

# %%
Nosep=dataset.drop(['Sepal_Length', 'Sepal_Width'],axis='columns')
Nosep
# Out:
#      Petal_Length  Petal_Width  Flower
# 0             1.4          0.2       0
# 1             1.4          0.2       0
# 2             1.3          0.2       0
# 3             1.5          0.2       0
# 4             1.4          0.2       0
# ..            ...          ...     ...
# 145           5.2          2.3       2
# 146           5.0          1.9       2
# 147           5.2          2.0       2
# 148           5.4          2.3       2
# 149           5.1          1.8       2
#
# [150 rows x 3 columns]

# %%
Nopet=dataset.drop(['Petal_Length', 'Petal_Width'],axis='columns')
Nopet
# Out:
#      Sepal_Length  Sepal_Width  Flower
# 0             5.1          3.5       0
# 1             4.9          3.0       0
# 2             4.7          3.2       0
# 3             4.6          3.1       0
# 4             5.0          3.6       0
# ..            ...          ...     ...
# 145           6.7          3.0       2
# 146           6.3          2.5       2
# 147           6.5          3.0       2
# 148           6.2          3.4       2
# 149           5.9          3.0       2
#
# [150 rows x 3 columns]

# %%
dataset['Flower_encoded'] = dataset['Flower'].astype('category').cat.codes
Encoded=dataset[['Sepal_Length', 'Sepal_Width', 'Flower_encoded']]
Encoded
# Out:
#      Sepal_Length  Sepal_Width  Flower_encoded
# 0             5.1          3.5               0
# 1             4.9          3.0               0
# 2             4.7          3.2               0
# 3             4.6          3.1               0
# 4             5.0          3.6               0
# ..            ...          ...             ...
# 145           6.7          3.0               2
# 146           6.3          2.5               2
# 147           6.5          3.0               2
# 148           6.2          3.4               2
# 149           5.9          3.0               2
#
# [150 rows x 3 columns]

# %%
# Plot the histograms for each of the four quantitative variables combined
sns.histplot(data=dataset, x="Sepal_Length")
sns.histplot(data=dataset, x="Sepal_Width")
sns.histplot(data=dataset, x="Petal_Length")
sns.histplot(data=dataset, x="Petal_Width")
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Count'>

# %%
sns.histplot(data=dataset, x="Sepal_Length")
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Count'>

# %% [markdown]
# Este histograma muestra la longitud del sepalo de distintas flores y la cantidad de cada una.

# %%
sns.histplot(data=dataset, x="Sepal_Width")
# Out:
# <Axes: xlabel='Sepal_Width', ylabel='Count'>

# %% [markdown]
# El histograma muestra la anchura del sepalo de distintas flores y cuantas hay de cada una.

# %%
sns.histplot(data=dataset, x="Petal_Length")
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Count'>

# %% [markdown]
# Este histograma muestra los datos de longitud de petalo de distintas flores y cuantas hay de cada longitud

# %%
sns.histplot(data=dataset, x="Petal_Width")
# Out:
# <Axes: xlabel='Petal_Width', ylabel='Count'>

# %% [markdown]
# El histograma previo muestra los datos de distitas flores mostrando su anchura de petalo

# %%
# Plot the boxplots of the petal width grouped by type of flower
sns.boxplot(x="Flower", y="Petal_Width", data=dataset)
# Out:
# <Axes: xlabel='Flower', ylabel='Petal_Width'>

# %%
#Plot the boxplots of the sepal length grouped by type of flower
sns.boxplot(x="Flower", y="Sepal_Length", data=dataset)
# Out:
# <Axes: xlabel='Flower', ylabel='Sepal_Length'>

# %% [markdown]
# Recall that for this dataset we know in advance the class to which each point belongs to
