# %% [markdown]
# #Leer Datos con Pandas
#
# El objetivo de este notebook es leer el archivo de datos .csv con la información del dataset

# %% [markdown]
# #Definiciones

# %% [markdown]
# #Import libraries

# %%
#Import packages
import pandas as pd

# %%
#Montar Drive
from google.colab import drive

#Mount the Google Drive at /content/drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/MyDrive/Data/
# Out:
# cartwheel.csv

# %% [markdown]
# #Leer datos

# %%
#Lectura de los datos.
file_path = '/content/drive/MyDrive/Data/cartwheel.csv'

#Read the CSV file into a pandas Dataframe

df = pd.read_csv(file_path)

# %%
#Get number of rows
NRows = df.shape[0]

#Print the number of rows
print('The number of rows is: ' + str(NRows))
# Out:
# The number of rows is: 52

# %%
#Get number of columns
NColumns = df.shape[1]

#Print the number of columns
print('The number of columns is: ' + str(NColumns))
# Out:
# The number of columns is: 12

# %%
#Print name of columns

df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
#Obtener data sobre una columna
df.Gender
# Out:
# 0     F
# 1     F
# 2     F
# 3     F
# 4     M
# 5     M
# 6     M
# 7     F
# 8     M
# 9     F
# 10    M
# 11    F
# 12    F
# 13    F
# 14    M
# 15    M
# 16    F
# 17    M
# 18    M
# 19    F
# 20    M
# 21    M
# 22    M
# 23    M
# 24    F
# 25    M
# 26    M
# 27    M
# 28    F
# 29    F
# 30    F
# 31    F
# 32    F
# 33    M
# 34    F
# 35    M
# 36    F
# 37    F
# 38    M
# 39    M
# 40    F
# 41    M
# 42    F
# 43    F
# 44    F
# 45    F
# 46    M
# 47    M
# 48    M
# 49    F
# 50    M
# 51    M
# Name: Gender, dtype: object

# %%
#Obtener un dataframe con algunas columnas

df2 = df[['Age','Height','Wingspan','CWDistance']]
df2
# Out:
#      Age  Height  Wingspan  CWDistance
# 0   56.0   62.00      61.0          79
# 1   26.0   62.00      60.0          70
# 2   33.0   66.00      64.0          85
# 3   39.0   64.00      63.0          87
# 4   27.0   73.00      75.0          72
# 5   24.0   75.00      71.0          81
# 6   28.0   75.00      76.0         107
# 7   22.0   65.00      62.0          98
# 8   29.0   74.00      73.0         106
# 9   33.0   63.00      60.0          65
# 10  30.0   69.50      66.0          96
# 11  28.0   62.75      58.0          79
# 12  25.0   65.00      64.5          92
# 13  23.0   61.50      57.5          66
# 14  31.0   73.00      74.0          72
# 15  26.0   71.00      72.0         115
# 16  26.0   61.50      59.5          90
# 17  27.0   66.00      66.0          74
# 18  23.0   70.00      69.0          64
# 19  24.0   68.00      66.0          85
# 20  23.0   69.00      67.0          66
# 21  29.0   71.00      70.0         101
# 22  25.0   70.00      68.0          82
# ...

# %% [markdown]
# #Estadistica de las variables

# %%
#Get Means
meanAge = df['Age'].mean()
meanAge
# Out:
# 28.41176470588235

# %%
#Get Median
medHeight = df['Height'].median()
medHeight
# Out:
# 69.0
