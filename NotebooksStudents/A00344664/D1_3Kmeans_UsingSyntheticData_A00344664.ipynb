# %% [markdown]
# # K-means clustering
#
# The notebook aims to study and implement a k-means clustering using "sklearn". A synthetic dataset will be used to identify clusters automatically using the K-means method.
#
#
# ## Acknowledgments
#
# - Inquiries: mauricio.antelis@tec.miris_sanitized

# %% [markdown]
# # Activity: work with the iris dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


_irs_src_ = "datasets/iris/iris.csv"
iris_columns = ["sepal length", "sepal width", "petal length", "petal width", "Flower_Type"]
iris_data = pd.read_csv(_irs_src_, names=iris_columns)

# %%
sns.scatterplot(data=iris_data)
# Out:
# <Axes: >

# %%
iris_data["Flower_Type"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# 1. Do clustering with the iris flower dataset to form clusters using as features the four features

# %%
iris_sanitized = iris_data.iloc[:, :-1]
iris_sanitized
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
clusters_number = 3
# Initilialize kmeans object
k_means = KMeans(n_clusters=clusters_number,
                init='k-means++',
                max_iter=300,
                n_init=10,
                random_state=0)
y_kmeans = k_means.fit_predict(iris_sanitized)

# %%
iris_colum = iris_data.columns
iris_colum
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width',
#        'Flower_Type'],
#       dtype='object')

# %%
plt.scatter(iris_sanitized.loc[y_kmeans == 0, iris_colum[0]],
            iris_sanitized.loc[y_kmeans == 0, iris_colum[1]],
            s=100, c='green',
            label='Iris-setosa')
plt.scatter(iris_sanitized.loc[y_kmeans == 1, iris_colum[0]],
            iris_sanitized.loc[y_kmeans == 1, iris_colum[1]],
            s=100, c='purple',
            label='Iris-versicolour')
plt.scatter(iris_sanitized.loc[y_kmeans == 2, iris_colum[0]],
            iris_sanitized.loc[y_kmeans == 2, iris_colum[1]],
            s=100, c='blue',
            label='Iris-virginica')
plt.scatter(k_means.cluster_centers_[:, 0],
            k_means.cluster_centers_[:, 1],
            s=100, c='orange',
            label='Centroids')
plt.title("KMeans (Sepal length vs Sepal width)")
plt.legend()

# %% [markdown]
# 2. Do clustering with the iris flower dataset to form clusters using as features the two petal measurements: Drop out the other two features

# %%
keep = ['petal width', 'petal length']
petal_data = iris_data[keep]
petal_data
# Out:
#      petal width  petal length
# 0            0.2           1.4
# 1            0.2           1.4
# 2            0.2           1.3
# 3            0.2           1.5
# 4            0.2           1.4
# ..           ...           ...
# 145          2.3           5.2
# 146          1.9           5.0
# 147          2.0           5.2
# 148          2.3           5.4
# 149          1.8           5.1
#
# [150 rows x 2 columns]

# %%
clusters_number = 3
# Initilialize kmeans object
k_means = KMeans(n_clusters=clusters_number,
                init='k-means++',
                max_iter=300,
                n_init=10,
                random_state=0)
y_kmeans = k_means.fit_predict(petal_data)

# %%
# Scater petal with vs petal length for type iris setosa, with y_kmeans of 0
plt.scatter(petal_data.loc[y_kmeans == 0, "petal width"],
            petal_data.loc[y_kmeans == 0, "petal length"],
            s=100, c='green',
            label='Iris-setosa')
# Scater  petal with vs petal length for type iris setosa, with y_kmeans of 0
plt.scatter(petal_data.loc[y_kmeans == 1, "petal width"],
            petal_data.loc[y_kmeans == 1, "petal length"],
            s=100, c='purple',
            label='Iris-versicolour')
# Scater  petal with vs petal length fir type iris setosa, with y_kmeans of 0
plt.scatter(petal_data.loc[y_kmeans == 2, "petal width"],
            petal_data.loc[y_kmeans == 2, "petal length"],
            s=100, c='blue',
            label='Iris-virginica')
# Plot the centroids stored in the kmean object
plt.scatter(k_means.cluster_centers_[:, 0],
            k_means.cluster_centers_[:, 1],
            s=100, c='orange',
            label='Centroids')
  
plt.title("KMeans (Petal width vs Petal length)")
plt.legend()

# %% [markdown]
# 3. Do clustering with the iris flower dataset to form clusters using as features the two sepal measurements: Drop out the other two features

# %%
keep = ['sepal width', 'sepal length']
sepal_data = iris_data[keep]
sepal_data
# Out:
#      sepal width  sepal length
# 0            3.5           5.1
# 1            3.0           4.9
# 2            3.2           4.7
# 3            3.1           4.6
# 4            3.6           5.0
# ..           ...           ...
# 145          3.0           6.7
# 146          2.5           6.3
# 147          3.0           6.5
# 148          3.4           6.2
# 149          3.0           5.9
#
# [150 rows x 2 columns]

# %%
clusters_number = 3
# Initilialize kmeans object
k_means = KMeans(n_clusters=clusters_number,
                init='k-means++',
                max_iter=300,
                n_init=10,
                random_state=0)
y_kmeans = k_means.fit_predict(sepal_data)

# %%
# Scater petal with vs petal length for type iris setosa, with y_kmeans of 0
plt.scatter(sepal_data.loc[y_kmeans == 0, "sepal width"],
            sepal_data.loc[y_kmeans == 0, "sepal length"],
            s=100, c='green',
            label='Iris-setosa')
# Scater  sepal with vs sepal length for type iris setosa, with y_kmeans of 0
plt.scatter(sepal_data.loc[y_kmeans == 1, "sepal width"],
            sepal_data.loc[y_kmeans == 1, "sepal length"],
            s=100, c='purple',
            label='Iris-versicolour')
# Scater  sepal with vs sepal length fir type iris setosa, with y_kmeans of 0
plt.scatter(sepal_data.loc[y_kmeans == 2, "sepal width"],
            sepal_data.loc[y_kmeans == 2, "sepal length"],
            s=100, c='blue',
            label='Iris-virginica')
# Plot the centroids stored in the kmean object
plt.scatter(k_means.cluster_centers_[:, 0],
            k_means.cluster_centers_[:, 1],
            s=100, c='orange',
            label='Centroids')
  
plt.title("KMeans (Sepal width vs Sepal length)")
plt.legend()

# %% [markdown]
# 4. Which one provides the better grouping? Solve this using programming skills, e.g., compute performance metrics

# %%
sns.FacetGrid(iris_data,hue="Flower_Type").map(sns.distplot,"petal length").add_legend()
sns.FacetGrid(iris_data,hue="Flower_Type").map(sns.distplot,"petal width").add_legend()
sns.FacetGrid(iris_data,hue="Flower_Type").map(sns.distplot,"sepal length").add_legend()
sns.FacetGrid(iris_data,hue="Flower_Type").map(sns.distplot,"sepal width").add_legend()
plt.title("Distribution of values")
plt.show()
# Out:
# /home/paok/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /home/paok/.local/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# As we can see in this graphs that ilustrate the density of values for the different species, the data for petals presents a clearer difference between species; fact that coincides with the scatter plot obtained.
