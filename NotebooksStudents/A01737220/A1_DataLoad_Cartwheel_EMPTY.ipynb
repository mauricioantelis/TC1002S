# %% [markdown]
# #Leer datos
#
# El objetivo de este notebook es leer el archivo de datos .csv con la información del dataset cartwheel.

# %% [markdown]
# #Definiciones

# %%
#Aqui van las definiciones

#rutadatos = TDB

# %% [markdown]
# #Import libraries

# %%
#import pakages
import pandas as pd

# %%
#montar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "drive/MyDrive/TEC - ITC/ago - dic 2024/semanas tec/TC1002S/NotebooksProfessor/cartwheel/"
# Out:
# cartwheel.csv

# %% [markdown]
# #Leer datos
#
# Cargar el archivo de datos y ponerlo en un dataframe de pandas

# %%
#Define the file path
file_path = "drive/MyDrive/TEC - ITC/ago - dic 2024/semanas tec/TC1002S/NotebooksProfessor/cartwheel/cartwheel.csv"

# %%
#Read the CVS file intoo a pandas DataFrame
df = pd.read_csv(file_path)

# %%
df
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %%
#get the number of  rows
df.shape[0]
# Out:
# 52

# %%
#get the number of columns
df.shape[1]
# Out:
# 12

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
#obtener datos de una columna
#df.age
df['Age']
# Out:
# 0     56.0
# 1     26.0
# 2     33.0
# 3     39.0
# 4     27.0
# 5     24.0
# 6     28.0
# 7     22.0
# 8     29.0
# 9     33.0
# 10    30.0
# 11    28.0
# 12    25.0
# 13    23.0
# 14    31.0
# 15    26.0
# 16    26.0
# 17    27.0
# 18    23.0
# 19    24.0
# 20    23.0
# 21    29.0
# 22    25.0
# 23    26.0
# 24    23.0
# 25    28.0
# 26    24.0
# 27    25.0
# 28    32.0
# 29    38.0
# 30    27.0
# 31    33.0
# 32    38.0
# 33    27.0
# 34    24.0
# 35    27.0
# 36    25.0
# 37    26.0
# 38    31.0
# 39    30.0
# 40    23.0
# 41    26.0
# 42    28.0
# 43    26.0
# 44    30.0
# 45    39.0
# 46    27.0
# 47    24.0
# 48    28.0
# 49    30.0
# 50     NaN
# 51    27.0
# Name: Age, dtype: float64

# %%
#obtener un nuevo dataframe con algunas columnas

df2  = df[['Age','Gender','Height','Wingspan','CWDistance']]
df2
# Out:
#      Age Gender  Height  Wingspan  CWDistance
# 0   56.0      F   62.00      61.0          79
# 1   26.0      F   62.00      60.0          70
# 2   33.0      F   66.00      64.0          85
# 3   39.0      F   64.00      63.0          87
# 4   27.0      M   73.00      75.0          72
# 5   24.0      M   75.00      71.0          81
# 6   28.0      M   75.00      76.0         107
# 7   22.0      F   65.00      62.0          98
# 8   29.0      M   74.00      73.0         106
# 9   33.0      F   63.00      60.0          65
# 10  30.0      M   69.50      66.0          96
# 11  28.0      F   62.75      58.0          79
# 12  25.0      F   65.00      64.5          92
# 13  23.0      F   61.50      57.5          66
# 14  31.0      M   73.00      74.0          72
# 15  26.0      M   71.00      72.0         115
# 16  26.0      F   61.50      59.5          90
# 17  27.0      M   66.00      66.0          74
# 18  23.0      M   70.00      69.0          64
# ...

# %%
df2.tail(10)
# Out:
#      Age Gender  Height  Wingspan  CWDistance
# 42  28.0      F    72.5      72.0          81
# 43  26.0      F    72.0      72.0          92
# 44  30.0      F    66.0      64.0          85
# 45  39.0      F    64.0      63.0          87
# 46  27.0      M    78.0      75.0          72
# 47  24.0      M    79.5      75.0          82
# 48  28.0      M    77.8      76.0          99
# 49  30.0      F    74.6       NaN          71
# 50   NaN      M    71.0      70.0         101
# 51  27.0      M     NaN      71.5         103

# %%
#identificar rows
df2.iloc[0]
# Out:
# Age           56.0
# Gender           F
# Height        62.0
# Wingspan      61.0
# CWDistance      79
# Name: 0, dtype: object

# %% [markdown]
# #Estadística de las variables
#
# Calcular e imprimir estadistica descriptiva

# %%
#imprimir estadisticas descriptivas
df2.describe()
# Out:
#              Age     Height   Wingspan  CWDistance
# count  51.000000  51.000000  51.000000   52.000000
# mean   28.411765  68.971569  67.313725   85.576923
# std     5.755611   5.303812   5.624021   14.353173
# min    22.000000  61.500000  57.500000   63.000000
# 25%    25.000000  64.500000  63.000000   72.000000
# 50%    27.000000  69.000000  66.000000   85.000000
# 75%    30.000000  73.000000  72.000000   96.500000
# max    56.000000  79.500000  76.000000  115.000000
