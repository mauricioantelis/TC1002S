# %% [markdown]
# # Understanding the cartwheel data set
#
# The notebook aims to undertand the content of the cartwheel data set.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Cartwheel data set
#
# 1. A cartwheel
#
# ![cartwheel1.png](datasets/cartwheel/cartwheel1.png)
#
# 2. The dataset description
#     - The dataset used here is an extension from the original cartwheel dataset from cursera
#     - Total numer of observations: 28
#     - Many observations/measurements/recordings of the characteristics/attributes/variables of cartwheel executions
#     - Variables: Age, Gender, GenderGroup, Glasses, GlassesGroup, Height, Wingspan, CWDistance, ... (X variables)

# %% [markdown]
# # Importing and inspecting the data

# %%
# Import the packages that we will be using
import pandas as pd
# Dataset url
path = r"D:\Escuela\SextoSemestre\SemanaTec\TC1002S\NotebooksStudents\A01639678\cartwheel\cartwheel.csv"
# Load the dataset
df = pd.read_csv(path)

# %%
# Print the dataset
print(df)
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %%
# Print the number of rows
rows_count = df.shape[0]
print('Number of Rows count is:', rows_count )
# Out:
# Number of Rows count is: 52

# %%
# Print the number of columns
columns_count = df.shape[1]
print('Number of Columns count is:', columns_count )
# Out:
# Number of Columns count is: 12

# %% [markdown]
# # Activity: work with the iris dataset
#
# 1. Load the iris.csv file in your computer and understand the dataset
#
#
# 2. How many observations (rows) are in total? 149
#
#
# 3. How many variables (columns) are in total? What do they represent? 5
#
#
# 4. How many observations are for each type of flower? There are 5 observations for any flower
#
#
# 5. What is the type of data for each variable? There are 4 columns with float variables and the last one is a string
#
#
# 6. What are the units of each variable? cm

# %%
path = "D:\Escuela\SextoSemestre\SemanaTec\TC1002S\NotebooksStudents\A01639678\iris\iris.csv"
# Load the dataset
df1 = pd.read_csv(r'D:\Escuela\SextoSemestre\SemanaTec\TC1002S\NotebooksStudents\A01639678\iris\iris.csv')
# Print the dataset
print(df1)
# Print the number of rows
rows_count = df1.shape[0]
print('Number of Rows count is:', rows_count )
# Print the number of columns
columns_count = df1.shape[1]
print('Number of Columns count is:', columns_count )
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]
# Number of Rows count is: 149
# Number of Columns count is: 5
