# %% [markdown]
# # Leer Datos Car Wheel
# El objetivo de este notebook es leer el archivo de datos .csv con las información del datasheet de carwheel

# %% [markdown]
# # Definiciones

# %%
# Aqui van las definiciones 
# rutadatos = TBD

# %% [markdown]
# # Import Libraries

# %%
# Import packages 
import pandas as pd

# %% [markdown]
# # Leer Datos
#
# Cargar el archivo de datos y ponerlo en un dataframe de pandas

# %%
# Define the file path

file_path = '/Users/rguti/Documents/TC1002s/TC1002S/NotebooksProfessor/cartwheel/cartwheel.csv'

# Read the CSV file into pandas DataFrame

df = pd.read_csv(file_path)

# %%
df
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %% [markdown]
# Get number of rows and columns

# %%
df.shape
# Out:
# (52, 12)

# %% [markdown]
# Get number of rows

# %%
Nrows = df.shape[0]

print(f"The number of rows is: {Nrows}")
# Out:
# The number of rows is: 52

# %% [markdown]
# Get number of columns

# %%
Ncols = df.shape[1]

print(f"The number of columns is: {Ncols}")
# Out:
# The number of columns is: 12

# %% [markdown]
# # Explorar DataFrame

# %%
# Obtener los nombres de las columnas
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
# Obtener los datos de una columna

# df.Age
# df['Age']

# %%
#  Obtener un nuevo dataframe con algunas columnas
df2 = df[["Age","Height","Wingspan"]]
df2
# Out:
#      Age  Height  Wingspan
# 0   56.0   62.00      61.0
# 1   26.0   62.00      60.0
# 2   33.0   66.00      64.0
# 3   39.0   64.00      63.0
# 4   27.0   73.00      75.0
# 5   24.0   75.00      71.0
# 6   28.0   75.00      76.0
# 7   22.0   65.00      62.0
# 8   29.0   74.00      73.0
# 9   33.0   63.00      60.0
# 10  30.0   69.50      66.0
# 11  28.0   62.75      58.0
# 12  25.0   65.00      64.5
# 13  23.0   61.50      57.5
# 14  31.0   73.00      74.0
# 15  26.0   71.00      72.0
# 16  26.0   61.50      59.5
# 17  27.0   66.00      66.0
# 18  23.0   70.00      69.0
# 19  24.0   68.00      66.0
# 20  23.0   69.00      67.0
# 21  29.0   71.00      70.0
# 22  25.0   70.00      68.0
# 23  26.0   69.00      71.0
# 24  23.0   65.00      63.0
# 25  28.0   75.00      76.0
# 26  24.0   78.40      71.0
# 27  25.0   76.00      73.0
# 28  32.0   63.00      60.0
# 29  38.0   61.50      61.0
# 30  27.0   62.00      60.0
# 31  33.0   65.30      64.0
# 32  38.0   64.00      63.0
# ...

# %%
df2.tail(3)
# Out:
#      Age  Height  Wingspan
# 49  30.0    74.6       NaN
# 50   NaN    71.0      70.0
# 51  27.0     NaN      71.5

# %%
df2.head(4)
# Out:
#     Age  Height  Wingspan
# 0  56.0    62.0      61.0
# 1  26.0    62.0      60.0
# 2  33.0    66.0      64.0
# 3  39.0    64.0      63.0

# %% [markdown]
# # Estadisticas de las variables
#
# Calcular y visualizar estadisiticas descriptivas

# %%
df2.mean(0)
# Out:
# Age         28.411765
# Height      68.971569
# Wingspan    67.313725
# dtype: float64

# %%
df2.describe()
# Out:
#              Age     Height   Wingspan
# count  51.000000  51.000000  51.000000
# mean   28.411765  68.971569  67.313725
# std     5.755611   5.303812   5.624021
# min    22.000000  61.500000  57.500000
# 25%    25.000000  64.500000  63.000000
# 50%    27.000000  69.000000  66.000000
# 75%    30.000000  73.000000  72.000000
# max    56.000000  79.500000  76.000000

# %% [markdown]
# Iris

# %%
# Importar librerías necesarias
import pandas as pd
from sklearn.datasets import load_iris

# Cargar el dataset de iris
iris = load_iris()

# Crear un DataFrame con las características de iris
iris_df = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])

# Añadir la columna de especies (target)
iris_df['species'] = iris['target']

# Mostrar las primeras filas del DataFrame
print(iris_df.head())

# Explorar el DataFrame
print(f"Shape of the iris dataset: {iris_df.shape}")
print(f"Column names: {iris_df.columns}")
print(f"Descriptive statistics: \n{iris_df.describe()}")

# Estadísticas por especie
species_mapping = dict(enumerate(iris['target_names']))
print(f"Species mapping: {species_mapping}")

# Reemplazar valores numéricos de 'species' con nombres
iris_df['species'] = iris_df['species'].map(species_mapping)

# Mostrar DataFrame con nombres de especies
print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# Shape of the iris dataset: (150, 5)
# Column names: Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')
# Descriptive statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# ...
