# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)

# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/TC1002S/NotebooksProfessor/"

else:
    # Define path del proyecto
    Ruta            = "nop"
# Out:
# Mounted at /content/drive

# %%
# url string that hosts our .csv file
url = Ruta + "cartwheel.csv"
print(url)

# Read the .csv file and store it as a pandas Data Frame

df = pd.read_csv(url)
# Out:
# /content/drive/My Drive/TC1002S/NotebooksProfessor/cartwheel.csv

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df
# Out:
#     ID   Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1  56.0      F            1       Y             1   62.00      61.0
# 1    2  26.0      F            1       Y             1   62.00      60.0
# 2    3  33.0      F            1       Y             1   66.00      64.0
# 3    4  39.0      F            1       N             0   64.00      63.0
# 4    5  27.0      M            2       N             0   73.00      75.0
# 5    6  24.0      M            2       N             0   75.00      71.0
# 6    7  28.0      M            2       N             0   75.00      76.0
# 7    8  22.0      F            1       N             0   65.00      62.0
# 8    9  29.0      M            2       Y             1   74.00      73.0
# 9   10  33.0      F            1       Y             1   63.00      60.0
# 10  11  30.0      M            2       Y             1   69.50      66.0
# 11  12  28.0      F            1       Y             1   62.75      58.0
# ...

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.value_counts()
# print(df["ID"].value_counts())
# print(df["Age"].value_counts())
# print(df["Gender"].value_counts())
# print(df["GenderGroup"].value_counts())
# print(df["Glasses"].value_counts())
# print(df["GlassesGroup"].value_counts())
# print(df["Height"].value_counts())
# print(df["Wingspan"].value_counts())
# print(df["CWDistance"].value_counts())
# print(df["CompleteGroup"].value_counts())
# print(df["Score"].value_counts())
# Out:
# ID  Age   Gender  GenderGroup  Glasses  GlassesGroup  Height  Wingspan  CWDistance  Complete  CompleteGroup  Score
# 1   56.0  F       1            Y        1             62.00   61.0      79          Y         1.0            7        1
# 2   26.0  F       1            Y        1             62.00   60.0      70          Y         1.0            8        1
# 3   33.0  F       1            Y        1             66.00   64.0      85          Y         1.0            7        1
# 4   39.0  F       1            N        0             64.00   63.0      87          Y         1.0            10       1
# 5   27.0  M       2            N        0             73.00   75.0      72          N         0.0            4        1
# 6   24.0  M       2            N        0             75.00   71.0      81          N         0.0            3        1
# 7   28.0  M       2            N        0             75.00   76.0      107         Y         1.0            10       1
# ...

# %%
# Proportion of each distinct value of a variable occurs in a data set
df.value_counts(normalize=True)
# Out:
# ID  Age   Gender  GenderGroup  Glasses  GlassesGroup  Height  Wingspan  CWDistance  Complete  CompleteGroup  Score
# 1   56.0  F       1            Y        1             62.00   61.0      79          Y         1.0            7        0.020408
# 2   26.0  F       1            Y        1             62.00   60.0      70          Y         1.0            8        0.020408
# 3   33.0  F       1            Y        1             66.00   64.0      85          Y         1.0            7        0.020408
# 4   39.0  F       1            N        0             64.00   63.0      87          Y         1.0            10       0.020408
# 5   27.0  M       2            N        0             73.00   75.0      72          N         0.0            4        0.020408
# 6   24.0  M       2            N        0             75.00   71.0      81          N         0.0            3        0.020408
# ...

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations

print(f"Número de Observaciones {len(df)}")

# total number of null observations in Age

print(f"Número de null en Age: {pd.isnull(df.Age).sum()}")

# Total number of counts in Age (excluding missing values)

print(f"Número de NOT null en Age: {pd.notnull(df.Age).sum()}")
# Out:
# Número de Observaciones 52
# Número de null en Age: 1
# Número de NOT null en Age: 51

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of Age

df["Age"].plot(kind='hist', edgecolor='black')
plt.show()

# %%
# Plot distribution of CWDistance
df["CWDistance"].plot(kind='hist', edgecolor='black')
plt.show()

# %%
# Plot histogram of both the Age and the Wingspan

plt.hist(df["Age"], edgecolor='black')
plt.hist(df["Wingspan"], edgecolor='black')
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
df.groupby('Gender')['Age'].plot(kind='hist', edgecolor='black')
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "CWDistance"
df.boxplot('CWDistance')
plt.title("Boxplot de CWDistance")
plt.ylabel("CWDistance")
plt.show()

# %%
# Create the boxplot of the "Height"

df.boxplot('Height')
plt.title("Boxplot de Height")
plt.ylabel("Height")
plt.show()

# %%
# Create the boxplots of the "CWDistance", "Height" and "Wingspan"

df.boxplot(["CWDistance",'Height',"Wingspan"])
plt.show()

# %%
# Create the boxplots of the "CWDistance" and of the "Wingspan"

df.boxplot(["CWDistance","Wingspan"])
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "CWDistance" grouped by "Gender"
sns.boxplot(data=df, y='CWDistance', hue='Gender', gap=.4)
# Out:
# <Axes: ylabel='CWDistance'>

# %%
# Create side-by-side boxplots of the "Glasses" grouped by "Gender"
sns.boxplot(data=df, x="Glasses", y="Height", hue="Gender")
# Out:
# <Axes: xlabel='Glasses', ylabel='Height'>

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "tips" grouped by "Gender"

sns.boxplot(data=df, y='Score', hue='Gender', gap=.4)
# Out:
# <Axes: ylabel='Score'>

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
plt.scatter(df['Height'], df['Wingspan'], color='blue', edgecolor='orange')
plt.show()

# %%
# scatter plot between two variables (one categorical)
plt.scatter(df['Height'], df['Gender'], color='blue', edgecolor='orange')
plt.show()

# %%
# scatter plot between two variables (one categorical)
plt.scatter(df['Glasses'], df['Gender'], color='blue', edgecolor='orange')
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable
plt.scatter(df[df['Gender'] == 'M']['Height'],
            df[df['Gender'] == 'M']['Wingspan'],
            color='blue', label='Male', edgecolor='black')

plt.scatter(df[df['Gender'] == 'F']['Height'],
            df[df['Gender'] == 'F']['Wingspan'],
            color='red', label='Female', edgecolor='black')
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers
plt.scatter(df[df['Gender'] == 'M']['Height'],
            df[df['Gender'] == 'M']['Wingspan'],
            color='blue',
            label='Male',
            s=df[df['Gender'] == 'M']['Score']*10,
            edgecolor='black')

plt.scatter(df[df['Gender'] == 'F']['Height'],
            df[df['Gender'] == 'F']['Wingspan'],
            color='red',
            label='Female',
            s=df[df['Gender'] == 'F']['Score']*10,
            edgecolor='black')
plt.show()

# %%
# Pairplot: Scatterplot of "Age","CWDistance","Height",'Wingspan'
sns.pairplot(df[['Age', 'CWDistance', 'Height', 'Wingspan']])
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %%
# Define where you are running the code: colab or local
RunInColab          = True     # (False: no  | True: yes)
# If running in colab:
if RunInColab:
    # Mount your google drive in google colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Find location
    #!pwd
    #!ls
    #!ls "/content/drive/My Drive/Colab Notebooks/MachineLearningWithPython/"

    # Define path del proyecto
    Ruta            = "/content/drive/My Drive/TC1002S/NotebooksProfessor/"

else:
    # Define path del proyecto
    Ruta            = "nop"
# Out:
# Mounted at /content/drive

# %%
# url string that hosts our .csv file
urlnew = Ruta + "iris.csv"
print(urlnew)


# Read the .csv file and store it as a pandas Data Frame

newdf = pd.read_csv(urlnew)
newdf
# Out:
# /content/drive/My Drive/TC1002S/NotebooksProfessor/iris.csv
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Ejercicio 1

# %%
newdf.hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms of Quantitative Variables", fontsize=16)
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# newdf.hist(figsize=(10, 8), bins=20)
# plt.suptitle("Histograms of Quantitative Variables", fontsize=16)

newdf.plot(kind='hist', edgecolor='black')
plt.show()

# %% [markdown]
# # Ejercicio 3

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=newdf)
plt.title("Boxplots of Quantitative Variables")
plt.show()

# %% [markdown]
# # Ejercicio 4

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='variety', y='petal.width', data=newdf)
plt.title("Boxplot of Petal Width by Flower Type")
plt.show()

# %% [markdown]
# # Ejercicio 5

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='variety', y='sepal.length', data=newdf)
plt.title("Boxplot of Sepal Length by Flower Type")
plt.show()

# %% [markdown]
# # Ejercicio 6

# %%
print("Summary statistics of quantitative variables:")
print(newdf.describe())
# Out:
# Summary statistics of quantitative variables:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
