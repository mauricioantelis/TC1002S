# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan
#
# ## Diego Sú Gómez A01620476

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# url string that hosts our .csv file
ruta = "datasets/iris/iris.csv"

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(ruta,header=None)

# %%
df = df.rename(columns={0 : "SepalLength"})
df = df.rename(columns={1: "SepalWidth"})
df = df.rename(columns={2: "PetalLength"})
df = df.rename(columns={3: "PetalWidth"})
df = df.rename(columns={4: "Class"})
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
df.SepalLength.value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 6.2     4
# 5.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.5     1
# 7.0     1
# 5.3     1
# 7.3     1
# 4.3     1
# Name: SepalLength, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = df.SepalLength.value_counts()
prop = x/x.sum() * 100
prop
# Out:
# 5.0    6.666667
# 6.3    6.000000
# 5.1    6.000000
# 5.7    5.333333
# 6.7    5.333333
# 5.8    4.666667
# 5.5    4.666667
# 6.4    4.666667
# 4.9    4.000000
# 6.0    4.000000
# 5.4    4.000000
# 5.6    4.000000
# 6.1    4.000000
# 6.5    3.333333
# 4.8    3.333333
# 6.2    2.666667
# 5.2    2.666667
# 7.7    2.666667
# 6.9    2.666667
# 4.6    2.666667
# 7.2    2.000000
# 5.9    2.000000
# 4.4    2.000000
# 6.8    2.000000
# 6.6    1.333333
# 4.7    1.333333
# 7.1    0.666667
# 7.4    0.666667
# 7.6    0.666667
# 7.9    0.666667
# 4.5    0.666667
# 7.0    0.666667
# 5.3    0.666667
# 7.3    0.666667
# 4.3    0.666667
# Name: SepalLength, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
Obs,Var = df.shape
print(Obs)
# Total number of null observations
ObsNull = df.Class.isnull().sum()
print(ObsNull)
# Total number of counts (excluding missing values)
ObsNoNull = df.Class.notnull().sum()
print(ObsNoNull)
# Out:
# 150
# 0
# 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of the total bill only
X = sns.displot(df["SepalWidth"])
plt.show()

# %%
# Plot distribution of the tips only
X = sns.histplot(df["SepalLength"],kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma de la SepalLength")
plt.show()

# %%
# Plot histogram of both the Age and the Wingspan
sns.histplot(df["PetalLength"],kde=False)
X = sns.histplot(df["PetalWidth"],kde = False)
X.set_ylabel("Frequency")
X.set_title("Histograma de los parámetros de los pétalos")
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"
Y = sns.FacetGrid(df,row = "Class")
Y = Y.map(plt.hist,"SepalLength")
plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot of the "total bill" amounts
r = sns.boxplot(x=df["SepalWidth"])
r.set_title("Boxplot SepalWidth")
plt.show()

# %%
# Create the boxplot of the "tips" amounts
sns.boxplot(x=df["PetalWidth"])
a=sns.boxplot(x=df["PetalLength"])
a.set_title("Boxplot PetalWidth y PetalLength")
plt.show()

# %%
# Create the boxplots of the "Wingspan" and of the "Height" amounts
sns.boxplot(x=df["PetalLength"])
sns.boxplot(x=df["SepalLength"])
plt.show()

# %%
# Create the boxplots of the "Wingspan" and of the "tips" amounts
sns.boxplot(x=df["SepalWidth"])
sns.boxplot(x=df["PetalWidth"])
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "Height" grouped by "Gender"
Xdata = df.loc[:,["PetalLength","PetalWidth","SepalLength","SepalWidth"]]
sns.boxplot(data=Xdata,orient="v")
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "tips" grouped by "Gender"

sns.boxplot(x=df["SepalLength"], y=df["PetalLength"])
plt.show()

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
sns.scatterplot(data=df, y="SepalLength",x = "SepalWidth")
plt.show()

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df,x="SepalWidth",y="PetalWidth")
plt.show()

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df,x="PetalLength",y="SepalLength")
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable
sns.scatterplot(data=df,x="SepalLength",y="SepalWidth",hue="Class")
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers
sns.scatterplot(data=df,x="PetalLength",y="PetalWidth",hue="Class",size="SepalLength",legend=None)
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %%
#Respuestas 1 y 2
X = sns.histplot(df["SepalLength"])
X.set_title("Histograma SepalLength")
X.set_ylabel("Frequency")
plt.show()

# %%
#Se puede observar que la longitud de la sepa de las flores abarca desde 4 hasta 7.5 cm aproximadamente, donde las longitudes
#más dominantes son las que están entre los 5.5 y los 6.25 cm aproximadamente, luego le seguirían las de entre 4.75 y 5.2 cm, y 
#de ahí en adelante ya son más variadas

# %%
X = sns.histplot(df["SepalWidth"])
X.set_title("Histograma SepalWidth")
X.set_ylabel("Frequency")
plt.show()

# %%
#En cuanto a este histograma, se observa que el ancho predominante de la sepa es de entre 2.8 y 3.2 cm aproximadamente, y que el
#resto de sepas ya son más variadas y no están tanto entre la longitud promedio, se puede observar que es una tendencia 
#centralizada,
#puesto que desde los extremos hacia el centro van aumentando los valores

# %%
X = sns.histplot(df["PetalLength"])
X.set_title("Histograma PetalLength")
X.set_ylabel("Frequency")
plt.show()

# %%
#En cuanto a la longitud de los pétalos, se observa que predominan los de entre 1 y 1.7 cm aproximadamente, y luego seguirían 
#los más grandes, entre 3.5 y 6.5 cm son los que más predominan después de los ya mencionados. En este caso, la varianza de
#los valores es bastante grande.

# %%
X = sns.histplot(df["PetalWidth"])
X.set_title("Histograma PetalWidth")
X.set_ylabel("Frequency")
plt.show()

# %%
#la anchura de los pétalos es algo más regular, aunque sigue predominando la anchura muy pequeña, y los pétalos más anchos son
#más escasos dentro de esta muestra estadística. También se puede observar que las medidas sin embargo están un poco mejor
#distrubuidas entre sí y no hay tanta varianza como en la longitud

# %%
#Respuesta 3
r = sns.boxplot(x=df["SepalLength"])
r.set_title("Boxplot SepalLength")
plt.show()

# %%
#En este caso se puede ver que la distribución mayoritaria se encuentra entre los 5.2 y los 6.4 cm de largo, y de ahí en fuera 
#hay algunos valores que ya no pertenecen tanto al promedio, se puede ver también que no hay outliers en esta variable

# %%
r = sns.boxplot(x=df["SepalWidth"])
r.set_title("Boxplot SepalWidth")
plt.show()

# %%
#Contrario al caso anterior, en el ancho de la sepa se pueden apreciar cuatro outliers, y es por eso por lo que este gráfico
#está tan corto en el medio, puesto que los valores están más diferenciados y hay una mayor varianza entre ellos

# %%
r = sns.boxplot(x=df["PetalLength"])
r.set_title("Boxplot PetalLength")
plt.show()

# %%
#Este gráfico permite observar que para la longitud de los pétalos la gran mayoría de los valores abarcan los percentiles 2 y 3
#, y que los valores se concentran en este rango, ya que tampoco se pueden observar outliers.

# %%
r = sns.boxplot(x=df["PetalWidth"])
r.set_title("Boxplot PetalWidth")
plt.show()

# %%
#Al igual que el gráfico anterior, se puede ver que los valores predominan dentro de la caja, por lo que no hay tanta varianza 
#entre las mediciones y esto permite que no haya outliers y que sea más constante esta medida

# %%
#Respuesta 4
t=sns.boxplot(x=df["PetalWidth"], y=df["Class"])
t.set_title("Boxplot PetalWidth vs Class")
plt.show()

# %%
#Para este gráfico de caja, se puede observar que la clase de flor que es la que más provoca la varianza en los datos es la iris
#setosa,puesto que se observa que cuenta con dos valores fuera del rango "normal", lo que hace que los demás datos se vean
#afectados. En cambio, el resto de las flores sigue con una distribución normla de los datos

# %%
#Respuesta 5
q=sns.boxplot(x=df["SepalLength"], y=df["Class"])
q.set_title("Boxplot SepalLength vs Class")
plt.show()

# %%
#Este gráfico permite mostrar que, en cuanto a la longitud de la sepa, la iris virginica es la que cuenta con un outlier, por lo
#que esto podría significar que ese outlier fue el que modificó tanto el diagrama general, sin embargo, en las otras dos flores
#, la distribución sigue estando de forma adecuada y no se resaltan valores extremos importantes.
