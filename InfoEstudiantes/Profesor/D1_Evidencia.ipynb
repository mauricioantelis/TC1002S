# %% [markdown]
# # TC1002S Herramientas computacionales: el arte de la analítica
#
# This is a notebook with all your work for the final evidence of this course
#
#
# # Niveles de dominio a demostrar con la evidencia
#
# ### SING0202A
#
# Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.
#
#
# # Student information
#
# - Name:
#
# - ID:
#
# - My carreer:

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd

# %% [markdown]
# # A1 Load data

# %%
url = "L01046417.csv"

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(url)

# %% [markdown]
# # A2 Data managment

# %% [markdown]
# Print the first 7 rows

# %%
df.head(7)
# Out:
#    Unnamed: 0        x1        x2        x3        x4        x5        x6
# 0           0  4.210094  8.162368  6.390386 -8.916069  3.830503 -5.926408
# 1           1  3.764571  7.627563  8.355818 -9.040587  3.794381 -2.849884
# 2           2  7.083508 -9.430915  3.044111  3.220022  3.035588 -2.678869
# 3           3  0.526555 -6.718922 -8.697643  3.493189 -0.606370  5.980839
# 4           4  3.256206  6.897405  7.043394 -9.995899  4.909124 -3.942438
# 5           5  8.007767 -6.392258  3.423443 -0.196050  3.944418 -1.884682
# 6           6  3.804506 -7.945924  5.057480  1.529277  1.486452 -2.391061

# %% [markdown]
# Print the first 4 last rows

# %% [markdown]
# How many rows and columns are in your data?
#
# Use the `shape` method

# %% [markdown]
# Print the name of all columns
#
# Use the `columns` method

# %% [markdown]
# What is the data type in each column
#
# Use the `dtypes` method

# %% [markdown]
# What is the meaning of rows and columns?

# %%
# Your responses here

# 1) 

# 2) 

# 3) 

#...

# %% [markdown]
# Print a statistical summary of your columns

# %%
# 1) What is the minumum and maximum values of each variable

# Para la variable x1:
#  min: ...
#  max: ...

# 2) What is the mean and standar deviation of each variable

# 3) What the 25%, 50% and 75% represent?

# %% [markdown]
# Rename the columns using the same name with capital letters

# %% [markdown]
# Rename the columns to their original names

# %% [markdown]
# Use two different alternatives to get one of the columns

# %% [markdown]
# Get a slice of your data set: second and thrid columns and rows from 62 to 72

# %% [markdown]
# For the second and thrid columns, calculate the number of null and not null values and verify that their sum equals the total number of rows

# %% [markdown]
# Discard the last column

# %%
df.drop("Unnamed: 0", axis=1, inplace = True)
df.head(3)
# Out:
#          x1        x2        x3        x4        x5        x6
# 0  4.210094  8.162368  6.390386 -8.916069  3.830503 -5.926408
# 1  3.764571  7.627563  8.355818 -9.040587  3.794381 -2.849884
# 2  7.083508 -9.430915  3.044111  3.220022  3.035588 -2.678869

# %% [markdown]
# ### Questions
#
# Based on the previos results, provide a description of yout dataset
#
# Your response:

# %% [markdown]
# # A3 Data visualization

# %% [markdown]
# Plot in the same figure the histogram of the two variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Plot histogram of both the Age and the Wingspan
sns.distplot(df["x1"], kde = False, color='r')
dfhist = sns.distplot(df["x2"], kde = False, color='b')#.set_title("Histogram of both Age and Wingspan")
dfhist2 = sns.distplot(df["x3"], kde = False)
dfhist3 = sns.distplot(df["x4"], kde = False)
dfhist.set_ylabel("Frequency")
dfhist.set_title("Histogram of both x1 and x2")

plt.show()

# %%
#sns.pairplot(df)
sns.pairplot(df, corner =True)

# %% [markdown]
# Based on this plots, provide a description of your data:
#
# Your response here:

# %% [markdown]
# Plot in the same figure the boxplot of the two variables

# %%
fig,axs=plt.subplots(3,2,figsize=(20,13))
col=['x1', 'x2', 'x3', 'x4', 'x5','x6']
ax=axs.flatten()

for i,j in enumerate(col):
    sns.boxplot(x=df[j],ax=ax[i],color='red')

# %%
sns.boxplot(data=df, orient="v", palette="Set3");

# %% [markdown]
# Scatter plot of the two variables

# %% [markdown]
# ### Questions
#
# Based on the previos plots, provide a description of yout dataset
#
# Your response:

# %%
#plt.figure(figsize=(15,15))
#sns.heatmap(df.corr(),annot=True,square=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      417 non-null    float64
#  1   x2      417 non-null    float64
#  2   x3      417 non-null    float64
#  3   x4      417 non-null    float64
#  4   x5      417 non-null    float64
#  5   x6      417 non-null    float64
# dtypes: float64(6)
# memory usage: 19.7 KB

# %% [markdown]
# # A4 Kmeans

# %% [markdown]
# Do Kmeans clustering assuming a number of clusters accorging to your scatter plot

# %% [markdown]
# Add to your dataset a column with the assihned cluster to each data point

# %% [markdown]
# Print the number associated to each cluster

# %% [markdown]
# Print the centroids

# %% [markdown]
# Print the intertia metric

# %% [markdown]
# Plot a scatter plot of your data assigned to each cluster. Also plot the centroids

# %% [markdown]
# ### Questions
#
# Provides a detailed description of your results
#
# Your response:

# %% [markdown]
# # A4 Elbow plot
#
# Compute the Elbow plot

# %% [markdown]
# ### Questions
#
# What is the best number of clusters K? (argue your response)
#
# Your response:
#
#
# Does this number of clusters agree with your inital guess? (argue your response)
#
# Your response:

# %% [markdown]
# # BONUS

# %% [markdown]
# 1) Generate some data using the "make_blobs" function from "sklearn.datasets"
#
# - The number of observations is equal to the three last digits in your ID
#
# - 2 variables
#
# - 4 clusters
#
# - Standar deviation of each cluster of 1.5

# %% [markdown]
# 2) Plot the scatter plot of your data using the real cluster labels

# %% [markdown]
# 3) Do K means clustering

# %% [markdown]
# 4) Plot the scatter plot of your data using the estimated cluster labels

# %% [markdown]
# ### Questions
#
# Provides a detailed description of your results.
#
# Your response:

# %% [markdown]
# # Descipcion de tu percepcion del nivel de desarrollo de la subcompetencia
#
# ### SING0202A Interpretación de variables

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Interpreta interacciones**. Interpreta interacciones entre variables relevantes en un problema, como base para la construcción de modelos bivariados basados en datos de un fenómeno investigado que le permita reproducir la respuesta del mismo.

# %% [markdown]
# Tu respuesta:

# %% [markdown]
# Escribe tu description del nivel de logro del siguiente criterio de la subcompetencia
#
# **Construcción de modelos**. Es capaz de construir modelos bivariados que expliquen el comportamiento de un fenómeno.

# %% [markdown]
# Tu respuesta:
