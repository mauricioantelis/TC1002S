# %%
import pandas as pd

ruta = "datasets/iris/iris.csv"


iris = pd.read_csv(ruta)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
sns.displot(iris["5.1"])
plt.show()

# %%
sns.displot(iris["3.5"])
plt.show()

# %%
sns.displot(iris["1.4"])
plt.show()

# %%
sns.displot(iris["0.2"])
plt.show()

# %%
sns.displot(iris["Iris-setosa"])
plt.show()

# %%
g = sns.FacetGrid(iris,row="Iris-setosa")
g = g.map(plt.hist,"5.1")

plt.show()

# %%
data = sns.boxplot(iris["5.1"])
data.set(title = "Diagrama de longitud de setal")
plt.show
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = sns.boxplot(iris["3.5"])
data.set(title = "Diagrama de longitud de setal")
plt.show
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = sns.boxplot(iris["1.4"])
data.set(title = "Diagrama de longitud de setal")
plt.show
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = sns.boxplot(iris["0.2"])
data.set(title = "Diagrama de longitud de setal")
plt.show
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(y=iris["0.2"], x=iris["Iris-setosa"]).set(title = "De longitud por el tipo de flor")

plt.show()

# %%
sns.boxplot(y=iris["5.1"], x=iris["Iris-setosa"]).set(title = "De longitud por el tipo de flor")

plt.show()
