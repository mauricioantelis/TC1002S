# %% [markdown]
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# Define the col names for the iris dataset
colnames = ["Sepal_Length", "Sepal_Width","Petal_Length","Petal_Width", "Flower_Name"]

# Dataset url
# from HHDD
url = "datasets/iris/iris.csv"

dataframe = pd.read_csv(url, header = None, names = colnames )

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
dataframe.head(5)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Flower_Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set
#dataframe.Sepal_Length.value_counts()
#dataframe.Sepal_Width.value_counts()
#dataframe.Petal_Length.value_counts()
#dataframe.Petal_Width.value_counts()
dataframe.Flower_Name.value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Flower_Name, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = dataframe.Flower_Name.value_counts()

proporcion = 100 * x / x.sum()

proporcion
# Out:
# Iris-virginica     33.333333
# Iris-versicolor    33.333333
# Iris-setosa        33.333333
# Name: Flower_Name, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
Nobs, Nvar = dataframe.shape
print(Nobs)


# Total number of null observations
NobsNull = dataframe.Flower_Name.isnull().sum()
print(NobsNull)

# Total number of counts (excluding missing values)
NobsNotNull = dataframe.Flower_Name.notnull().sum()
print(NobsNotNull)
# Out:
# 150
# 0
# 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of the total bill only
#X = sns.displot(dataframe["Height"], kde=True)
#X.set_ylabel("Frequency")
#X.set_title("Histograma de la altura")

X = sns.distplot(dataframe["Sepal_Length"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del tamaño del sétalo en las flores")
plt.show()

# %%
# Plot distribution of the tips only
X = sns.distplot(dataframe["Sepal_Width"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del ancho del sétalo en las flores")
plt.show()

# %%
# Plot distribution of the tips only
X = sns.distplot(dataframe["Petal_Length"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del largo del petalo en las flores")
plt.show()
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot distribution of the tips only
X = sns.distplot(dataframe["Petal_Width"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del ancho del petalo en las flores")
plt.show()

# %%
dataframe["FlowerNameGroup"] = dataframe.Flower_Name.replace({"Iris-setosa": 1, "Iris-versicolor": 2, "Iris-virginica": 3})
# Plot distribution of the tips only
X = sns.distplot(dataframe["FlowerNameGroup"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del tipo de flores")
plt.show()

# %%
# Plot histogram of both the Age and the Wingspan
sns.distplot(dataframe["Sepal_Length"], kde=False)
X = sns.distplot(dataframe["Sepal_Width"], kde=False)
X.set_ylabel("Frequency")
X.set_title("Histograma del tamaño y ancho del sétalo ")
plt.show()

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"

g = sns.FacetGrid(dataframe, row = "Flower_Name")
g = g.map(plt.hist, 'Sepal_Length')

plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot
Y = sns.boxplot(dataframe["Sepal_Length"])
Y.set_title("Diagrama de bigotes del largo del sépalo")
plt.show()
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplot of the "CDDsitance" amounts
Y1 = sns.boxplot(dataframe["Sepal_Width"])
Y1.set_title("Diagrama de bigotes del ancho del sépalo")
plt.show()
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "Wingspan" and of the "Height" amounts
sns.boxplot(dataframe["Sepal_Length"])
sns.boxplot(dataframe["Sepal_Width"])

plt.show()
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "Wingspan" and of the "tips" amounts
sns.boxplot(dataframe["Petal_Length"])
sns.boxplot(dataframe["Petal_Width"])

plt.show()
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\carlo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "Height" grouped by "Gender"

Xdata = dataframe.loc[:, ["Sepal_Length", "Sepal_Width", "Petal_Length", "Petal_Width"]]

sns.boxplot(data=Xdata, orient="h")

plt.show()

#Los diamantes nos muestran datos atipicos

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "Wingspan" grouped by "Gender"

#sns.boxplot(x=dataframe["Wingspan"], y = dataframe["Gender"]).set_title("Boxplot de wingspan de cada genero")

sns.boxplot(x=dataframe["Sepal_Length"], y = dataframe["Flower_Name"]).set_title("Boxplot del largo del sépalo de cada genero")

plt.show()

# %%
sns.boxplot(x=dataframe["Petal_Width"], y = dataframe["Flower_Name"]).set_title("Boxplot del ancho del petalo de cada genero")

plt.show()

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
sns.scatterplot(data = dataframe, x= "Petal_Length", y="Petal_Width")
plt.show()

# %% [markdown]
# # scatter plot between two variables (one categorical)

# %%
# scatter plot between two variables (one categorical)
#sns.scatterplot(data = dataframe, x= "CWDistance", y="Gender" )
sns.scatterplot(data = dataframe, x= "Petal_Length", y="Flower_Name" )
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable
sns.scatterplot(data = dataframe, y= "Petal_Length", x="Petal_Width", hue= "Flower_Name")
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers

sns.scatterplot(data = dataframe, x = "Petal_Length", y = "Petal_Width", hue= "Flower_Name", size = "Sepal_Length")
plt.show()

sns.scatterplot(data = dataframe, x = "Sepal_Length", y = "Sepal_Width", hue= "Flower_Name", size = "Petal_Length")
plt.show()

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
# OK
#
# 2. Plot the histograms for each of the quantitative variables
# OK
#
# 3. Plot the boxplots for each of the quantitative variables
# OK
#
# 4. Plot the boxplots of the petal width grouped by type of flower
# OK
#
# 5. Plot the boxplots of the setal length grouped by type of flower
# OK
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables
#
# Cada una de las variables de las flores representan caracterisiticas fisicas de las mismas, de acuerdo a cada uno de los distintos tipos de flores, estos van cambiando. En cada una de las graficas que observaron, se puede ver como el ancho y largo del petalo en las flores esta directamente relacionado entre ellos, tambien se puede notar como por cada especie sus petalos y sepalos crecen o decrecen y se agrupan junto a las flores de su misma familia.
