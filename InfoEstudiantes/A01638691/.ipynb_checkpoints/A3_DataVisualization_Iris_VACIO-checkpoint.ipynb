# %% [markdown]
# Gerardo Novelo De Anda
#
# Matricula: A01638691
#
# Actividad Evaluable: Manejo de datos con Pandas
#
# Herramientas computacionales: el arte de la analítica (Gpo 2)
#
#
# # Visualizing Data in Python
#
# When working with a new dataset, one of the most useful things to do is to begin to visualize the data. By using **tables**, **histograms**, **boxplots**, **scatter plots** and other visual tools, we can get a better idea of what the data may be trying to tell us, and we can gain insights into the data that we may have not discovered otherwise.
#
# In this notebook will use the [Seaborn](https://seaborn.pydata.org/) data processing library, which is a higher-level interface to **Matplotlib** that can be used to simplify many visualization tasks
#
# The **Seaborn** provides visualisations tools that will allow to explore data from a graphical perspective.
#
#
# ## Acknowledgments
#
# - Data from https://www.coursera.org/ from the course "Understanding and Visualizing Data with Python" by University of Michigan

# %% [markdown]
# # Importing libraries

# %%
# Import the packages that we will be using
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
# url string that hosts our .csv file
ruta = 'dataset/iris/iris.csv'

# Read the .csv file and store it as a pandas Data Frame
df = pd.read_csv(ruta)

df.head(5)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Exploring the content of the data set
#
# Get a general 'feel' of the data

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Frequency tables
#
# The `value_counts()` method can be used to determine the number of times that each distinct value of a variable occurs in a data set.  In statistical terms, this is the "frequency distribution" of the variable. The `value_counts()` method produces a table with two columns.  The first column contains all distinct observed values for the variable.  The second column contains the number of times each of these values occurs.  Note that the table returned by `value_counts()` is actually a **Pandas** data frame, so can be further processed using any Pandas methods for working with data frames.

# %%
# Number of times that each distinct value of a variable occurs in a data set

df.SepalLength.value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 6.2     4
# 5.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.5     1
# 7.0     1
# 5.3     1
# 7.3     1
# 4.3     1
# Name: SepalLength, dtype: int64

# %%
# Proportion of each distinct value of a variable occurs in a data set
x = df.SepalLength.value_counts()
prop = x/x.sum() * 100
prop
# Out:
# 5.0    6.666667
# 6.3    6.000000
# 5.1    6.000000
# 5.7    5.333333
# 6.7    5.333333
# 5.8    4.666667
# 5.5    4.666667
# 6.4    4.666667
# 4.9    4.000000
# 6.0    4.000000
# 5.4    4.000000
# 5.6    4.000000
# 6.1    4.000000
# 6.5    3.333333
# 4.8    3.333333
# 6.2    2.666667
# 5.2    2.666667
# 7.7    2.666667
# 6.9    2.666667
# 4.6    2.666667
# 7.2    2.000000
# 5.9    2.000000
# 4.4    2.000000
# 6.8    2.000000
# 6.6    1.333333
# 4.7    1.333333
# 7.1    0.666667
# 7.4    0.666667
# 7.6    0.666667
# 7.9    0.666667
# 4.5    0.666667
# 7.0    0.666667
# 5.3    0.666667
# 7.3    0.666667
# 4.3    0.666667
# Name: SepalLength, dtype: float64

# %% [markdown]
# Note that the `value_counts()` method excludes missing values. We confirm this below by adding up observations to your data frame with some missing values and then computing `value_counts()` and comparing this to the total number of rows in the data set, which is 28. This tells us that there are 28 - (21+6) = 1 missing values for this variable (other variables may have different numbers of missing values).

# %%
# Total number of observations
Nobs, Nvar = df.shape
print(Nobs)


# Total number of null observations
NobsNull = df.Class.isnull().sum()
print(NobsNull)

# Total number of counts (excluding missing values)
NobsNoNull = df.Class.notnull().sum()
print(NobsNoNull)
# Out:
# 150
# 0
# 150

# %% [markdown]
# # Histogram
#
# It is often good to get a feel for the shape of the distribution of the data.

# %%
# Plot histogram of the total bill only
X = sns.distplot( df["SepalWidth"] )

plt.show()

# %%
# Plot distribution of the tips only
X = sns.distplot( df["SepalWidth"] , kde=False)
X.set_ylabel("Frequency")
X.set_title("Histrograma de Width")

plt.show()
# Out:
# C:\Users\geraq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot histogram of both the Age and the Wingspan
sns.distplot( df["PetalLength"], kde=False)
X = sns.distplot( df["PetalWidth"] , kde=False)
X.set_ylabel("Frequency")
X.set_title("Histrograma de PetalWidth")

plt.show()
# Out:
# C:\Users\geraq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histograms plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a histograms of one quantitative variable grouped by another categorical variables.

# %%
# Create histograms of the "Wingspan" grouped by "Gender"
g = sns.FacetGrid(df,row="Class")
g = g.map(plt.hist, 'SepalLength')

plt.show()

# %% [markdown]
# # Boxplots
#
# Boxplots do not show the shape of the distribution, but they can give us a better idea about the center and spread of the distribution as well as any potential outliers that may exist. Boxplots and Histograms often complement each other and help an analyst get more information about the data

# %%
# Create the boxplot
Y = sns.boxplot(x=df["SepalWidth"])
Y.set_title("Diagrama de bigotes de SepalWidth")
plt.show()

# %%
# Create the boxplot
Y = sns.boxplot(df["SepalLength"])
Y.set_title("Diagrama de bigotes de SepalLength")
plt.show()
# Out:
# C:\Users\geraq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the boxplots of the "PetalWidth" and of the "PetalLength" amounts

sns.boxplot(x=df["PetalWidth"])
j=sns.boxplot(x=df["PetalLength"])
j.set_title("Diagrama de bigotes de PetalWidth y PetalLength")
plt.show()

# %%
# Create the boxplots of the "Wingspan" and of the "CWDistance" amounts

sns.boxplot(x=df["SepalWidth"])
j=sns.boxplot(x=df["SepalLength"])
j.set_title("Diagrama de bigotes de SepalWidth y SepalLength")
plt.show()

# %% [markdown]
# # Boxplots plotted by groups
#
# While looking at a single variable is interesting, it is often useful to see how a variable changes in response to another. Thus, we can create a side-by-side boxplots of one quantitative variable grouped by another categorical variables.

# %%
# Create side-by-side boxplots of the "Height" grouped by "Gender"
Xdata = df.loc[:,["PetalLength","PetalWidth","SepalLength","SepalWidth"]]
sns.boxplot(data=Xdata, orient="v")
plt.show()

# %% [markdown]
# # Histograms and boxplots plotted by groups
#
# We cal also create both boxplots and histograms of one quantitative variable grouped by another categorical variables

# %%
# Create a boxplot and histogram of the "tips" grouped by "Gender"

sns.boxplot(x=df["SepalLength"], y=df["PetalLength"]).set_title("Boxplot de SepalLength de cada PetalLength")

plt.show()

# %% [markdown]
# # Scatter plot
#
# Plot values of one variable versus another variable to see how they are correlated

# %%
# scatter plot between two variables
sns.scatterplot(data=df, y="SepalLength", x="SepalWidth")
plt.show()

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x="PetalLength", y="PetalWidth")
plt.show()

# %%
# scatter plot between two variables (one categorical)
sns.scatterplot(data=df, x="PetalWidth", y="SepalWidth")
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable
sns.scatterplot(data=df, y="SepalWidth", x="SepalLength", hue="Class")
plt.show()

# %%
# scatter plot between two variables grouped according to a categorical variable and with size of markers

# %% [markdown]
# # Final remarks
#
#
# - Visualizing your data using **tables**, **histograms**, **boxplots**, **scatter plots** and other tools is essential to carry put analysis and extract conclusions
#
# - There are several ways to do the same thing
#
# - The **Seaborn** package provides visualisations tools that allow to explore data from a graphical perspective

# %% [markdown]
# # Activity: work with the iris dataset
#
# Repeat this tutorial with the iris data set and respond to the following inquiries
#
# 1. Plot the histograms for each of the four quantitative variables
#
#
# 2. Plot the histograms for each of the quantitative variables
#
#
# 3. Plot the boxplots for each of the quantitative variables
#
#
# 4. Plot the boxplots of the petal width grouped by type of flower
#
#
# 5. Plot the boxplots of the setal length grouped by type of flower
#
#
# 6. Provide a description (explaination from your observations) of each of the quantitative variables

# %%
# 1.Plot the histograms for each of the four quantitative variables // Trazar los histogramas para cada una de las cuatro variables cuantitativas
# 2.Plot the histograms for each of the quantitative variables // Trazar los histogramas para cada una de las variables cuantitativas
X = sns.distplot(df["SepalLength"])
X.set_ylabel("Frequency")
X.set_title("Histrograma de SepalLength")

plt.show()

X = sns.distplot(df["SepalWidth"])
X.set_ylabel("Frequency")
X.set_title("Histrograma de SepalWidth")

plt.show()

X = sns.distplot(df["PetalLength"])
X.set_ylabel("Frequency")
X.set_title("Histrograma de PetalLength")

plt.show()

X = sns.distplot(df["PetalWidth"])
X.set_ylabel("Frequency")
X.set_title("Histrograma de PetalWidth")

plt.show()
# Out:
# C:\Users\geraq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\geraq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# 3.Plot the boxplots for each of the quantitative variables // Trazar los diagramas de caja para cada una de las variables cuantitativas
Y = sns.boxplot(x=df["SepalLength"])
Y.set_title("Diagrama de bigotes de SepalLength")
plt.show()

Y = sns.boxplot(x=df["SepalWidth"])
Y.set_title("Diagrama de bigotes de SepalWidth")
plt.show()

Y = sns.boxplot(x=df["PetalLength"])
Y.set_title("Diagrama de bigotes de PetalLength")
plt.show()

Y = sns.boxplot(x=df["PetalWidth"])
Y.set_title("Diagrama de bigotes de PetalWidth")
plt.show()

# %%
# 4.Plot the boxplots of the petal width grouped by type of flower // Trazar las parcelas de caja del ancho de pétalos agrupadas por tipo de flor
z=sns.boxplot(x=df["PetalWidth"], y=df["Class"]).set_title("Diagrama de bigotes de PetalWidth contra Class")
plt.show()

# %%
# 5.Plot the boxplots of the setal length grouped by type of flower // Trazar las tramas de caja de la longitud setal agrupadas por tipo de flor
a=sns.boxplot(x=df["SepalLength"], y=df["Class"]).set_title("Diagrama de bigotes de SepalLength contra Class")
plt.show()
